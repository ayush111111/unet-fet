# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush111111/unet-fet/blob/main/Unet_fetal_head_seg_retrained_ellipse_fitted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/'Semester Project '/dataset_filled/
# %ls
# Out:
# /content/drive/MyDrive/Semester Project /dataset_filled
# best_model_224_res.h5  test_set/  training_set/

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
trainPath = "training_set/"
testPath = "test_set/"
trainList = sorted(os.listdir(trainPath))
testList = sorted(os.listdir(testPath))


train_image = []
train_mask = []
for i, item in enumerate(trainList):
    if i % 2 == 0:
        train_image.append(item)
    else:
        train_mask.append(item)
print("Ultrasound training images in dataset {}".format(len(train_image)))
print("Ultrasound training masks in dataset  {}".format(len(train_mask)))
# Out:
# Ultrasound training images in dataset 999
# Ultrasound training masks in dataset  999

# %%
img = np.array(Image.open(trainPath+"000_HC.png"))
img_mask = np.array(Image.open(trainPath+"000_HC_Annotation.png"))
img_mask = np.ma.masked_where(img_mask == 0, img_mask)
print(len(img[0]))
#display images with mask
fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(img, cmap = 'gray')
ax[1].imshow(img_mask, cmap = 'gray')
ax[2].imshow(img, cmap = 'gray', interpolation = 'none')
ax[2].imshow(img_mask, cmap = 'gray', interpolation = 'none', alpha = 0.7)
# Out:
# 800

# %%
#
X = []
y = []
for image, mask in zip(train_image, train_mask):
    X.append(np.array(Image.open(trainPath+image)))
    y.append(np.array(Image.open(trainPath+mask)))

X = np.array(X)
y = np.array(y)

print("X_shape : ", X.shape)
print("y_shape : ", y.shape)
# Out:
# X_shape :  (999,)
# y_shape :  (999,)
# <ipython-input-7-5829c98f866b>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# <ipython-input-7-5829c98f866b>:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y = np.array(y)

# %%
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split

import tensorflow.keras
import tensorflow as tf
from tensorflow.keras import backend as K

K.set_image_data_format('channels_last')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Add
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
def Generator(X_list, y_list, batch_size = 16):
    c = 0

    while(True):
        X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            image = X_list[i]
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            mask =  y_list[i]
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            X[i - c] = image
            y[i - c] = mask
        
        X = X[:,:,:,np.newaxis] / 255
        y = y[:,:,:,np.newaxis] / 255
        
        c += batch_size
        if(c+batch_size >= len(X_list)):
            c = 0
        yield X, y

# %%
train_img_aug = []
train_mask_aug = []


for img, mask in zip(train_image, train_mask):
    img = cv2.imread(trainPath + img)
    mask = cv2.imread(trainPath + mask)
    train_img_aug.append(img)
    
    train_mask_aug.append(mask)
    img_lr = np.fliplr(img)
    mask_lr = np.fliplr(mask)

    img_up = np.flipud(img)
    mask_up = np.flipud(mask)

    img_lr_up = np.flipud(img_lr)
    mask_lr_up = np.flipud(mask_lr)

    img_up_lr = np.fliplr(img_up)
    mask_up_lr = np.fliplr(mask_up)

    train_img_aug.append(img_lr)
    train_mask_aug.append(mask_lr)

    train_img_aug.append(img_up)
    train_mask_aug.append(mask_up)

    train_img_aug.append(img_lr_up)
    train_mask_aug.append(mask_lr_up)

    train_img_aug.append(img_up_lr)
    train_mask_aug.append(mask_up_lr)

print(len(train_image))
print(len(train_img_aug))
# Out:
# 999
# 4995

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
# define building blocks
def BatchnormActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_block(x, filters, size, strides=(1,1), padding="same", activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchnormActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchnormActivate(blockInput)
    x = conv_block(x, num_filters, (3,3))
    x = conv_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchnormActivate(x)
    return x

# %%
def build_Unet(input_layer, start_neurons, DropoutRatio = 0.5):
    

    """ Encoder """
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    #pool1 = Dropout(DropoutRatio/2)(pool1)

    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    #pool2 = Dropout(DropoutRatio)(pool2)

    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    #pool3 = Dropout(DropoutRatio)(pool3)

    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    #pool4 = Dropout(DropoutRatio)(pool4)


    """ Bridge """
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)



    """ Decoder """
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    #uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    #uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    """ Output """
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

# %%
#split training data

#test_size changed from 0.3 t0 0.2 
X_train, X_val, y_train, y_val = train_test_split(train_img_aug, train_mask_aug, test_size = 0.2, random_state = 1)

# set training parameters
epochs = 50
batch_size = 16
steps_per_epoch = int(len(X_train) / batch_size)
validation_steps = int(len(X_val) / batch_size)

train_gen = Generator(X_train, y_train, batch_size = batch_size)
val_gen = Generator(X_val, y_val, batch_size = batch_size)

# initialize our model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, 1))
output_layer = build_Unet(inputs, 16, 0.5)

# Define callbacks to save model with best val_dice_coef
checkpointer = ModelCheckpoint(filepath = 'best_model_224_res.h5', monitor='val_dice_coef', verbose=1, save_best_only=True, mode='max')
model = Model(inputs=[inputs], outputs=[output_layer])
model.compile(optimizer=Adam(lr = 1e-4), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d_46 (Conv2D)             (None, 224, 224, 16  160         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 224, 224, 16  64         ['conv2d_46[0][0]']
#  ormalization)                  )
#
#  activation_45 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 224, 224, 16  2320        ['activation_45[0][0]']
#                                 )
#
#  batch_normalization_46 (BatchN  (None, 224, 224, 16  64         ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  activation_46 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_46[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 224, 224, 16  2320        ['activation_46[0][0]']
#                                 )
#
#  add_18 (Add)                   (None, 224, 224, 16  0           ['conv2d_48[0][0]',
#                                 )                                 'conv2d_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 224, 224, 16  64         ['add_18[0][0]']
#  ormalization)                  )
#
#  activation_47 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 224, 224, 16  2320        ['activation_47[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 224, 224, 16  64         ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 224, 224, 16  2320        ['activation_48[0][0]']
#                                 )
#
#  add_19 (Add)                   (None, 224, 224, 16  0           ['conv2d_50[0][0]',
#                                 )                                 'add_18[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 224, 224, 16  64         ['add_19[0][0]']
#  ormalization)                  )
#
#  activation_49 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 112, 112, 16  0          ['activation_49[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 112, 112, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_50 (BatchN  (None, 112, 112, 32  128        ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  activation_50 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_50[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 112, 112, 32  9248        ['activation_50[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 112, 112, 32  128        ['conv2d_52[0][0]']
#  ormalization)                  )
#
#  activation_51 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 112, 112, 32  9248        ['activation_51[0][0]']
#                                 )
#
#  add_20 (Add)                   (None, 112, 112, 32  0           ['conv2d_53[0][0]',
#                                 )                                 'conv2d_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 112, 112, 32  128        ['add_20[0][0]']
#  ormalization)                  )
#
#  activation_52 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 112, 112, 32  9248        ['activation_52[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 112, 112, 32  128        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  activation_53 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 112, 112, 32  9248        ['activation_53[0][0]']
#                                 )
#
#  add_21 (Add)                   (None, 112, 112, 32  0           ['conv2d_55[0][0]',
#                                 )                                 'add_20[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 112, 112, 32  128        ['add_21[0][0]']
#  ormalization)                  )
#
#  activation_54 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_54[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 32)  0           ['activation_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 56, 56, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 56, 56, 64)  256         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 56, 56, 64)  256         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_56[0][0]']
#
#  add_22 (Add)                   (None, 56, 56, 64)   0           ['conv2d_58[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 56, 56, 64)  256         ['add_22[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 56, 56, 64)  256         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_58[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_58[0][0]']
#
#  add_23 (Add)                   (None, 56, 56, 64)   0           ['conv2d_60[0][0]',
#                                                                   'add_22[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 56, 56, 64)  256         ['add_23[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_59[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_59[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 28, 28, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 28, 28, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_61[0][0]']
#
#  add_24 (Add)                   (None, 28, 28, 128)  0           ['conv2d_63[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 28, 28, 128)  512        ['add_24[0][0]']
#  ormalization)
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#  activation_62 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_62[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 28, 28, 128)  512        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_63[0][0]']
#
#  add_25 (Add)                   (None, 28, 28, 128)  0           ['conv2d_65[0][0]',
#                                                                   'add_24[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 28, 28, 128)  512        ['add_25[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_64[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_64[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 14, 14, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_65[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_66[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_66[0][0]']
#
#  add_26 (Add)                   (None, 14, 14, 256)  0           ['conv2d_68[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 14, 14, 256)  1024       ['add_26[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_67[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_68[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_68[0][0]']
#
#  add_27 (Add)                   (None, 14, 14, 256)  0           ['conv2d_70[0][0]',
#                                                                   'add_26[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 14, 14, 256)  1024       ['add_27[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_69[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 28, 28, 128)  295040     ['activation_69[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'activation_64[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 28, 28, 128)  295040      ['concatenate_4[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 28, 28, 128)  512        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_70[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_70[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 28, 28, 128)  512        ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_71[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_71[0][0]']
#
#  add_28 (Add)                   (None, 28, 28, 128)  0           ['conv2d_73[0][0]',
#                                                                   'conv2d_71[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 28, 28, 128)  512        ['add_28[0][0]']
#  ormalization)
#
#  activation_72 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_72[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_72[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 28, 28, 128)  512        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_73[0][0]']
#
#  add_29 (Add)                   (None, 28, 28, 128)  0           ['conv2d_75[0][0]',
#                                                                   'add_28[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 28, 28, 128)  512        ['add_29[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_74[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_74[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'activation_59[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 56, 56, 64)   73792       ['concatenate_5[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 56, 56, 64)  256         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_75[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 56, 56, 64)  256         ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_76[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_76[0][0]']
#
#  add_30 (Add)                   (None, 56, 56, 64)   0           ['conv2d_78[0][0]',
#                                                                   'conv2d_76[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 56, 56, 64)  256         ['add_30[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_77[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 56, 56, 64)  256         ['conv2d_79[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_78[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_78[0][0]']
#
#  add_31 (Add)                   (None, 56, 56, 64)   0           ['conv2d_80[0][0]',
#                                                                   'add_30[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 56, 56, 64)  256         ['add_31[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_79[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_79[0][0]']
#  spose)                         )
#
#  concatenate_6 (Concatenate)    (None, 112, 112, 64  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'activation_54[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 112, 112, 32  18464       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_80 (BatchN  (None, 112, 112, 32  128        ['conv2d_81[0][0]']
#  ormalization)                  )
#
#  activation_80 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_80[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 112, 112, 32  9248        ['activation_80[0][0]']
#                                 )
#
#  batch_normalization_81 (BatchN  (None, 112, 112, 32  128        ['conv2d_82[0][0]']
#  ormalization)                  )
#
#  activation_81 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_81[0][0]']
#                                 )
#
#  conv2d_83 (Conv2D)             (None, 112, 112, 32  9248        ['activation_81[0][0]']
#                                 )
#
#  add_32 (Add)                   (None, 112, 112, 32  0           ['conv2d_83[0][0]',
#                                 )                                 'conv2d_81[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 112, 112, 32  128        ['add_32[0][0]']
#  ormalization)                  )
#
#  activation_82 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_82[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 112, 112, 32  9248        ['activation_82[0][0]']
#                                 )
#
#  batch_normalization_83 (BatchN  (None, 112, 112, 32  128        ['conv2d_84[0][0]']
#  ormalization)                  )
#
#  activation_83 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 112, 112, 32  9248        ['activation_83[0][0]']
#                                 )
#
#  add_33 (Add)                   (None, 112, 112, 32  0           ['conv2d_85[0][0]',
#                                 )                                 'add_32[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 112, 112, 32  128        ['add_33[0][0]']
#  ormalization)                  )
#
#  activation_84 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_84[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 224, 224, 16  4624       ['activation_84[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 224, 224, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'activation_49[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 224, 224, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_85 (BatchN  (None, 224, 224, 16  64         ['conv2d_86[0][0]']
#  ormalization)                  )
#
#  activation_85 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_85[0][0]']
#                                 )
#
#  conv2d_87 (Conv2D)             (None, 224, 224, 16  2320        ['activation_85[0][0]']
#                                 )
#
#  batch_normalization_86 (BatchN  (None, 224, 224, 16  64         ['conv2d_87[0][0]']
#  ormalization)                  )
#
#  activation_86 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_86[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 224, 224, 16  2320        ['activation_86[0][0]']
#                                 )
#
#  add_34 (Add)                   (None, 224, 224, 16  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 224, 224, 16  64         ['add_34[0][0]']
#  ormalization)                  )
#
#  activation_87 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_87[0][0]']
#                                 )
#
#  conv2d_89 (Conv2D)             (None, 224, 224, 16  2320        ['activation_87[0][0]']
#                                 )
#
#  batch_normalization_88 (BatchN  (None, 224, 224, 16  64         ['conv2d_89[0][0]']
#  ormalization)                  )
#
#  activation_88 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_88[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 224, 224, 16  2320        ['activation_88[0][0]']
#                                 )
#
#  add_35 (Add)                   (None, 224, 224, 16  0           ['conv2d_90[0][0]',
#                                 )                                 'add_34[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 224, 224, 16  64         ['add_35[0][0]']
#  ormalization)                  )
#
#  activation_89 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 224, 224, 1)  17          ['activation_89[0][0]']
#
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# Out:
# Epoch 1/100
# <ipython-input-34-350936afeb50>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# 249/249 [==============================] - ETA: 0s - loss: -0.7548 - accuracy: 0.9328 - dice_coef: 0.7548 - specificity: 0.9487 - sensitivity: 0.9103 - precision: 0.8703
# Epoch 1: val_dice_coef improved from -inf to 0.47648, saving model to best_model_224_res.h5
# 249/249 [==============================] - 91s 344ms/step - loss: -0.7548 - accuracy: 0.9328 - dice_coef: 0.7548 - specificity: 0.9487 - sensitivity: 0.9103 - precision: 0.8703 - val_loss: -0.4765 - val_accuracy: 0.8003 - val_dice_coef: 0.4765 - val_specificity: 0.9975 - val_sensitivity: 0.3424 - val_precision: 0.9864
# Epoch 2/100
# 249/249 [==============================] - ETA: 0s - loss: -0.8634 - accuracy: 0.9748 - dice_coef: 0.8634 - specificity: 0.9802 - sensitivity: 0.9783 - precision: 0.9522
# Epoch 2: val_dice_coef improved from 0.47648 to 0.87635, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 341ms/step - loss: -0.8634 - accuracy: 0.9748 - dice_coef: 0.8634 - specificity: 0.9802 - sensitivity: 0.9783 - precision: 0.9522 - val_loss: -0.8763 - val_accuracy: 0.9729 - val_dice_coef: 0.8763 - val_specificity: 0.9788 - val_sensitivity: 0.9746 - val_precision: 0.9494
# Epoch 3/100
# 249/249 [==============================] - ETA: 0s - loss: -0.8942 - accuracy: 0.9782 - dice_coef: 0.8942 - specificity: 0.9845 - sensitivity: 0.9803 - precision: 0.9624
# Epoch 3: val_dice_coef improved from 0.87635 to 0.89928, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 340ms/step - loss: -0.8942 - accuracy: 0.9782 - dice_coef: 0.8942 - specificity: 0.9845 - sensitivity: 0.9803 - precision: 0.9624 - val_loss: -0.8993 - val_accuracy: 0.9783 - val_dice_coef: 0.8993 - val_specificity: 0.9835 - val_sensitivity: 0.9822 - val_precision: 0.9604
# Epoch 4/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9152 - accuracy: 0.9799 - dice_coef: 0.9152 - specificity: 0.9867 - sensitivity: 0.9812 - precision: 0.9678
# Epoch 4: val_dice_coef improved from 0.89928 to 0.91884, saving model to best_model_224_res.h5
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9152 - accuracy: 0.9799 - dice_coef: 0.9152 - specificity: 0.9867 - sensitivity: 0.9812 - precision: 0.9678 - val_loss: -0.9188 - val_accuracy: 0.9783 - val_dice_coef: 0.9188 - val_specificity: 0.9824 - val_sensitivity: 0.9854 - val_precision: 0.9583
# Epoch 5/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9300 - accuracy: 0.9807 - dice_coef: 0.9300 - specificity: 0.9880 - sensitivity: 0.9813 - precision: 0.9709
# Epoch 5: val_dice_coef improved from 0.91884 to 0.93016, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 341ms/step - loss: -0.9300 - accuracy: 0.9807 - dice_coef: 0.9300 - specificity: 0.9880 - sensitivity: 0.9813 - precision: 0.9709 - val_loss: -0.9302 - val_accuracy: 0.9783 - val_dice_coef: 0.9302 - val_specificity: 0.9829 - val_sensitivity: 0.9847 - val_precision: 0.9593
# Epoch 6/100
# 249/249 [==============================] - ETA: 0s - loss: -0.
100
# 249/249 [==============================] - ETA: 0s - loss: -0.9894 - accuracy: 0.9875 - dice_coef: 0.9894 - specificity: 0.9957 - sensitivity: 0.9902 - precision: 0.9899
# Epoch 36: val_dice_coef improved from 0.97925 to 0.97954, saving model to best_model_224_res.h5
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9894 - accuracy: 0.9875 - dice_coef: 0.9894 - specificity: 0.9957 - sensitivity: 0.9902 - precision: 0.9899 - val_loss: -0.9795 - val_accuracy: 0.9823 - val_dice_coef: 0.9795 - val_specificity: 0.9923 - val_sensitivity: 0.9788 - val_precision: 0.9812
# Epoch 37/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9899 - accuracy: 0.9877 - dice_coef: 0.9899 - specificity: 0.9960 - sensitivity: 0.9905 - precision: 0.9905
# Epoch 37: val_dice_coef improved from 0.97954 to 0.98059, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 343ms/step - loss: -0.9899 - accuracy: 0.9877 - dice_coef: 0.9899 - specificity: 0.9960 - sensitivity: 0.9905 - precision: 0.9905 - val_loss: -0.9806 - val_accuracy: 0.9828 - val_dice_coef: 0.9806 - val_specificity: 0.9905 - val_sensitivity: 0.9850 - val_precision: 0.9772
# Epoch 38/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9907 - accuracy: 0.9881 - dice_coef: 0.9907 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9912
# Epoch 38: val_dice_coef did not improve from 0.98059
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9907 - accuracy: 0.9881 - dice_coef: 0.9907 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9912 - val_loss: -0.9789 - val_accuracy: 0.9819 - val_dice_coef: 0.9789 - val_specificity: 0.9902 - val_sensitivity: 0.9822 - val_precision: 0.9764
# Epoch 39/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9906 - accuracy: 0.9880 - dice_coef: 0.9906 - specificity: 0.9962 - sensitivity: 0.9913 - precision: 0.9911
# Epoch 39: val_dice_coef did not improve from 0.98059
# 249/249 [==============================] - 83s 335ms/step - loss: -0.9906 - accuracy: 0.9880 - dice_coef: 0.9906 - specificity: 0.9962 - sensitivity: 0.9913 - precision: 0.9911 - val_loss: -0.9779 - val_accuracy: 0.9814 - val_dice_coef: 0.9779 - val_specificity: 0.9917 - val_sensitivity: 0.9766 - val_precision: 0.9799
# Epoch 40/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9908 - accuracy: 0.9881 - dice_coef: 0.9908 - specificity: 0.9963 - sensitivity: 0.9915 - precision: 0.9913
# Epoch 40: val_dice_coef did not improve from 0.98059
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9908 - accuracy: 0.9881 - dice_coef: 0.9908 - specificity: 0.9963 - sensitivity: 0.9915 - precision: 0.9913 - val_loss: -0.9780 - val_accuracy: 0.9814 - val_dice_coef: 0.9780 - val_specificity: 0.9919 - val_sensitivity: 0.9764 - val_precision: 0.9804
# Epoch 41/100
# 249/249 [==============================] - ETA: 0s - loss: -0.
100
# 249/249 [==============================] - ETA: 0s - loss: -0.9913 - accuracy: 0.9883 - dice_coef: 0.9913 - specificity: 0.9965 - sensitivity: 0.9920 - precision: 0.9917
# Epoch 47: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9913 - accuracy: 0.9883 - dice_coef: 0.9913 - specificity: 0.9965 - sensitivity: 0.9920 - precision: 0.9917 - val_loss: -0.9798 - val_accuracy: 0.9823 - val_dice_coef: 0.9798 - val_specificity: 0.9943 - val_sensitivity: 0.9742 - val_precision: 0.9860
# Epoch 48/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9916 - accuracy: 0.9884 - dice_coef: 0.9916 - specificity: 0.9967 - sensitivity: 0.9922 - precision: 0.9921
# Epoch 48: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 83s 335ms/step - loss: -0.9916 - accuracy: 0.9884 - dice_coef: 0.9916 - specificity: 0.9967 - sensitivity: 0.9922 - precision: 0.9921 - val_loss: -0.9786 - val_accuracy: 0.9817 - val_dice_coef: 0.9786 - val_specificity: 0.9932 - val_sensitivity: 0.9745 - val_precision: 0.9834
# Epoch 49/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9915 - accuracy: 0.9883 - dice_coef: 0.9915 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920
# Epoch 49: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 85s 340ms/step - loss: -0.9915 - accuracy: 0.9883 - dice_coef: 0.9915 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920 - val_loss: -0.9793 - val_accuracy: 0.9820 - val_dice_coef: 0.9793 - val_specificity: 0.9916 - val_sensitivity: 0.9795 - val_precision: 0.9797
# Epoch 50/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9887 - accuracy: 0.9869 - dice_coef: 0.9887 - specificity: 0.9955 - sensitivity: 0.9892 - precision: 0.9892
# Epoch 50: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 83s 334ms/step - loss: -0.9887 - accuracy: 0.9869 - dice_coef: 0.9887 - specificity: 0.9955 - sensitivity: 0.9892 - precision: 0.9892 - val_loss: -0.9701 - val_accuracy: 0.9767 - val_dice_coef: 0.9701 - val_specificity: 0.9836 - val_sensitivity: 0.9804 - val_precision: 0.9608
# Epoch 51/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9912 - accuracy: 0.9881 - dice_coef: 0.9912 - specificity: 0.9966 - sensitivity: 0.9917 - precision: 0.9918
# Epoch 51: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 83s 334ms/step - loss: -0.9912 - accuracy: 0.9881 - dice_coef: 0.9912 - specificity: 0.9966 - sensitivity: 0.9917 - precision: 0.9918 - val_loss: -0.9805 - val_accuracy: 0.9826 - val_dice_coef: 0.9805 - val_specificity: 0.9932 - val_sensitivity: 0.9784 - val_precision: 0.9834
# Epoch 52/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9933 - accuracy: 0.9890 - dice_coef: 0.9933 - specificity: 0.9975 - sensitivity: 0.9942 - precision: 0.9941
# Epoch 52: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9933 - accuracy: 0.9890 - dice_coef: 0.9933 - specificity: 0.9975 - sensitivity: 0.9942 - precision: 0.9941 - val_loss: -0.9808 - val_accuracy: 0.9828 - val_dice_coef: 0.9808 - val_specificity: 0.9929 - val_sensitivity: 0.9796 - val_precision: 0.9828
# Epoch 53/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9935 - accuracy: 0.9891 - dice_coef: 0.9935 - specificity: 0.9976 - sensitivity: 0.9944 - precision: 0.9943
# Epoch 53: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 83s 334ms/step - loss: -0.9935 - accuracy: 0.9891 - dice_coef: 0.9935 - specificity: 0.9976 - sensitivity: 0.9944 - precision: 0.9943 - val_loss: -0.9800 - val_accuracy: 0.9825 - val_dice_coef: 0.9800 - val_specificity: 0.9943 - val_sensitivity: 0.9747 - val_precision: 0.9861
# Epoch 54/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9928 - accuracy: 0.9888 - dice_coef: 0.9928 - specificity: 0.9972 - sensitivity: 0.9936 - precision: 0.9933
# Epoch 54: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 83s 335ms/step - loss: -0.9928 - accuracy: 0.9888 - dice_coef: 0.9928 - specificity: 0.9972 - sensitivity: 0.9936 - precision: 0.9933 - val_loss: -0.9806 - val_accuracy: 0.9828 - val_dice_coef: 0.9806 - val_specificity: 0.9941 - val_sensitivity: 0.9763 - val_precision: 0.9857
# Epoch 55/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9917 - accuracy: 0.9884 - dice_coef: 0.9917 - specificity: 0.9967 - sensitivity: 0.9923 - precision: 0.9922
# Epoch 55: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 83s 334ms/step - loss: -0.9917 - accuracy: 0.9884 - dice_coef: 0.9917 - specificity: 0.9967 - sensitivity: 0.9923 - precision: 0.9922 - val_loss: -0.9811 - val_accuracy: 0.9830 - val_dice_coef: 0.9811 - val_specificity: 0.9939 - val_sensitivity: 0.9777 - val_precision: 0.9851
# Epoch 56/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9917 - accuracy: 0.9884 - dice_coef: 0.9917 - specificity: 0.9967 - sensitivity: 0.9923 - precision: 0.9922
# Epoch 56: val_dice_coef did not improve from 0.98109
# 249/249 [==============================] - 85s 341ms/step - loss: -0.9917 - accuracy: 0.9884 - dice_coef: 0.9917 - specificity: 0.9967 - sensitivity: 0.9923 - precision: 0.9922 - val_loss: -0.9807 - val_accuracy: 0.9828 - val_dice_coef: 0.9807 - val_specificity: 0.9918 - val_sensitivity: 0.9818 - val_precision: 0.9803
# Epoch 57/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9919 - accuracy: 0.9885 - dice_coef: 0.9919 - specificity: 0.9968 - sensitivity: 0.9925 - precision: 0.9925
# Epoch 57: val_dice_coef improved from 0.98109 to 0.98123, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 341ms/step - loss: -0.9919 - accuracy: 0.9885 - dice_coef: 0.9919 - specificity: 0.9968 - sensitivity: 0.9925 - precision: 0.9925 - val_loss: -0.9812 - val_accuracy: 0.9830 - val_dice_coef: 0.9812 - val_specificity: 0.9913 - val_sensitivity: 0.9840 - val_precision: 0.9792
# Epoch 58/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9930
# Epoch 58: val_dice_coef did not improve from 0.98123
# 249/249 [==============================] - 83s 335ms/step - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9930 - val_loss: -0.9810 - val_accuracy: 0.9829 - val_dice_coef: 0.9810 - val_specificity: 0.9927 - val_sensitivity: 0.9803 - val_precision: 0.9824
# Epoch 59/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9929
# Epoch 59: val_dice_coef did not improve from 0.98123
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9929 - val_loss: -0.9803 - val_accuracy: 0.9825 - val_dice_coef: 0.9803 - val_specificity: 0.9926 - val_sensitivity: 0.9791 - val_precision: 0.9821
# Epoch 60/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9930
# Epoch 60: val_dice_coef did not improve from 0.98123
# 249/249 [==============================] - 83s 334ms/step - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9930 - val_loss: -0.9810 - val_accuracy: 0.9828 - val_dice_coef: 0.9810 - val_specificity: 0.9913 - val_sensitivity: 0.9837 - val_precision: 0.9790
# Epoch 61/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9971 - sensitivity: 0.9931 - precision: 0.9930
# Epoch 61: val_dice_coef did not improve from 0.98123
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9971 - sensitivity: 0.9931 - precision: 0.9930 - val_loss: -0.9802 - val_accuracy: 0.9824 - val_dice_coef: 0.9802 - val_specificity: 0.9907 - val_sensitivity: 0.9833 - val_precision: 0.9778
# Epoch 62/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9926 - accuracy: 0.9888 - dice_coef: 0.9926 - specificity: 0.9971 - sensitivity: 0.9933 - precision: 0.9932
# Epoch 62: val_dice_coef did not improve from 0.98123
# 249/249 [==============================] - 83s 335ms/step - loss: -0.9926 - accuracy: 0.9888 - dice_coef: 0.9926 - specificity: 0.9971 - sensitivity: 0.9933 - precision: 0.9932 - val_loss: -0.9806 - val_accuracy: 0.9826 - val_dice_coef: 0.9806 - val_specificity: 0.9928 - val_sensitivity: 0.9794 - val_precision: 0.9825
# Epoch 63/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9927 - accuracy: 0.9888 - dice_coef: 0.9927 - specificity: 0.9972 - sensitivity: 0.9935 - precision: 0.9934
# Epoch 63: val_dice_coef did not improve from 0.98123
# 249/249 [==============================] - 85s 341ms/step - loss: -0.9927 - accuracy: 0.9888 - dice_coef: 0.9927 - specificity: 0.9972 - sensitivity: 0.9935 - precision: 0.9934 - val_loss: -0.9796 - val_accuracy: 0.9822 - val_dice_coef: 0.9796 - val_specificity: 0.9930 - val_sensitivity: 0.9770 - val_precision: 0.9829
# Epoch 64/100
# 111/249 [============>.................] - ETA: 41s - loss: -0.9931 - accuracy: 0.9890 - dice_coef: 0.9931 - specificity: 0.9974 - sensitivity: 0.9939 - precision: 0.9938

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['specificity'], 'b', label='train specificity')
acc_ax.plot(results.history['val_specificity'], 'g', label='val specificity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['sensitivity'], 'b', label='train sensitivity')
acc_ax.plot(results.history['val_sensitivity'], 'g', label='val sensitivity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['precision'], 'b', label='train precision')
acc_ax.plot(results.history['val_precision'], 'g', label='val precision')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print(results.history['precision'][-1])

# %%
print(results.history['dice_coef'][-1])

# %%
print(results.history['specificity'][-1])

# %% [markdown]
# testing values

# %%
# import os
test_list = os.listdir("test_set/")
print("The number of test data : ", len(test_list))
test_list[:5]
# Out:
# The number of test data :  335
# ['001_HC.png', '000_HC.png', '003_HC.png', '004_HC.png', '002_HC.png']

# %%
#used just for prediction, not as a checkpoint
model = tf.keras.models.load_model('best_model_224_res.h5', compile=False)

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
for i, item in enumerate(test_list):
    image = cv2.imread("test_set/" + item, 0)
    image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    X_test[i] = image
X_test = X_test[:,:,:,np.newaxis] / 255

y_pred = model.predict(X_test)
# Out:
# 11/11 [==============================] - 12s 198ms/step

# %%
def getbound(binary_mask):

  # draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  # draw[img > 0.5] = (255,) * 3
  kernelSize = (3,3)

  gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(binary_mask, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  # gradient = cv2.cvtColor(gradient, cv2.COLOR_GRAY2RGB)
  return gradient


def fitEllipse(binary_mask, method="Direct"):
    assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0

    # print(binary_mask.shape)
   
    gradient  = getbound(binary_mask)

    # print(gradient.shape)

    points1 = np.argwhere(gradient > 0.5)  
    points2 = np.argwhere(binary_mask > 0.5)  

    points = points1
    # print(points1.shape)
    # print(points2.shape)

    if method == "AMS":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
    elif method == "Direct":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
    elif method == "Simple":
        (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

    return (xx, yy), (MA, ma), angle


# img = pred.copy()
# (xx, yy), (MA, ma), angle = fitEllipse(img)
# print((xx, yy), (MA, ma), angle)

# draw = np.zeros((*img.shape, 3), dtype=np.uint8)

# draw[img > 0.5] = (255,) * 3

# cv2.ellipse(
#     draw,
#     (int(yy), int(xx)),
#     (int(ma / 2), int(MA / 2)),
#     -angle,
#     0,
#     360,
#     color=(255, 0, 0),
#     thickness=2,
# )

for test, pred in zip(X_test[180:190],y_pred[180:190]):
    fig, ax = plt.subplots(1,4,figsize = (16,16))
    test = test.reshape((IMG_HEIGHT,IMG_WIDTH))

    pred = pred.reshape((IMG_HEIGHT,IMG_WIDTH))



    img = pred.copy()
    (xx, yy), (MA, ma), angle = fitEllipse(img)
    print((xx, yy), (MA, ma), angle)

    draw = np.zeros((*img.shape, 3), dtype=np.uint8)

    draw[img < 0.5] = (255,) * 3

    cv2.ellipse(
        draw,
        (int(yy), int(xx)),
        (int(ma / 2), int(MA / 2)),
        -angle,
        0,
        360,
        color=(255, 0, 0),
        thickness=2,
    )
    
    pred = pred>0.5
    pred = np.ma.masked_where(pred == 0, pred)

    ax[0].imshow(test, cmap = 'gray')

    ax[1].imshow(pred, cmap = 'gray')

    ax[2].imshow(test, cmap = 'gray', interpolation = 'none')
    ax[2].imshow(pred, cmap = 'jet', interpolation = 'none', alpha = 0.7)
    ax[3].imshow(draw,cmap='jet')
# Out:
# (107.82980346679688, 108.90900421142578) (152.9547119140625, 185.180908203125) 85.06382751464844
# (114.63394165039062, 133.82025146484375) (54.4749870300293, 87.90869903564453) 81.57330322265625
# (104.85633850097656, 83.32151794433594) (98.02146911621094, 140.27784729003906) 77.7124252319336
# (116.03387451171875, 100.03182983398438) (165.7427520751953, 188.51243591308594) 86.82600402832031
# (113.14583587646484, 112.02924346923828) (123.79280853271484, 147.3717041015625) 87.15340423583984
# (106.63650512695312, 118.68380737304688) (62.36629867553711, 105.90763092041016) 93.65827178955078
# (126.43470001220703, 117.11428833007812) (95.62138366699219, 113.37725830078125) 75.3254165649414
# (111.00895690917969, 108.36187744140625) (92.1311264038086, 133.17767333984375) 97.69041442871094
# (121.73214721679688, 116.49618530273438) (161.02685546875, 195.5316619873047) 86.36371612548828
# (93.7846450805664, 98.96853637695312) (115.42121124267578, 134.83334350585938) 76.89474487304688

# %%
#ellipse fitting is performed on below displayed figure


def getbound(img):
  draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  draw[img > 0.5] = (255,) * 3

  kernelSize = (3,3)
  gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(draw, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  return gradient

# def fitEllipse(binary_mask, method="Direct"):
#     assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0
#     points = np.argwhere(binary_mask > 0.5)  

#     if method == "AMS":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
#     elif method == "Direct":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
#     elif method == "Simple":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

#     return (xx, yy), (MA, ma), angle


# # img = np.load("./output_samples/3.npy")
img = pred.copy()
# (xx, yy), (MA, ma), angle = fitEllipse(img)
# print((xx, yy), (MA, ma), angle)

draw = np.zeros((*img.shape, 3), dtype=np.uint8)

draw[img > 0.5] = (255,) * 3

# cv2.ellipse(
#     draw,
#     (int(yy), int(xx)),
#     (int(ma / 2), int(MA / 2)),
#     -angle,
#     0,
#     360,
#     color=(255, 0, 0),
#     thickness=2,
# )
gradient = getbound(img)
plt.imshow(gradient)
plt.show()

# %%
#get dice coefficent for test set
