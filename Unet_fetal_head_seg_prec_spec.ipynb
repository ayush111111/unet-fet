# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush111111/unet-fet/blob/main/Unet_fetal_head_seg_prec_spec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/'Semester Project '/dataset/
# %ls
# Out:
# /content/drive/MyDrive/Semester Project /dataset
# best_model_224_res.h5  test_set/  training_set/

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
trainPath = "training_set/"
testPath = "test_set/"
trainList = sorted(os.listdir(trainPath))
testList = sorted(os.listdir(testPath))


train_image = []
train_mask = []
for i, item in enumerate(trainList):
    if i % 2 == 0:
        train_image.append(item)
    else:
        train_mask.append(item)
print("Ultrasound training images in dataset {}".format(len(train_image)))
print("Ultrasound training masks in dataset  {}".format(len(train_mask)))
# Out:
# Ultrasound training images in dataset 999
# Ultrasound training masks in dataset  999

# %%
img = np.array(Image.open(trainPath+"000_HC.png"))
img_mask = np.array(Image.open(trainPath+"000_HC_Annotation.png"))
print(len(img[0]))
#display images with mask
fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(img, cmap = 'gray')
ax[1].imshow(img_mask, cmap = 'gray')
ax[2].imshow(img, cmap = 'gray', interpolation = 'none')
ax[2].imshow(img_mask, cmap = 'gray', interpolation = 'none', alpha = 0.7)
# Out:
# 800

# %%
#
X = []
y = []
for image, mask in zip(train_image, train_mask):
    X.append(np.array(Image.open(trainPath+image)))
    y.append(np.array(Image.open(trainPath+mask)))

X = np.array(X)
y = np.array(y)

print("X_shape : ", X.shape)
print("y_shape : ", y.shape)
# Out:
# X_shape :  (999,)
# y_shape :  (999,)
# <ipython-input-6-5829c98f866b>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# <ipython-input-6-5829c98f866b>:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y = np.array(y)

# %%
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split

import tensorflow.keras
import tensorflow as tf
from tensorflow.keras import backend as K

K.set_image_data_format('channels_last')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Add
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
def Generator(X_list, y_list, batch_size = 16):
    c = 0

    while(True):
        X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            image = X_list[i]
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            mask =  y_list[i]
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            X[i - c] = image
            y[i - c] = mask
        
        X = X[:,:,:,np.newaxis] / 255
        y = y[:,:,:,np.newaxis] / 255
        
        c += batch_size
        if(c+batch_size >= len(X_list)):
            c = 0
        yield X, y

# %%
train_img_aug = []
train_mask_aug = []


for img, mask in zip(train_image, train_mask):
    img = cv2.imread(trainPath + img)
    mask = cv2.imread(trainPath + mask)
    train_img_aug.append(img)
    
    train_mask_aug.append(mask)
    img_lr = np.fliplr(img)
    mask_lr = np.fliplr(mask)

    img_up = np.flipud(img)
    mask_up = np.flipud(mask)

    img_lr_up = np.flipud(img_lr)
    mask_lr_up = np.flipud(mask_lr)

    img_up_lr = np.fliplr(img_up)
    mask_up_lr = np.fliplr(mask_up)

    train_img_aug.append(img_lr)
    train_mask_aug.append(mask_lr)

    train_img_aug.append(img_up)
    train_mask_aug.append(mask_up)

    train_img_aug.append(img_lr_up)
    train_mask_aug.append(mask_lr_up)

    train_img_aug.append(img_up_lr)
    train_mask_aug.append(mask_up_lr)

print(len(train_image))
print(len(train_img_aug))
# Out:
# 999
# 4995

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
# define building blocks
def BatchnormActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_block(x, filters, size, strides=(1,1), padding="same", activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchnormActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchnormActivate(blockInput)
    x = conv_block(x, num_filters, (3,3))
    x = conv_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchnormActivate(x)
    return x

# %%
def build_Unet(input_layer, start_neurons, DropoutRatio = 0.5):
    

    """ Encoder """
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)


    """ Bridge """
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)



    """ Decoder """
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    """ Output """
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

# %%
#split training data
X_train, X_val, y_train, y_val = train_test_split(train_img_aug, train_mask_aug, test_size = 0.3, random_state = 1)

# set training parameters
epochs = 100
batch_size = 16
steps_per_epoch = int(len(X_train) / batch_size)
validation_steps = int(len(X_val) / batch_size)

train_gen = Generator(X_train, y_train, batch_size = batch_size)
val_gen = Generator(X_val, y_val, batch_size = batch_size)

# initialize our model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, 1))
output_layer = build_Unet(inputs, 16, 0.5)

# Define callbacks to save model with best val_dice_coef
checkpointer = ModelCheckpoint(filepath = 'best_model_224_res.h5', monitor='val_dice_coef', verbose=1, save_best_only=True, mode='max')
model = Model(inputs=[inputs], outputs=[output_layer])
model.compile(optimizer=Adam(lr = 3e-5), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d_255 (Conv2D)            (None, 224, 224, 16  160         ['input_7[0][0]']
#                                 )
#
#  batch_normalization_250 (Batch  (None, 224, 224, 16  64         ['conv2d_255[0][0]']
#  Normalization)                 )
#
#  activation_250 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_250[0][0]']
#                                 )
#
#  conv2d_256 (Conv2D)            (None, 224, 224, 16  2320        ['activation_250[0][0]']
#                                 )
#
#  batch_normalization_251 (Batch  (None, 224, 224, 16  64         ['conv2d_256[0][0]']
#  Normalization)                 )
#
#  activation_251 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_251[0][0]']
#                                 )
#
#  conv2d_257 (Conv2D)            (None, 224, 224, 16  2320        ['activation_251[0][0]']
#                                 )
#
#  add_100 (Add)                  (None, 224, 224, 16  0           ['conv2d_257[0][0]',
#                                 )                                 'conv2d_255[0][0]']
#
#  batch_normalization_252 (Batch  (None, 224, 224, 16  64         ['add_100[0][0]']
#  Normalization)                 )
#
#  activation_252 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_252[0][0]']
#                                 )
#
#  conv2d_258 (Conv2D)            (None, 224, 224, 16  2320        ['activation_252[0][0]']
#                                 )
#
#  batch_normalization_253 (Batch  (None, 224, 224, 16  64         ['conv2d_258[0][0]']
#  Normalization)                 )
#
#  activation_253 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_253[0][0]']
#                                 )
#
#  conv2d_259 (Conv2D)            (None, 224, 224, 16  2320        ['activation_253[0][0]']
#                                 )
#
#  add_101 (Add)                  (None, 224, 224, 16  0           ['conv2d_259[0][0]',
#                                 )                                 'add_100[0][0]']
#
#  batch_normalization_254 (Batch  (None, 224, 224, 16  64         ['add_101[0][0]']
#  Normalization)                 )
#
#  activation_254 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_254[0][0]']
#                                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 112, 112, 16  0          ['activation_254[0][0]']
#  )                              )
#
#  dropout_34 (Dropout)           (None, 112, 112, 16  0           ['max_pooling2d_24[0][0]']
#                                 )
#
#  conv2d_260 (Conv2D)            (None, 112, 112, 32  4640        ['dropout_34[0][0]']
#                                 )
#
#  batch_normalization_255 (Batch  (None, 112, 112, 32  128        ['conv2d_260[0][0]']
#  Normalization)                 )
#
#  activation_255 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_255[0][0]']
#                                 )
#
#  conv2d_261 (Conv2D)            (None, 112, 112, 32  9248        ['activation_255[0][0]']
#                                 )
#
#  batch_normalization_256 (Batch  (None, 112, 112, 32  128        ['conv2d_261[0][0]']
#  Normalization)                 )
#
#  activation_256 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_256[0][0]']
#                                 )
#
#  conv2d_262 (Conv2D)            (None, 112, 112, 32  9248        ['activation_256[0][0]']
#                                 )
#
#  add_102 (Add)                  (None, 112, 112, 32  0           ['conv2d_262[0][0]',
#                                 )                                 'conv2d_260[0][0]']
#
#  batch_normalization_257 (Batch  (None, 112, 112, 32  128        ['add_102[0][0]']
#  Normalization)                 )
#
#  activation_257 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_257[0][0]']
#                                 )
#
#  conv2d_263 (Conv2D)            (None, 112, 112, 32  9248        ['activation_257[0][0]']
#                                 )
#
#  batch_normalization_258 (Batch  (None, 112, 112, 32  128        ['conv2d_263[0][0]']
#  Normalization)                 )
#
#  activation_258 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_258[0][0]']
#                                 )
#
#  conv2d_264 (Conv2D)            (None, 112, 112, 32  9248        ['activation_258[0][0]']
#                                 )
#
#  add_103 (Add)                  (None, 112, 112, 32  0           ['conv2d_264[0][0]',
#                                 )                                 'add_102[0][0]']
#
#  batch_normalization_259 (Batch  (None, 112, 112, 32  128        ['add_103[0][0]']
#  Normalization)                 )
#
#  activation_259 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_259[0][0]']
#                                 )
#
#  max_pooling2d_25 (MaxPooling2D  (None, 56, 56, 32)  0           ['activation_259[0][0]']
#  )
#
#  dropout_35 (Dropout)           (None, 56, 56, 32)   0           ['max_pooling2d_25[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 56, 56, 64)   18496       ['dropout_35[0][0]']
#
#  batch_normalization_260 (Batch  (None, 56, 56, 64)  256         ['conv2d_265[0][0]']
#  Normalization)
#
#  activation_260 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_260[0][0]']
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
#  conv2d_266 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_260[0][0]']
#
#  batch_normalization_261 (Batch  (None, 56, 56, 64)  256         ['conv2d_266[0][0]']
#  Normalization)
#
#  activation_261 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_261[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_261[0][0]']
#
#  add_104 (Add)                  (None, 56, 56, 64)   0           ['conv2d_267[0][0]',
#                                                                   'conv2d_265[0][0]']
#
#  batch_normalization_262 (Batch  (None, 56, 56, 64)  256         ['add_104[0][0]']
#  Normalization)
#
#  activation_262 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_262[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_262[0][0]']
#
#  batch_normalization_263 (Batch  (None, 56, 56, 64)  256         ['conv2d_268[0][0]']
#  Normalization)
#
#  activation_263 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_263[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_263[0][0]']
#
#  add_105 (Add)                  (None, 56, 56, 64)   0           ['conv2d_269[0][0]',
#                                                                   'add_104[0][0]']
#
#  batch_normalization_264 (Batch  (None, 56, 56, 64)  256         ['add_105[0][0]']
#  Normalization)
#
#  activation_264 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_264[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 28, 28, 64)  0           ['activation_264[0][0]']
#  )
#
#  dropout_36 (Dropout)           (None, 28, 28, 64)   0           ['max_pooling2d_26[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 28, 28, 128)  73856       ['dropout_36[0][0]']
#
#  batch_normalization_265 (Batch  (None, 28, 28, 128)  512        ['conv2d_270[0][0]']
#  Normalization)
#
#  activation_265 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_265[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_265[0][0]']
#
#  batch_normalization_266 (Batch  (None, 28, 28, 128)  512        ['conv2d_271[0][0]']
#  Normalization)
#
#  activation_266 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_266[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_266[0][0]']
#
#  add_106 (Add)                  (None, 28, 28, 128)  0           ['conv2d_272[0][0]',
#                                                                   'conv2d_270[0][0]']
#
#  batch_normalization_267 (Batch  (None, 28, 28, 128)  512        ['add_106[0][0]']
#  Normalization)
#
#  activation_267 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_267[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_267[0][0]']
#
#  batch_normalization_268 (Batch  (None, 28, 28, 128)  512        ['conv2d_273[0][0]']
#  Normalization)
#
#  activation_268 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_268[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_268[0][0]']
#
#  add_107 (Add)                  (None, 28, 28, 128)  0           ['conv2d_274[0][0]',
#                                                                   'add_106[0][0]']
#
#  batch_normalization_269 (Batch  (None, 28, 28, 128)  512        ['add_107[0][0]']
#  Normalization)
#
#  activation_269 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_269[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 14, 14, 128)  0          ['activation_269[0][0]']
#  )
#
#  dropout_37 (Dropout)           (None, 14, 14, 128)  0           ['max_pooling2d_27[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 14, 14, 256)  295168      ['dropout_37[0][0]']
#
#  batch_normalization_270 (Batch  (None, 14, 14, 256)  1024       ['conv2d_275[0][0]']
#  Normalization)
#
#  activation_270 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_270[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_270[0][0]']
#
#  batch_normalization_271 (Batch  (None, 14, 14, 256)  1024       ['conv2d_276[0][0]']
#  Normalization)
#
#  activation_271 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_271[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_271[0][0]']
#
#  add_108 (Add)                  (None, 14, 14, 256)  0           ['conv2d_277[0][0]',
#                                                                   'conv2d_275[0][0]']
#
#  batch_normalization_272 (Batch  (None, 14, 14, 256)  1024       ['add_108[0][0]']
#  Normalization)
#
#  activation_272 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_272[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_272[0][0]']
#
#  batch_normalization_273 (Batch  (None, 14, 14, 256)  1024       ['conv2d_278[0][0]']
#  Normalization)
#
#  activation_273 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_273[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_273[0][0]']
#
#  add_109 (Add)                  (None, 14, 14, 256)  0           ['conv2d_279[0][0]',
#                                                                   'add_108[0][0]']
#
#  batch_normalization_274 (Batch  (None, 14, 14, 256)  1024       ['add_109[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_274[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 28, 28, 128)  295040     ['activation_274[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 28, 28, 256)  0           ['conv2d_transpose_21[0][0]',
#                                                                   'activation_269[0][0]']
#
#  dropout_38 (Dropout)           (None, 28, 28, 256)  0           ['concatenate_21[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 28, 28, 128)  295040      ['dropout_38[0][0]']
#
#  batch_normalization_275 (Batch  (None, 28, 28, 128)  512        ['conv2d_280[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_275[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_275[0][0]']
#
#  batch_normalization_276 (Batch  (None, 28, 28, 128)  512        ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_276 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_276[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_276[0][0]']
#
#  add_110 (Add)                  (None, 28, 28, 128)  0           ['conv2d_282[0][0]',
#                                                                   'conv2d_280[0][0]']
#
#  batch_normalization_277 (Batch  (None, 28, 28, 128)  512        ['add_110[0][0]']
#  Normalization)
#
#  activation_277 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_277[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_277[0][0]']
#
#  batch_normalization_278 (Batch  (None, 28, 28, 128)  512        ['conv2d_283[0][0]']
#  Normalization)
#
#  activation_278 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_278[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_278[0][0]']
#
#  add_111 (Add)                  (None, 28, 28, 128)  0           ['conv2d_284[0][0]',
#                                                                   'add_110[0][0]']
#
#  batch_normalization_279 (Batch  (None, 28, 28, 128)  512        ['add_111[0][0]']
#  Normalization)
#
#  activation_279 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_279[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 56, 56, 64)  73792       ['activation_279[0][0]']
#  nspose)
#
#  concatenate_22 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_transpose_22[0][0]',
#                                                                   'activation_264[0][0]']
#
#  dropout_39 (Dropout)           (None, 56, 56, 128)  0           ['concatenate_22[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 56, 56, 64)   73792       ['dropout_39[0][0]']
#
#  batch_normalization_280 (Batch  (None, 56, 56, 64)  256         ['conv2d_285[0][0]']
#  Normalization)
#
#  activation_280 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_280[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_280[0][0]']
#
#  batch_normalization_281 (Batch  (None, 56, 56, 64)  256         ['conv2d_286[0][0]']
#  Normalization)
#
#  activation_281 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_281[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_281[0][0]']
#
#  add_112 (Add)                  (None, 56, 56, 64)   0           ['conv2d_287[0][0]',
#                                                                   'conv2d_285[0][0]']
#
#  batch_normalization_282 (Batch  (None, 56, 56, 64)  256         ['add_112[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_282[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_282[0][0]']
#
#  batch_normalization_283 (Batch  (None, 56, 56, 64)  256         ['conv2d_288[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_283[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_283[0][0]']
#
#  add_113 (Add)                  (None, 56, 56, 64)   0           ['conv2d_289[0][0]',
#                                                                   'add_112[0][0]']
#
#  batch_normalization_284 (Batch  (None, 56, 56, 64)  256         ['add_113[0][0]']
#  Normalization)
#
#  activation_284 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_284[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 112, 112, 32  18464      ['activation_284[0][0]']
#  nspose)                        )
#
#  concatenate_23 (Concatenate)   (None, 112, 112, 64  0           ['conv2d_transpose_23[0][0]',
#                                 )                                 'activation_259[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 112, 112, 32  18464       ['concatenate_23[0][0]']
#                                 )
#
#  batch_normalization_285 (Batch  (None, 112, 112, 32  128        ['conv2d_290[0][0]']
#  Normalization)                 )
#
#  activation_285 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_285[0][0]']
#                                 )
#
#  conv2d_291 (Conv2D)            (None, 112, 112, 32  9248        ['activation_285[0][0]']
#                                 )
#
#  batch_normalization_286 (Batch  (None, 112, 112, 32  128        ['conv2d_291[0][0]']
#  Normalization)                 )
#
#  activation_286 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_286[0][0]']
#                                 )
#
#  conv2d_292 (Conv2D)            (None, 112, 112, 32  9248        ['activation_286[0][0]']
#                                 )
#
#  add_114 (Add)                  (None, 112, 112, 32  0           ['conv2d_292[0][0]',
#                                 )                                 'conv2d_290[0][0]']
#
#  batch_normalization_287 (Batch  (None, 112, 112, 32  128        ['add_114[0][0]']
#  Normalization)                 )
#
#  activation_287 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_287[0][0]']
#                                 )
#
#  conv2d_293 (Conv2D)            (None, 112, 112, 32  9248        ['activation_287[0][0]']
#                                 )
#
#  batch_normalization_288 (Batch  (None, 112, 112, 32  128        ['conv2d_293[0][0]']
#  Normalization)                 )
#
#  activation_288 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_288[0][0]']
#                                 )
#
#  conv2d_294 (Conv2D)            (None, 112, 112, 32  9248        ['activation_288[0][0]']
#                                 )
#
#  add_115 (Add)                  (None, 112, 112, 32  0           ['conv2d_294[0][0]',
#                                 )                                 'add_114[0][0]']
#
#  batch_normalization_289 (Batch  (None, 112, 112, 32  128        ['add_115[0][0]']
#  Normalization)                 )
#
#  activation_289 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_289[0][0]']
#                                 )
#
#  conv2d_transpose_24 (Conv2DTra  (None, 224, 224, 16  4624       ['activation_289[0][0]']
#  nspose)                        )
#
#  concatenate_24 (Concatenate)   (None, 224, 224, 32  0           ['conv2d_transpose_24[0][0]',
#                                 )                                 'activation_254[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 224, 224, 16  4624        ['concatenate_24[0][0]']
#                                 )
#
#  batch_normalization_290 (Batch  (None, 224, 224, 16  64         ['conv2d_295[0][0]']
#  Normalization)                 )
#
#  activation_290 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_290[0][0]']
#                                 )
#
#  conv2d_296 (Conv2D)            (None, 224, 224, 16  2320        ['activation_290[0][0]']
#                                 )
#
#  batch_normalization_291 (Batch  (None, 224, 224, 16  64         ['conv2d_296[0][0]']
#  Normalization)                 )
#
#  activation_291 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_291[0][0]']
#                                 )
#
#  conv2d_297 (Conv2D)            (None, 224, 224, 16  2320        ['activation_291[0][0]']
#                                 )
#
#  add_116 (Add)                  (None, 224, 224, 16  0           ['conv2d_297[0][0]',
#                                 )                                 'conv2d_295[0][0]']
#
#  batch_normalization_292 (Batch  (None, 224, 224, 16  64         ['add_116[0][0]']
#  Normalization)                 )
#
#  activation_292 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_292[0][0]']
#                                 )
#
#  conv2d_298 (Conv2D)            (None, 224, 224, 16  2320        ['activation_292[0][0]']
#                                 )
#
#  batch_normalization_293 (Batch  (None, 224, 224, 16  64         ['conv2d_298[0][0]']
#  Normalization)                 )
#
#  activation_293 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_293[0][0]']
#                                 )
#
#  conv2d_299 (Conv2D)            (None, 224, 224, 16  2320        ['activation_293[0][0]']
#                                 )
#
#  add_117 (Add)                  (None, 224, 224, 16  0           ['conv2d_299[0][0]',
#                                 )                                 'add_116[0][0]']
#
#  batch_normalization_294 (Batch  (None, 224, 224, 16  64         ['add_117[0][0]']
#  Normalization)                 )
#
#  activation_294 (Activation)    (None, 224, 224, 16  0           ['batch_normalization_294[0][0]']
#                                 )
#
#  conv2d_300 (Conv2D)            (None, 224, 224, 1)  17          ['activation_294[0][0]']
#
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# Out:
# Epoch 1/100
# <ipython-input-42-350936afeb50>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# 218/218 [==============================] - ETA: 0s - loss: -0.0241 - accuracy: 0.6537 - dice_coef: 0.0241 - specificity: 0.6599 - sensitivity: 0.5715 - precision: 0.0135
# Epoch 1: val_dice_coef improved from -inf to 0.01594, saving model to best_model_224_res.h5
# 218/218 [==============================] - 94s 362ms/step - loss: -0.0241 - accuracy: 0.6537 - dice_coef: 0.0241 - specificity: 0.6599 - sensitivity: 0.5715 - precision: 0.0135 - val_loss: -0.0159 - val_accuracy: 0.9655 - val_dice_coef: 0.0159 - val_specificity: 0.9766 - val_sensitivity: 0.0143 - val_precision: 0.0055
# Epoch 2/100
# 218/218 [==============================] - ETA: 0s - loss: -0.0328 - accuracy: 0.8004 - dice_coef: 0.0328 - specificity: 0.8079 - sensitivity: 0.7063 - precision: 0.0277
# Epoch 2: val_dice_coef improved from 0.01594 to 0.02023, saving model to best_model_224_res.h5
# 218/218 [==============================] - 78s 358ms/step - loss: -0.0328 - accuracy: 0.8004 - dice_coef: 0.0328 - specificity: 0.8079 - sensitivity: 0.7063 - precision: 0.0277 - val_loss: -0.0202 - val_accuracy: 0.3827 - val_dice_coef: 0.0202 - val_specificity: 0.3858 - val_sensitivity: 0.9408 - val_precision: 0.0112
# Epoch 3/100
# 218/218 [==============================] - ETA: 0s - loss: -0.0415 - accuracy: 0.8588 - dice_coef: 0.0415 - specificity: 0.8662 - sensitivity: 0.8145 - precision: 0.0440
# Epoch 3: val_dice_coef improved from 0.02023 to 0.04297, saving model to best_model_224_res.h5
# 218/218 [==============================] - 80s
saving model to best_model_224_res.h5
# 218/218 [==============================] - 81s 370ms/step - loss: -0.3397 - accuracy: 0.9738 - dice_coef: 0.3397 - specificity: 0.9862 - sensitivity: 0.5911 - precision: 0.2432 - val_loss: -0.2848 - val_accuracy: 0.9727 - val_dice_coef: 0.2848 - val_specificity: 0.9857 - val_sensitivity: 0.4885 - val_precision: 0.2027
# Epoch 96/100
# 218/218 [==============================] - ETA: 0s - loss: -0.3396 - accuracy: 0.9738 - dice_coef: 0.3396 - specificity: 0.9862 - sensitivity: 0.5902 - precision: 0.2432
# Epoch 96: val_dice_coef improved from 0.28481 to 0.28517, saving model to best_model_224_res.h5
# 218/218 [==============================] - 81s 370ms/step - loss: -0.3396 - accuracy: 0.9738 - dice_coef: 0.3396 - specificity: 0.9862 - sensitivity: 0.5902 - precision: 0.2432 - val_loss: -0.2852 - val_accuracy: 0.9727 - val_dice_coef: 0.2852 - val_specificity: 0.9857 - val_sensitivity: 0.4902 - val_precision: 0.2025
# Epoch 97/100
# 218/218 [==============================] - ETA: 0s - loss: -0.3416 - accuracy: 0.9740 - dice_coef: 0.3416 - specificity: 0.9865 - sensitivity: 0.5877 - precision: 0.2458
# Epoch 97: val_dice_coef did not improve from 0.28517
# 218/218 [==============================] - 80s 368ms/step - loss: -0.3416 - accuracy: 0.9740 - dice_coef: 0.3416 - specificity: 0.9865 - sensitivity: 0.5877 - precision: 0.2458 - val_loss: -0.2830 - val_accuracy: 0.9730 - val_dice_coef: 0.2830 - val_specificity: 0.9862 - val_sensitivity: 0.4749 - val_precision: 0.2033
# Epoch 98/100
# 218/218 [==============================] - ETA: 0s - loss: -0.3422 - accuracy: 0.9739 - dice_coef: 0.3422 - specificity: 0.9864 - sensitivity: 0.5914 - precision: 0.2459
# Epoch 98: val_dice_coef did not improve from 0.28517
# 218/218 [==============================] - 79s 364ms/step - loss: -0.3422 - accuracy: 0.9739 - dice_coef: 0.3422 - specificity: 0.9864 - sensitivity: 0.5914 - precision: 0.2459 - val_loss: -0.2712 - val_accuracy: 0.9726 - val_dice_coef: 0.2712 - val_specificity: 0.9859 - val_sensitivity: 0.4560 - val_precision: 0.1933
# Epoch 99/100
# 218/218 [==============================] - ETA: 0s - loss: -0.3430 - accuracy: 0.9740 - dice_coef: 0.3430 - specificity: 0.9865 - sensitivity: 0.5892 - precision: 0.2467
# Epoch 99: val_dice_coef did not improve from 0.28517
# 218/218 [==============================] - 79s 363ms/step - loss: -0.3430 - accuracy: 0.9740 - dice_coef: 0.3430 - specificity: 0.9865 - sensitivity: 0.5892 - precision: 0.2467 - val_loss: -0.2710 - val_accuracy: 0.9720 - val_dice_coef: 0.2710 - val_specificity: 0.9852 - val_sensitivity: 0.4717 - val_precision: 0.1909
# Epoch 100/100
# 218/218 [==============================] - ETA: 0s - loss: -0.3457 - accuracy: 0.9741 - dice_coef: 0.3457 - specificity: 0.9866 - sensitivity: 0.5916 - precision: 0.2492
# Epoch 100: val_dice_coef improved from 0.28517 to 0.28715, saving model to best_model_224_res.h5
# 218/218 [==============================] - 82s 377ms/step - loss: -0.3457 - accuracy: 0.9741 - dice_coef: 0.3457 - specificity: 0.9866 - sensitivity: 0.5916 - precision: 0.2492 - val_loss: -0.2871 - val_accuracy: 0.9729 - val_dice_coef: 0.2871 - val_specificity: 0.9860 - val_sensitivity: 0.4862 - val_precision: 0.2051

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['specificity'], 'b', label='train specificity')
acc_ax.plot(results.history['val_specificity'], 'g', label='val specificity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['sensitivity'], 'b', label='train sensitivity')
acc_ax.plot(results.history['val_sensitivity'], 'g', label='val sensitivity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['precision'], 'b', label='train precision')
acc_ax.plot(results.history['val_precision'], 'g', label='val precision')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print(results.history['precision'][-1])
# Out:
# 0.2491554468870163

# %%
print(results.history['dice_coef'][-1])
# Out:
# 0.345697820186615

# %%
print(results.history['specificity'][-1])
# Out:
# 0.9866116046905518

# %%
# import os
test_list = os.listdir("test_set/")
print("The number of test data : ", len(test_list))
test_list[:5]
# Out:
# The number of test data :  335
# ['000_HC.png', '001_HC.png', '004_HC.png', '007_HC.png', '006_HC.png']

# %%
#used just for prediction, not as a checkpoint
model = tf.keras.models.load_model('best_model_224_res.h5', compile=False)

# %%
X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
for i, item in enumerate(test_list):
    image = cv2.imread("test_set/" + item, 0)
    image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    X_test[i] = image
X_test = X_test[:,:,:,np.newaxis] / 255

y_pred = model.predict(X_test)
# Out:
# 11/11 [==============================] - 4s 208ms/step

# %%
for test, pred in zip(X_test[180:190],y_pred[180:190]):
    fig, ax = plt.subplots(1,3,figsize = (16,12))
    test = test.reshape((IMG_HEIGHT,IMG_WIDTH))

    pred = pred.reshape((IMG_HEIGHT,IMG_WIDTH))
    pred = pred>0.5
    pred = np.ma.masked_where(pred == 0, pred)
    ax[0].imshow(test, cmap = 'gray')

    ax[1].imshow(pred, cmap = 'gray')

    ax[2].imshow(test, cmap = 'gray', interpolation = 'none')
    ax[2].imshow(pred, cmap = 'jet', interpolation = 'none', alpha = 0.7)

# %%
def fitEllipse(binary_mask, method="Direct"):
    assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0
    points = np.argwhere(binary_mask > 0.5)  

    if method == "AMS":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
    elif method == "Direct":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
    elif method == "Simple":
        (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

    return (xx, yy), (MA, ma), angle


# img = np.load("./output_samples/3.npy")
img = pred
(xx, yy), (MA, ma), angle = fitEllipse(img)
print((xx, yy), (MA, ma), angle)

draw = np.zeros((*img.shape, 3), dtype=np.uint8)

draw[img > 0.5] = (255,) * 3

cv2.ellipse(
    draw,
    (int(yy), int(xx)),
    (int(ma / 2), int(MA / 2)),
    -angle,
    0,
    360,
    color=(255, 0, 0),
    thickness=2,
)

plt.imshow(draw)
plt.show()
# Out:
# (106.53057098388672, 102.17353820800781) (147.84075927734375, 168.3318634033203) 88.4940185546875
