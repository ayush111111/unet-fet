# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush111111/unet-fet/blob/main/Unet_fetal_head_seg_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports and augmentation

# %%
# %cd drive/MyDrive/'Semester Project '/dataset_filled/
# %ls
# Out:
# /content/drive/MyDrive/Semester Project /dataset_filled
# best_model_224_res.h5  test_set/  training_set/

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
trainPath = "training_set/"
testPath = "test_set/"
trainList = sorted(os.listdir(trainPath))
testList = sorted(os.listdir(testPath))


train_image = []
train_mask = []
for i, item in enumerate(trainList):
    if i % 2 == 0:
        train_image.append(item)
    else:
        train_mask.append(item)
print("Ultrasound training images in dataset {}".format(len(train_image)))
print("Ultrasound training masks in dataset  {}".format(len(train_mask)))
# Out:
# Ultrasound training images in dataset 999
# Ultrasound training masks in dataset  999

# %%
img = np.array(Image.open(trainPath+"000_HC.png"))
img_mask = np.array(Image.open(trainPath+"000_HC_Annotation.png"))
img_mask = np.ma.masked_where(img_mask == 0, img_mask)
print(len(img[0]))
#display images with mask
fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(img, cmap = 'gray')
ax[1].imshow(img_mask, cmap = 'gray')
ax[2].imshow(img, cmap = 'gray', interpolation = 'none')
ax[2].imshow(img_mask, cmap = 'gray', interpolation = 'none', alpha = 0.7)
# Out:
# 800

# %%
#
X = []
y = []
for image, mask in zip(train_image, train_mask):
    X.append(np.array(Image.open(trainPath+image)))
    y.append(np.array(Image.open(trainPath+mask)))

X = np.array(X)
y = np.array(y)

print("X_shape : ", X.shape)
print("y_shape : ", y.shape)
# Out:
# X_shape :  (999,)
# y_shape :  (999,)
# <ipython-input-11-5829c98f866b>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# <ipython-input-11-5829c98f866b>:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y = np.array(y)

# %%
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split

import tensorflow.keras
import tensorflow as tf
from tensorflow.keras import backend as K

K.set_image_data_format('channels_last')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Add
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
def Generator(X_list, y_list, batch_size = 16):
    c = 0

    while(True):
        X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            image = X_list[i]
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            mask =  y_list[i]
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            X[i - c] = image
            y[i - c] = mask
        
        X = X[:,:,:,np.newaxis] / 255
        y = y[:,:,:,np.newaxis] / 255
        
        c += batch_size
        if(c+batch_size >= len(X_list)):
            c = 0
        yield X, y

# %%
train_img_aug = []
train_mask_aug = []


for img, mask in zip(train_image, train_mask):
    img = cv2.imread(trainPath + img)
    mask = cv2.imread(trainPath + mask)
    train_img_aug.append(img)
    
    train_mask_aug.append(mask)
    img_lr = np.fliplr(img)
    mask_lr = np.fliplr(mask)

    img_up = np.flipud(img)
    mask_up = np.flipud(mask)

    img_lr_up = np.flipud(img_lr)
    mask_lr_up = np.flipud(mask_lr)

    img_up_lr = np.fliplr(img_up)
    mask_up_lr = np.fliplr(mask_up)

    train_img_aug.append(img_lr)
    train_mask_aug.append(mask_lr)

    train_img_aug.append(img_up)
    train_mask_aug.append(mask_up)

    train_img_aug.append(img_lr_up)
    train_mask_aug.append(mask_lr_up)

    train_img_aug.append(img_up_lr)
    train_mask_aug.append(mask_up_lr)

print(len(train_image))
print(len(train_img_aug))
# Out:
# 999
# 4995

# %% [markdown]
# # Model Training

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
# define building blocks
def BatchnormActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_block(x, filters, size, strides=(1,1), padding="same", activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchnormActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchnormActivate(blockInput)
    x = conv_block(x, num_filters, (3,3))
    x = conv_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchnormActivate(x)
    return x

# %%
def build_Unet(input_layer, start_neurons, DropoutRatio = 0.5):
    

    """ Encoder """
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    #pool1 = Dropout(DropoutRatio/2)(pool1)

    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    #pool2 = Dropout(DropoutRatio)(pool2)

    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    #pool3 = Dropout(DropoutRatio)(pool3)

    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    #pool4 = Dropout(DropoutRatio)(pool4)


    """ Bridge """
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)



    """ Decoder """
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    #uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    #uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    """ Output """
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

# %%
#split training data

#test_size changed from 0.3 t0 0.2 
X_train, X_val, y_train, y_val = train_test_split(train_img_aug, train_mask_aug, test_size = 0.2, random_state = 1)

# set training parameters
epochs = 65
batch_size = 16
steps_per_epoch = int(len(X_train) / batch_size)
validation_steps = int(len(X_val) / batch_size)

train_gen = Generator(X_train, y_train, batch_size = batch_size)
val_gen = Generator(X_val, y_val, batch_size = batch_size)

# initialize our model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, 1))
output_layer = build_Unet(inputs, 16, 0.5)

# Define callbacks to save model with best val_dice_coef
checkpointer = ModelCheckpoint(filepath = 'best_model_224_res.h5', monitor='val_dice_coef', verbose=1, save_best_only=True, mode='max')
model = Model(inputs=[inputs], outputs=[output_layer])
model.compile(optimizer=Adam(lr = 1e-4), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 224, 224, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 16  2320        ['activation_1[0][0]']
#                                 )
#
#  add (Add)                      (None, 224, 224, 16  0           ['conv2d_2[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 224, 224, 16  64         ['add[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 16  2320        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 224, 224, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 224, 224, 16  2320        ['activation_3[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 224, 224, 16  0           ['conv2d_4[0][0]',
#                                 )                                 'add[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 224, 224, 16  64         ['add_1[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 16  0           ['activation_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 112, 112, 32  9248        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 112, 112, 32  9248        ['activation_6[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 112, 112, 32  0           ['conv2d_7[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 32  128        ['add_2[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 112, 112, 32  9248        ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 112, 112, 32  9248        ['activation_8[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 32  0           ['conv2d_9[0][0]',
#                                 )                                 'add_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 112, 112, 32  128        ['add_3[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 32)  0           ['activation_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_11[0][0]']
#
#  add_4 (Add)                    (None, 56, 56, 64)   0           ['conv2d_12[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 64)  256         ['add_4[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_12[0][0]']
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_13[0][0]']
#
#  add_5 (Add)                    (None, 56, 56, 64)   0           ['conv2d_14[0][0]',
#                                                                   'add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 64)  256         ['add_5[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_14[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['conv2d_17[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 128)  512        ['add_6[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_18[0][0]']
#
#  add_7 (Add)                    (None, 28, 28, 128)  0           ['conv2d_19[0][0]',
#                                                                   'add_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['add_7[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_21[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 256)  1024       ['add_8[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_23[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['conv2d_24[0][0]',
#                                                                   'add_8[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['add_9[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 128)  295040     ['activation_24[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 128)  295040      ['concatenate[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_26[0][0]']
#
#  add_10 (Add)                   (None, 28, 28, 128)  0           ['conv2d_27[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 128)  512        ['add_10[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_28[0][0]']
#
#  add_11 (Add)                   (None, 28, 28, 128)  0           ['conv2d_29[0][0]',
#                                                                   'add_10[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 128)  512        ['add_11[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_29[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 56, 56, 64)   73792       ['concatenate_1[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 56, 56, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 56, 56, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_31[0][0]']
#
#  add_12 (Add)                   (None, 56, 56, 64)   0           ['conv2d_32[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 56, 56, 64)  256         ['add_12[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 56, 56, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_33[0][0]']
#
#  add_13 (Add)                   (None, 56, 56, 64)   0           ['conv2d_34[0][0]',
#                                                                   'add_12[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 56, 56, 64)  256         ['add_13[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_34[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'activation_9[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 112, 112, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 112, 112, 32  128        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 112, 112, 32  9248        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 112, 112, 32  128        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 112, 112, 32  9248        ['activation_36[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 112, 112, 32  0           ['conv2d_37[0][0]',
#                                 )                                 'conv2d_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 112, 112, 32  128        ['add_14[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 112, 112, 32  9248        ['activation_37[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 112, 112, 32  128        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 112, 112, 32  9248        ['activation_38[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 112, 112, 32  0           ['conv2d_39[0][0]',
#                                 )                                 'add_14[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 112, 112, 32  128        ['add_15[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 16  4624       ['activation_39[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 224, 224, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 224, 224, 16  64         ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  activation_40 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_40[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 224, 224, 16  2320        ['activation_40[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 224, 224, 16  64         ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 224, 224, 16  2320        ['activation_41[0][0]']
#                                 )
#
#  add_16 (Add)                   (None, 224, 224, 16  0           ['conv2d_42[0][0]',
#                                 )                                 'conv2d_40[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 224, 224, 16  64         ['add_16[0][0]']
#  ormalization)                  )
#
#  activation_42 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 224, 224, 16  2320        ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 224, 224, 16  64         ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 224, 224, 16  2320        ['activation_43[0][0]']
#                                 )
#
#  add_17 (Add)                   (None, 224, 224, 16  0           ['conv2d_44[0][0]',
#                                 )                                 'add_16[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 224, 224, 16  64         ['add_17[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 224, 224, 1)  17          ['activation_44[0][0]']
#
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# Out:
# <ipython-input-14-350936afeb50>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# Epoch 1/65
# 249/249 [==============================] - ETA: 0s - loss: -0.6971 - accuracy: 0.8965 - dice_coef: 0.6971 - specificity: 0.8799 - sensitivity: 0.9515 - precision: 0.8036
# Epoch 1: val_dice_coef improved from -inf to 0.74236, saving model to best_model_224_res.h5
# 249/249 [==============================] - 96s 326ms/step - loss: -0.6971 - accuracy: 0.8965 - dice_coef: 0.6971 - specificity: 0.8799 - sensitivity: 0.9515 - precision: 0.8036 - val_loss: -0.7424 - val_accuracy: 0.9118 - val_dice_coef: 0.7424 - val_specificity: 0.9108 - val_sensitivity: 0.9304 - val_precision: 0.8116
# Epoch 2/65
# 249/249 [==============================] - ETA: 0s - loss: -0.8059 - accuracy: 0.9709 - dice_coef: 0.8059 - specificity: 0.9716 - sensitivity: 0.9849 - precision: 0.9338
# Epoch 2: val_dice_coef improved from 0.74236 to 0.81015, saving model to best_model_224_res.h5
# 249/249 [==============================] - 83s 333ms/step - loss: -0.8059 - accuracy: 0.9709 - dice_coef: 0.8059 - specificity: 0.9716 - sensitivity: 0.9849 - precision: 0.9338 - val_loss: -0.8102 - val_accuracy: 0.9637 - val_dice_coef: 0.8102 - val_specificity: 0.9707 - val_sensitivity: 0.9620 - val_precision: 0.9312
# Epoch 3/65
# 249/249 [==============================] - ETA: 0s - loss: -0.8391 - accuracy: 0.9755 - dice_coef: 0.8391 - specificity: 0.9778 - sensitivity: 0.9863 - precision: 0.9475
# Epoch 3: val_dice_coef improved from 0.81015 to 0.84139, saving model to best_model_224_res.h5
# 249/249 [==============================] - 83s 334ms/step - loss: -0.8391 - accuracy: 0.9755 - dice_coef: 0.8391 - specificity: 0.9778 - sensitivity: 0.9863 - precision: 0.9475 - val_loss: -0.8414 - val_accuracy: 0.9689 - val_dice_coef: 0.8414 - val_specificity: 0.9659 - val_sensitivity: 0.9922 - val_precision: 0.9227
# Epoch 4/65
# 249/249 [==============================] - ETA: 0s - loss: -0.8656 - accuracy: 0.9781 - dice_coef: 0.8656 - specificity: 0.9816 - sensitivity: 0.9864 - precision: 0.9566
# Epoch 4: val_dice_coef improved from 0.84139 to 0.87154, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 341ms/step - loss: -0.8656 - accuracy: 0.9781 - dice_coef: 0.8656 - specificity: 0.9816 - sensitivity: 0.9864 - precision: 0.9566 - val_loss: -0.8715 - val_accuracy: 0.9774 - val_dice_coef: 0.8715 - val_specificity: 0.9802 - val_sensitivity: 0.9871 - val_precision: 0.9536
# Epoch 5/65
# 249/249 [==============================] - ETA: 0s - loss: -0.8876 - accuracy: 0.9799 - dice_coef: 0.8876 - specificity: 0.9844 - sensitivity: 0.9862 - precision: 0.9630
# Epoch 5: val_dice_coef improved from 0.87154 to 0.89069, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 339ms/step - loss: -0.8876 - accuracy: 0.9799 - dice_coef: 0.8876 - specificity: 0.9844 - sensitivity: 0.9862 - precision: 0.9630 - val_loss: -0.8907 - val_accuracy: 0.9773 - val_dice_coef: 0.8907 - val_specificity: 0.9797 - val_sensitivity: 0.9886 - val_precision: 0.9527
# Epoch 6/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9060 - accuracy: 0.9815 - dice_coef: 0.9060 - specificity: 0.9867 - sensitivity: 0.9865 - precision: 0.9686
# Epoch 6: val_dice_coef improved from 0.89069 to 0.90779, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 342ms/step - loss: -0.9060 - accuracy: 0.9815 - dice_coef: 0.9060 - specificity: 0.9867 - sensitivity: 0.9865 - precision: 0.9686 - val_loss: -0.9078 - val_accuracy: 0.9793 - val_dice_coef: 0.9078 - val_specificity: 0.9847 - val_sensitivity: 0.9835 - val_precision: 0.9640
# Epoch 7/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9212 - accuracy: 0.9827 - dice_coef: 0.9212 - specificity: 0.9885 - sensitivity: 0.9868 - precision: 0.9729
# Epoch 7: val_dice_coef improved from 0.90779 to 0.91991, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 339ms/step - loss: -0.9212 - accuracy: 0.9827 - dice_coef: 0.9212 - specificity: 0.9885 - sensitivity: 0.9868 - precision: 0.9729 - val_loss: -0.9199 - val_accuracy: 0.9797 - val_dice_coef: 0.9199 - val_specificity: 0.9886 - val_sensitivity: 0.9763 - val_precision: 0.9727
# Epoch 8/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9329 - accuracy: 0.9832 - dice_coef: 0.9329 - specificity: 0.9895 - sensitivity: 0.9867 - precision: 0.9753
# Epoch 8: val_dice_coef improved from 0.91991 to 0.92951, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 340ms/step - loss: -0.9329 - accuracy: 0.9832 - dice_coef: 0.9329 - specificity: 0.9895 - sensitivity: 0.9867 - precision: 0.9753 - val_loss: -0.9295 - val_accuracy: 0.9792 - val_dice_coef: 0.9295 - val_specificity: 0.9889 - val_sensitivity: 0.9742 - val_precision: 0.9733
# Epoch 9/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9419 - accuracy: 0.9833 - dice_coef: 0.9419 - specificity: 0.9901 - sensitivity: 0.9861 - precision: 0.9767
# Epoch 9: val_dice_coef improved from 0.92951 to 0.93881, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9419 - accuracy: 0.9833 - dice_coef: 0.9419 - specificity: 0.9901 - sensitivity: 0.9861 - precision: 0.9767 - val_loss: -0.9388 - val_accuracy: 0.9795 - val_dice_coef: 0.9388 - val_specificity: 0.9852 - val_sensitivity: 0.9842 - val_precision: 0.9650
# Epoch 10/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9487 - accuracy: 0.9832 - dice_coef: 0.9487 - specificity: 0.9903 - sensitivity: 0.9854 - precision: 0.9772
# Epoch 10: val_dice_coef improved from 0.93881 to 0.94495, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 339ms/step - loss: -0.9487 - accuracy: 0.9832 - dice_coef: 0.9487 - specificity: 0.9903 - sensitivity: 0.9854 - precision: 0.9772 - val_loss: -0.9450 - val_accuracy: 0.9794 - val_dice_coef: 0.9450 - val_specificity: 0.9899 - val_sensitivity: 0.9729 - val_precision: 0.9756
# Epoch 11/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9548 - accuracy: 0.9835 - dice_coef: 0.9548 - specificity: 0.9909 - sensitivity: 0.9852 - precision: 0.9785
# Epoch 11: val_dice_coef improved from 0.94495 to 0.95133, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 337ms/step - loss: -0.9548 - accuracy: 0.9835 - dice_coef: 0.9548 - specificity: 0.9909 - sensitivity: 0.9852 - precision: 0.9785 - val_loss: -0.9513 - val_accuracy: 0.9800 - val_dice_coef: 0.9513 - val_specificity: 0.9879 - val_sensitivity: 0.9798 - val_precision: 0.9711
# Epoch 12/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9609 - accuracy: 0.9844 - dice_coef: 0.9609 - specificity: 0.9919 - sensitivity: 0.9862 - precision: 0.9809
# Epoch 12: val_dice_coef improved from 0.95133 to 0.95278, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 340ms/step - loss: -0.9609 - accuracy: 0.9844 - dice_coef: 0.9609 - specificity: 0.9919 - sensitivity: 0.9862 - precision: 0.9809 - val_loss: -0.9528 - val_accuracy: 0.9784 - val_dice_coef: 0.9528 - val_specificity: 0.9857 - val_sensitivity: 0.9796 - val_precision: 0.9660
# Epoch 13/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9640 - accuracy: 0.9840 - dice_coef: 0.9640 - specificity: 0.9918 - sensitivity: 0.9852 - precision: 0.9805
# Epoch 13: val_dice_coef improved from 0.95278 to 0.95849, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9640 - accuracy: 0.9840 - dice_coef: 0.9640 - specificity: 0.9918 - sensitivity: 0.9852 - precision: 0.9805 - val_loss: -0.9585 - val_accuracy: 0.9800 - val_dice_coef: 0.9585 - val_specificity: 0.9867 - val_sensitivity: 0.9829 - val_precision: 0.9686
# Epoch 14/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9692 - accuracy: 0.9852 - dice_coef: 0.9692 - specificity: 0.9929 - sensitivity: 0.9872 - precision: 0.9834
# Epoch 14: val_dice_coef improved from 0.95849 to 0.96361, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 339ms/step - loss: -0.9692 - accuracy: 0.9852 - dice_coef: 0.9692 - specificity: 0.9929 - sensitivity: 0.9872 - precision: 0.9834 - val_loss: -0.9636 - val_accuracy: 0.9813 - val_dice_coef: 0.9636 - val_specificity: 0.9898 - val_sensitivity: 0.9804 - val_precision: 0.9756
# Epoch 15/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9714 - accuracy: 0.9850 - dice_coef: 0.9714 - specificity: 0.9929 - sensitivity: 0.9866 - precision: 0.9832
# Epoch 15: val_dice_coef improved from 0.96361 to 0.96618, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9714 - accuracy: 0.9850 - dice_coef: 0.9714 - specificity: 0.9929 - sensitivity: 0.9866 - precision: 0.9832 - val_loss: -0.9662 - val_accuracy: 0.9814 - val_dice_coef: 0.9662 - val_specificity: 0.9878 - val_sensitivity: 0.9855 - val_precision: 0.9709
# Epoch 16/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9744 - accuracy: 0.9856 - dice_coef: 0.9744 - specificity: 0.9935 - sensitivity: 0.9873 - precision: 0.9847
# Epoch 16: val_dice_coef improved from 0.96618 to 0.96677, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 340ms/step - loss: -0.9744 - accuracy: 0.9856 - dice_coef: 0.9744 - specificity: 0.9935 - sensitivity: 0.9873 - precision: 0.9847 - val_loss: -0.9668 - val_accuracy: 0.9807 - val_dice_coef: 0.9668 - val_specificity: 0.9870 - val_sensitivity: 0.9850 - val_precision: 0.9692
# Epoch 17/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9771 - accuracy: 0.9861 - dice_coef: 0.9771 - specificity: 0.9940 - sensitivity: 0.9881 - precision: 0.9859
# Epoch 17: val_dice_coef improved from 0.96677 to 0.96857, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9771 - accuracy: 0.9861 - dice_coef: 0.9771 - specificity: 0.9940 - sensitivity: 0.9881 - precision: 0.9859 - val_loss: -0.9686 - val_accuracy: 0.9808 - val_dice_coef: 0.9686 - val_specificity: 0.9858 - val_sensitivity: 0.9884 - val_precision: 0.9665
# Epoch 18/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9788 - accuracy: 0.9862 - dice_coef: 0.9788 - specificity: 0.9943 - sensitivity: 0.9881 - precision: 0.9865
# Epoch 18: val_dice_coef did not improve from 0.96857
# 249/249 [==============================] - 83s 335ms/step - loss: -0.9788 - accuracy: 0.9862 - dice_coef: 0.9788 - specificity: 0.9943 - sensitivity: 0.9881 - precision: 0.9865 - val_loss: -0.9678 - val_accuracy: 0.9796 - val_dice_coef: 0.9678 - val_specificity: 0.9846 - val_sensitivity: 0.9867 - val_precision: 0.9638
# Epoch 19/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9804 - accuracy: 0.9864 - dice_coef: 0.9804 - specificity: 0.9944 - sensitivity: 0.9885 - precision: 0.9869
# Epoch 19: val_dice_coef improved from 0.96857 to 0.96925, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9804 - accuracy: 0.9864 - dice_coef: 0.9804 - specificity: 0.9944 - sensitivity: 0.9885 - precision: 0.9869 - val_loss: -0.9693 - val_accuracy: 0.9800 - val_dice_coef: 0.9693 - val_specificity: 0.9889 - val_sensitivity: 0.9779 - val_precision: 0.9733
# Epoch 20/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9818 - accuracy: 0.9866 - dice_coef: 0.9818 - specificity: 0.9946 - sensitivity: 0.9888 - precision: 0.9873
# Epoch 20: val_dice_coef improved from 0.96925 to 0.97172, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9818 - accuracy: 0.9866 - dice_coef: 0.9818 - specificity: 0.9946 - sensitivity: 0.9888 - precision: 0.9873 - val_loss: -0.9717 - val_accuracy: 0.9808 - val_dice_coef: 0.9717 - val_specificity: 0.9869 - val_sensitivity: 0.9857 - val_precision: 0.9688
# Epoch 21/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9827 - accuracy: 0.9867 - dice_coef: 0.9827 - specificity: 0.9947 - sensitivity: 0.9888 - precision: 0.9876
# Epoch 21: val_dice_coef improved from 0.97172 to 0.97465, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 340ms/step - loss: -0.9827 - accuracy: 0.9867 - dice_coef: 0.9827 - specificity: 0.9947 - sensitivity: 0.9888 - precision: 0.9876 - val_loss: -0.9746 - val_accuracy: 0.9821 - val_dice_coef: 0.9746 - val_specificity: 0.9904 - val_sensitivity: 0.9820 - val_precision: 0.9770
# Epoch 22/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9831 - accuracy: 0.9865 - dice_coef: 0.9831 - specificity: 0.9946 - sensitivity: 0.9884 - precision: 0.9873
# Epoch 22: val_dice_coef did not improve from 0.97465
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9831 - accuracy: 0.9865 - dice_coef: 0.9831 - specificity: 0.9946 - sensitivity: 0.9884 - precision: 0.9873 - val_loss: -0.9739 - val_accuracy: 0.9813 - val_dice_coef: 0.9739 - val_specificity: 0.9930 - val_sensitivity: 0.9731 - val_precision: 0.9830
# Epoch 23/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9842 - accuracy: 0.9867 - dice_coef: 0.9842 - specificity: 0.9949 - sensitivity: 0.9888 - precision: 0.9878
# Epoch 23: val_dice_coef improved from 0.97465 to 0.97486, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 339ms/step - loss: -0.9842 - accuracy: 0.9867 - dice_coef: 0.9842 - specificity: 0.9949 - sensitivity: 0.9888 - precision: 0.9878 - val_loss: -0.9749 - val_accuracy: 0.9815 - val_dice_coef: 0.9749 - val_specificity: 0.9914 - val_sensitivity: 0.9778 - val_precision: 0.9792
# Epoch 24/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9854 - accuracy: 0.9871 - dice_coef: 0.9854 - specificity: 0.9952 - sensitivity: 0.9894 - precision: 0.9887
# Epoch 24: val_dice_coef improved from 0.97486 to 0.97506, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 339ms/step - loss: -0.9854 - accuracy: 0.9871 - dice_coef: 0.9854 - specificity: 0.9952 - sensitivity: 0.9894 - precision: 0.9887 - val_loss: -0.9751 - val_accuracy: 0.9813 - val_dice_coef: 0.9751 - val_specificity: 0.9880 - val_sensitivity: 0.9851 - val_precision: 0.9714
# Epoch 25/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9828 - accuracy: 0.9854 - dice_coef: 0.9828 - specificity: 0.9940 - sensitivity: 0.9862 - precision: 0.9858
# Epoch 25: val_dice_coef did not improve from 0.97506
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9828 - accuracy: 0.9854 - dice_coef: 0.9828 - specificity: 0.9940 - sensitivity: 0.9862 - precision: 0.9858 - val_loss: -0.9727 - val_accuracy: 0.9797 - val_dice_coef: 0.9727 - val_specificity: 0.9870 - val_sensitivity: 0.9823 - val_precision: 0.9688
# Epoch 26/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9874 - accuracy: 0.9876 - dice_coef: 0.9874 - specificity: 0.9958 - sensitivity: 0.9905 - precision: 0.9901
# Epoch 26: val_dice_coef improved from 0.97506 to 0.97722, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 339ms/step - loss: -0.9874 - accuracy: 0.9876 - dice_coef: 0.9874 - specificity: 0.9958 - sensitivity: 0.9905 - precision: 0.9901 - val_loss: -0.9772 - val_accuracy: 0.9821 - val_dice_coef: 0.9772 - val_specificity: 0.9912 - val_sensitivity: 0.9807 - val_precision: 0.9787
# Epoch 27/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9890 - accuracy: 0.9882 - dice_coef: 0.9890 - specificity: 0.9964 - sensitivity: 0.9919 - precision: 0.9914
# Epoch 27: val_dice_coef did not improve from 0.97722
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9890 - accuracy: 0.9882 - dice_coef: 0.9890 - specificity: 0.9964 - sensitivity: 0.9919 - precision: 0.9914 - val_loss: -0.9744 - val_accuracy: 0.9804 - val_dice_coef: 0.9744 - val_specificity: 0.9904 - val_sensitivity: 0.9761 - val_precision: 0.9768
# Epoch 28/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9878 - accuracy: 0.9875 - dice_coef: 0.9878 - specificity: 0.9957 - sensitivity: 0.9904 - precision: 0.9898
# Epoch 28: val_dice_coef improved from 0.97722 to 0.97790, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 337ms/step - loss: -0.9878 - accuracy: 0.9875 - dice_coef: 0.9878 - specificity: 0.9957 - sensitivity: 0.9904 - precision: 0.9898 - val_loss: -0.9779 - val_accuracy: 0.9821 - val_dice_coef: 0.9779 - val_specificity: 0.9912 - val_sensitivity: 0.9808 - val_precision: 0.9787
# Epoch 29/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9877 - accuracy: 0.9873 - dice_coef: 0.9877 - specificity: 0.9955 - sensitivity: 0.9899 - precision: 0.9895
# Epoch 29: val_dice_coef did not improve from 0.97790
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9877 - accuracy: 0.9873 - dice_coef: 0.9877 - specificity: 0.9955 - sensitivity: 0.9899 - precision: 0.9895 - val_loss: -0.9765 - val_accuracy: 0.9813 - val_dice_coef: 0.9765 - val_specificity: 0.9927 - val_sensitivity: 0.9741 - val_precision: 0.9821
# Epoch 30/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9882 - accuracy: 0.9875 - dice_coef: 0.9882 - specificity: 0.9957 - sensitivity: 0.9903 - precision: 0.9898
# Epoch 30: val_dice_coef improved from 0.97790 to 0.97851, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9882 - accuracy: 0.9875 - dice_coef: 0.9882 - specificity: 0.9957 - sensitivity: 0.9903 - precision: 0.9898 - val_loss: -0.9785 - val_accuracy: 0.9823 - val_dice_coef: 0.9785 - val_specificity: 0.9938 - val_sensitivity: 0.9752 - val_precision: 0.9849
# Epoch 31/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9883 - accuracy: 0.9874 - dice_coef: 0.9883 - specificity: 0.9957 - sensitivity: 0.9901 - precision: 0.9897
# Epoch 31: val_dice_coef did not improve from 0.97851
# 249/249 [==============================] - 84s 336ms/step - loss: -0.9883 - accuracy: 0.9874 - dice_coef: 0.9883 - specificity: 0.9957 - sensitivity: 0.9901 - precision: 0.9897 - val_loss: -0.9770 - val_accuracy: 0.9814 - val_dice_coef: 0.9770 - val_specificity: 0.9918 - val_sensitivity: 0.9764 - val_precision: 0.9802
# Epoch 32/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9882 - accuracy: 0.9873 - dice_coef: 0.9882 - specificity: 0.9955 - sensitivity: 0.9898 - precision: 0.9894
# Epoch 32: val_dice_coef did not improve from 0.97851
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9882 - accuracy: 0.9873 - dice_coef: 0.9882 - specificity: 0.9955 - sensitivity: 0.9898 - precision: 0.9894 - val_loss: -0.9776 - val_accuracy: 0.9816 - val_dice_coef: 0.9776 - val_specificity: 0.9894 - val_sensitivity: 0.9828 - val_precision: 0.9747
# Epoch 33/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9888 - accuracy: 0.9875 - dice_coef: 0.9888 - specificity: 0.9958 - sensitivity: 0.9903 - precision: 0.9899
# Epoch 33: val_dice_coef did not improve from 0.97851
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9888 - accuracy: 0.9875 - dice_coef: 0.9888 - specificity: 0.9958 - sensitivity: 0.9903 - precision: 0.9899 - val_loss: -0.9770 - val_accuracy: 0.9813 - val_dice_coef: 0.9770 - val_specificity: 0.9917 - val_sensitivity: 0.9763 - val_precision: 0.9798
# Epoch 34/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9893 - accuracy: 0.9877 - dice_coef: 0.9893 - specificity: 0.9959 - sensitivity: 0.9907 - precision: 0.9904
# Epoch 34: val_dice_coef did not improve from 0.97851
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9893 - accuracy: 0.9877 - dice_coef: 0.9893 - specificity: 0.9959 - sensitivity: 0.9907 - precision: 0.9904 - val_loss: -0.9757 - val_accuracy: 0.9805 - val_dice_coef: 0.9757 - val_specificity: 0.9925 - val_sensitivity: 0.9716 - val_precision: 0.9817
# Epoch 35/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9896 - accuracy: 0.9878 - dice_coef: 0.9896 - specificity: 0.9960 - sensitivity: 0.9909 - precision: 0.9906
# Epoch 35: val_dice_coef improved from 0.97851 to 0.97857, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9896 - accuracy: 0.9878 - dice_coef: 0.9896 - specificity: 0.9960 - sensitivity: 0.9909 - precision: 0.9906 - val_loss: -0.9786 - val_accuracy: 0.9820 - val_dice_coef: 0.9786 - val_specificity: 0.9932 - val_sensitivity: 0.9755 - val_precision: 0.9834
# Epoch 36/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9897 - accuracy: 0.9878 - dice_coef: 0.9897 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9906
# Epoch 36: val_dice_coef improved from 0.97857 to 0.97889, saving model to best_model_224_res.h5
# 249/249 [==============================] - 85s 339ms/step - loss: -0.9897 - accuracy: 0.9878 - dice_coef: 0.9897 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9906 - val_loss: -0.9789 - val_accuracy: 0.9821 - val_dice_coef: 0.9789 - val_specificity: 0.9933 - val_sensitivity: 0.9757 - val_precision: 0.9837
# Epoch 37/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9901 - accuracy: 0.9880 - dice_coef: 0.9901 - specificity: 0.9962 - sensitivity: 0.9912 - precision: 0.9911
# Epoch 37: val_dice_coef did not improve from 0.97889
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9901 - accuracy: 0.9880 - dice_coef: 0.9901 - specificity: 0.9962 - sensitivity: 0.9912 - precision: 0.9911 - val_loss: -0.9781 - val_accuracy: 0.9816 - val_dice_coef: 0.9781 - val_specificity: 0.9907 - val_sensitivity: 0.9803 - val_precision: 0.9775
# Epoch 38/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9904 - accuracy: 0.9881 - dice_coef: 0.9904 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9913
# Epoch 38: val_dice_coef did not improve from 0.97889
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9904 - accuracy: 0.9881 - dice_coef: 0.9904 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9913 - val_loss: -0.9785 - val_accuracy: 0.9818 - val_dice_coef: 0.9785 - val_specificity: 0.9897 - val_sensitivity: 0.9830 - val_precision: 0.9753
# Epoch 39/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9904 - accuracy: 0.9880 - dice_coef: 0.9904 - specificity: 0.9963 - sensitivity: 0.9913 - precision: 0.9912
# Epoch 39: val_dice_coef improved from 0.97889 to 0.97926, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9904 - accuracy: 0.9880 - dice_coef: 0.9904 - specificity: 0.9963 - sensitivity: 0.9913 - precision: 0.9912 - val_loss: -0.9793 - val_accuracy: 0.9822 - val_dice_coef: 0.9793 - val_specificity: 0.9917 - val_sensitivity: 0.9800 - val_precision: 0.9798
# Epoch 40/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9904 - accuracy: 0.9880 - dice_coef: 0.9904 - specificity: 0.9962 - sensitivity: 0.9914 - precision: 0.9911
# Epoch 40: val_dice_coef did not improve from 0.97926
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9904 - accuracy: 0.9880 - dice_coef: 0.9904 - specificity: 0.9962 - sensitivity: 0.9914 - precision: 0.9911 - val_loss: -0.9789 - val_accuracy: 0.9820 - val_dice_coef: 0.9789 - val_specificity: 0.9938 - val_sensitivity: 0.9743 - val_precision: 0.9848
# Epoch 41/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9901 - accuracy: 0.9878 - dice_coef: 0.9901 - specificity: 0.9961 - sensitivity: 0.9910 - precision: 0.9907
# Epoch 41: val_dice_coef did not improve from 0.97926
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9901 - accuracy: 0.9878 - dice_coef: 0.9901 - specificity: 0.9961 - sensitivity: 0.9910 - precision: 0.9907 - val_loss: -0.9748 - val_accuracy: 0.9798 - val_dice_coef: 0.9748 - val_specificity: 0.9947 - val_sensitivity: 0.9639 - val_precision: 0.9870
# Epoch 42/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9902 - accuracy: 0.9879 - dice_coef: 0.9902 - specificity: 0.9961 - sensitivity: 0.9911 - precision: 0.9908
# Epoch 42: val_dice_coef did not improve from 0.97926
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9902 - accuracy: 0.9879 - dice_coef: 0.9902 - specificity: 0.9961 - sensitivity: 0.9911 - precision: 0.9908 - val_loss: -0.9763 - val_accuracy: 0.9806 - val_dice_coef: 0.9763 - val_specificity: 0.9915 - val_sensitivity: 0.9743 - val_precision: 0.9793
# Epoch 43/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9908 - accuracy: 0.9881 - dice_coef: 0.9908 - specificity: 0.9964 - sensitivity: 0.9916 - precision: 0.9915
# Epoch 43: val_dice_coef did not improve from 0.97926
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9908 - accuracy: 0.9881 - dice_coef: 0.9908 - specificity: 0.9964 - sensitivity: 0.9916 - precision: 0.9915 - val_loss: -0.9787 - val_accuracy: 0.9818 - val_dice_coef: 0.9787 - val_specificity: 0.9921 - val_sensitivity: 0.9776 - val_precision: 0.9808
# Epoch 44/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9911 - accuracy: 0.9883 - dice_coef: 0.9911 - specificity: 0.9966 - sensitivity: 0.9919 - precision: 0.9919
# Epoch 44: val_dice_coef improved from 0.97926 to 0.98052, saving model to best_model_224_res.h5
# 249/249 [==============================] - 84s 338ms/step - loss: -0.9911 - accuracy: 0.9883 - dice_coef: 0.9911 - specificity: 0.9966 - sensitivity: 0.9919 - precision: 0.9919 - val_loss: -0.9805 - val_accuracy: 0.9827 - val_dice_coef: 0.9805 - val_specificity: 0.9920 - val_sensitivity: 0.9813 - val_precision: 0.9807
# Epoch 45/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9912 - accuracy: 0.9883 - dice_coef: 0.9912 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9919
# Epoch 45: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9912 - accuracy: 0.9883 - dice_coef: 0.9912 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9919 - val_loss: -0.9791 - val_accuracy: 0.9819 - val_dice_coef: 0.9791 - val_specificity: 0.9911 - val_sensitivity: 0.9805 - val_precision: 0.9785
# Epoch 46/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9913 - accuracy: 0.9883 - dice_coef: 0.9913 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920
# Epoch 46: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9913 - accuracy: 0.9883 - dice_coef: 0.9913 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920 - val_loss: -0.9770 - val_accuracy: 0.9808 - val_dice_coef: 0.9770 - val_specificity: 0.9909 - val_sensitivity: 0.9769 - val_precision: 0.9780
# Epoch 47/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9914 - accuracy: 0.9883 - dice_coef: 0.9914 - specificity: 0.9967 - sensitivity: 0.9921 - precision: 0.9921
# Epoch 47: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9914 - accuracy: 0.9883 - dice_coef: 0.9914 - specificity: 0.9967 - sensitivity: 0.9921 - precision: 0.9921 - val_loss: -0.9780 - val_accuracy: 0.9814 - val_dice_coef: 0.9780 - val_specificity: 0.9920 - val_sensitivity: 0.9762 - val_precision: 0.9806
# Epoch 48/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9912 - accuracy: 0.9883 - dice_coef: 0.9912 - specificity: 0.9966 - sensitivity: 0.9919 - precision: 0.9918
# Epoch 48: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9912 - accuracy: 0.9883 - dice_coef: 0.9912 - specificity: 0.9966 - sensitivity: 0.9919 - precision: 0.9918 - val_loss: -0.9795 - val_accuracy: 0.9822 - val_dice_coef: 0.9795 - val_specificity: 0.9914 - val_sensitivity: 0.9807 - val_precision: 0.9792
# Epoch 49/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9911 - accuracy: 0.9882 - dice_coef: 0.9911 - specificity: 0.9965 - sensitivity: 0.9919 - precision: 0.9917
# Epoch 49: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9911 - accuracy: 0.9882 - dice_coef: 0.9911 - specificity: 0.9965 - sensitivity: 0.9919 - precision: 0.9917 - val_loss: -0.9786 - val_accuracy: 0.9816 - val_dice_coef: 0.9786 - val_specificity: 0.9931 - val_sensitivity: 0.9748 - val_precision: 0.9832
# Epoch 50/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9908 - accuracy: 0.9881 - dice_coef: 0.9908 - specificity: 0.9964 - sensitivity: 0.9915 - precision: 0.9914
# Epoch 50: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9908 - accuracy: 0.9881 - dice_coef: 0.9908 - specificity: 0.9964 - sensitivity: 0.9915 - precision: 0.9914 - val_loss: -0.9757 - val_accuracy: 0.9802 - val_dice_coef: 0.9757 - val_specificity: 0.9928 - val_sensitivity: 0.9697 - val_precision: 0.9825
# Epoch 51/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9907 - accuracy: 0.9880 - dice_coef: 0.9907 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9912
# Epoch 51: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9907 - accuracy: 0.9880 - dice_coef: 0.9907 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9912 - val_loss: -0.9768 - val_accuracy: 0.9807 - val_dice_coef: 0.9768 - val_specificity: 0.9909 - val_sensitivity: 0.9761 - val_precision: 0.9781
# Epoch 52/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9911 - accuracy: 0.9882 - dice_coef: 0.9911 - specificity: 0.9965 - sensitivity: 0.9917 - precision: 0.9917
# Epoch 52: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9911 - accuracy: 0.9882 - dice_coef: 0.9911 - specificity: 0.9965 - sensitivity: 0.9917 - precision: 0.9917 - val_loss: -0.9790 - val_accuracy: 0.9818 - val_dice_coef: 0.9790 - val_specificity: 0.9908 - val_sensitivity: 0.9809 - val_precision: 0.9778
# Epoch 53/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9914 - accuracy: 0.9883 - dice_coef: 0.9914 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920
# Epoch 53: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9914 - accuracy: 0.9883 - dice_coef: 0.9914 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920 - val_loss: -0.9794 - val_accuracy: 0.9820 - val_dice_coef: 0.9794 - val_specificity: 0.9914 - val_sensitivity: 0.9801 - val_precision: 0.9794
# Epoch 54/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9918 - accuracy: 0.9885 - dice_coef: 0.9918 - specificity: 0.9968 - sensitivity: 0.9925 - precision: 0.9925
# Epoch 54: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9918 - accuracy: 0.9885 - dice_coef: 0.9918 - specificity: 0.9968 - sensitivity: 0.9925 - precision: 0.9925 - val_loss: -0.9800 - val_accuracy: 0.9824 - val_dice_coef: 0.9800 - val_specificity: 0.9921 - val_sensitivity: 0.9800 - val_precision: 0.9807
# Epoch 55/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9922 - accuracy: 0.9886 - dice_coef: 0.9922 - specificity: 0.9970 - sensitivity: 0.9930 - precision: 0.9929
# Epoch 55: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9922 - accuracy: 0.9886 - dice_coef: 0.9922 - specificity: 0.9970 - sensitivity: 0.9930 - precision: 0.9929 - val_loss: -0.9788 - val_accuracy: 0.9818 - val_dice_coef: 0.9788 - val_specificity: 0.9936 - val_sensitivity: 0.9741 - val_precision: 0.9843
# Epoch 56/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9922 - accuracy: 0.9886 - dice_coef: 0.9922 - specificity: 0.9969 - sensitivity: 0.9931 - precision: 0.9927
# Epoch 56: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9922 - accuracy: 0.9886 - dice_coef: 0.9922 - specificity: 0.9969 - sensitivity: 0.9931 - precision: 0.9927 - val_loss: -0.9780 - val_accuracy: 0.9814 - val_dice_coef: 0.9780 - val_specificity: 0.9951 - val_sensitivity: 0.9689 - val_precision: 0.9880
# Epoch 57/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9922 - accuracy: 0.9886 - dice_coef: 0.9922 - specificity: 0.9970 - sensitivity: 0.9930 - precision: 0.9928
# Epoch 57: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9922 - accuracy: 0.9886 - dice_coef: 0.9922 - specificity: 0.9970 - sensitivity: 0.9930 - precision: 0.9928 - val_loss: -0.9792 - val_accuracy: 0.9821 - val_dice_coef: 0.9792 - val_specificity: 0.9952 - val_sensitivity: 0.9712 - val_precision: 0.9881
# Epoch 58/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9971 - sensitivity: 0.9931 - precision: 0.9931
# Epoch 58: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9924 - accuracy: 0.9887 - dice_coef: 0.9924 - specificity: 0.9971 - sensitivity: 0.9931 - precision: 0.9931 - val_loss: -0.9802 - val_accuracy: 0.9825 - val_dice_coef: 0.9802 - val_specificity: 0.9937 - val_sensitivity: 0.9766 - val_precision: 0.9846
# Epoch 59/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9914 - accuracy: 0.9882 - dice_coef: 0.9914 - specificity: 0.9966 - sensitivity: 0.9921 - precision: 0.9920
# Epoch 59: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9914 - accuracy: 0.9882 - dice_coef: 0.9914 - specificity: 0.9966 - sensitivity: 0.9921 - precision: 0.9920 - val_loss: -0.9639 - val_accuracy: 0.9729 - val_dice_coef: 0.9639 - val_specificity: 0.9788 - val_sensitivity: 0.9791 - val_precision: 0.9501
# Epoch 60/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9914 - accuracy: 0.9882 - dice_coef: 0.9914 - specificity: 0.9967 - sensitivity: 0.9920 - precision: 0.9922
# Epoch 60: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9914 - accuracy: 0.9882 - dice_coef: 0.9914 - specificity: 0.9967 - sensitivity: 0.9920 - precision: 0.9922 - val_loss: -0.9782 - val_accuracy: 0.9814 - val_dice_coef: 0.9782 - val_specificity: 0.9944 - val_sensitivity: 0.9711 - val_precision: 0.9862
# Epoch 61/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9934 - accuracy: 0.9890 - dice_coef: 0.9934 - specificity: 0.9976 - sensitivity: 0.9942 - precision: 0.9943
# Epoch 61: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9934 - accuracy: 0.9890 - dice_coef: 0.9934 - specificity: 0.9976 - sensitivity: 0.9942 - precision: 0.9943 - val_loss: -0.9792 - val_accuracy: 0.9820 - val_dice_coef: 0.9792 - val_specificity: 0.9939 - val_sensitivity: 0.9740 - val_precision: 0.9851
# Epoch 62/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9935 - accuracy: 0.9891 - dice_coef: 0.9935 - specificity: 0.9976 - sensitivity: 0.9944 - precision: 0.9944
# Epoch 62: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9935 - accuracy: 0.9891 - dice_coef: 0.9935 - specificity: 0.9976 - sensitivity: 0.9944 - precision: 0.9944 - val_loss: -0.9786 - val_accuracy: 0.9817 - val_dice_coef: 0.9786 - val_specificity: 0.9928 - val_sensitivity: 0.9754 - val_precision: 0.9826
# Epoch 63/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9928 - accuracy: 0.9889 - dice_coef: 0.9928 - specificity: 0.9973 - sensitivity: 0.9936 - precision: 0.9936
# Epoch 63: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 333ms/step - loss: -0.9928 - accuracy: 0.9889 - dice_coef: 0.9928 - specificity: 0.9973 - sensitivity: 0.9936 - precision: 0.9936 - val_loss: -0.9786 - val_accuracy: 0.9817 - val_dice_coef: 0.9786 - val_specificity: 0.9921 - val_sensitivity: 0.9770 - val_precision: 0.9808
# Epoch 64/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9923 - accuracy: 0.9887 - dice_coef: 0.9923 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9929
# Epoch 64: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 82s 331ms/step - loss: -0.9923 - accuracy: 0.9887 - dice_coef: 0.9923 - specificity: 0.9970 - sensitivity: 0.9931 - precision: 0.9929 - val_loss: -0.9799 - val_accuracy: 0.9823 - val_dice_coef: 0.9799 - val_specificity: 0.9934 - val_sensitivity: 0.9766 - val_precision: 0.9839
# Epoch 65/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9925 - accuracy: 0.9888 - dice_coef: 0.9925 - specificity: 0.9971 - sensitivity: 0.9933 - precision: 0.9932
# Epoch 65: val_dice_coef did not improve from 0.98052
# 249/249 [==============================] - 83s 332ms/step - loss: -0.9925 - accuracy: 0.9888 - dice_coef: 0.9925 - specificity: 0.9971 - sensitivity: 0.9933 - precision: 0.9932 - val_loss: -0.9797 - val_accuracy: 0.9821 - val_dice_coef: 0.9797 - val_specificity: 0.9931 - val_sensitivity: 0.9768 - val_precision: 0.9833

# %% [markdown]
# # Visualize results

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['specificity'], 'b', label='train specificity')
acc_ax.plot(results.history['val_specificity'], 'g', label='val specificity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['sensitivity'], 'b', label='train sensitivity')
acc_ax.plot(results.history['val_sensitivity'], 'g', label='val sensitivity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['precision'], 'b', label='train precision')
acc_ax.plot(results.history['val_precision'], 'g', label='val precision')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print(results.history['precision'][-1])
# Out:
# 0.9931812882423401

# %%
print(results.history['dice_coef'][-1])
# Out:
# 0.992533802986145

# %%
print(results.history['specificity'][-1])
# Out:
# 0.9971153140068054

# %% [markdown]
# testing values

# %%
# import os
test_list = os.listdir("test_set/")
print("The number of test data : ", len(test_list))
test_list[:5]
# Out:
# The number of test data :  335
# ['001_HC.png', '000_HC.png', '003_HC.png', '004_HC.png', '002_HC.png']

# %%
#used just for prediction, not as a checkpoint
model = tf.keras.models.load_model('best_model_224_res.h5', custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef':dice_coef,'specificity':specificity,'sensitivity':sensitivity,'precision':precision})

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
for i, item in enumerate(test_list):
    image = cv2.imread("test_set/" + item, 0)
    image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    X_test[i] = image
X_test = X_test[:,:,:,np.newaxis] / 255

y_pred = model.predict(X_test)
# Out:
# 11/11 [==============================] - 2s 161ms/step

# %%
def getbound(binary_mask):

  # draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  # draw[img > 0.5] = (255,) * 3
  kernelSize = (3,3)

  # gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(binary_mask, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  # gradient = cv2.cvtColor(gradient, cv2.COLOR_GRAY2RGB)
  return gradient


def fitEllipse(binary_mask, method="Direct"):
    assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0

    # print(binary_mask.shape)
   
    gradient  = getbound(binary_mask)

    # print(gradient.shape)

    points1 = np.argwhere(gradient > 0.5)  
    points2 = np.argwhere(binary_mask > 0.5)  

    points = points1
    # print(points1.shape)
    # print(points2.shape)

    if method == "AMS":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
    elif method == "Direct":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
    elif method == "Simple":
        (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

    return (xx, yy), (MA, ma), angle


# img = pred.copy()
# (xx, yy), (MA, ma), angle = fitEllipse(img)
# print((xx, yy), (MA, ma), angle)

# draw = np.zeros((*img.shape, 3), dtype=np.uint8)

# draw[img > 0.5] = (255,) * 3

# cv2.ellipse(
#     draw,
#     (int(yy), int(xx)),
#     (int(ma / 2), int(MA / 2)),
#     -angle,
#     0,
#     360,
#     color=(255, 0, 0),
#     thickness=2,
# )

for test, pred in zip(X_test[180:190],y_pred[180:190]):
    fig, ax = plt.subplots(1,4,figsize = (16,16))
    test = test.reshape((IMG_HEIGHT,IMG_WIDTH))

    pred = pred.reshape((IMG_HEIGHT,IMG_WIDTH))



    img = pred.copy()
    (xx, yy), (MA, ma), angle = fitEllipse(img)
    print((xx, yy), (MA, ma), angle)

    draw = np.zeros((*img.shape, 3), dtype=np.uint8)

    draw[img < 0.5] = (255,) * 3

    cv2.ellipse(
        draw,
        (int(yy), int(xx)),
        (int(ma / 2), int(MA / 2)),
        -angle,
        0,
        360,
        color=(255, 0, 0),
        thickness=2,
    )
    
    pred = pred>0.5
    pred = np.ma.masked_where(pred == 0, pred)

    ax[0].imshow(test, cmap = 'gray')

    ax[1].imshow(pred, cmap = 'gray')

    ax[2].imshow(test, cmap = 'gray', interpolation = 'none')
    ax[2].imshow(pred, cmap = 'jet', interpolation = 'none', alpha = 0.7)
    ax[3].imshow(draw,cmap='jet')
# Out:
# (108.11112213134766, 109.54448699951172) (152.83460998535156, 185.11557006835938) 85.69332122802734
# (114.83085632324219, 134.69488525390625) (54.20018768310547, 89.47705078125) 80.60630798339844
# (105.09628295898438, 84.7081527709961) (99.32860565185547, 137.0651397705078) 78.41011810302734
# (115.86592864990234, 100.84809112548828) (166.57374572753906, 189.72412109375) 87.3689193725586
# (114.0967788696289, 112.15789794921875) (123.79212951660156, 147.1931610107422) 87.56636047363281
# (107.37564849853516, 118.9029541015625) (62.7675895690918, 104.20272064208984) 94.54917907714844
# (126.22171783447266, 117.30368041992188) (95.00922393798828, 113.26615905761719) 74.48646545410156
# (109.92219543457031, 109.1847152709961) (87.83568572998047, 134.61878967285156) 100.92818450927734
# (123.13272094726562, 123.88982391357422) (175.24827575683594, 193.45654296875) 93.87444305419922
# (93.96442413330078, 99.01010131835938) (115.14590454101562, 135.75039672851562) 75.2899169921875

# %%
#ellipse fitting is performed on below displayed figure


def getbound(img):
  draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  draw[img > 0.5] = (255,) * 3

  kernelSize = (3,3)
  gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(draw, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  return gradient

# def fitEllipse(binary_mask, method="Direct"):
#     assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0
#     points = np.argwhere(binary_mask > 0.5)  

#     if method == "AMS":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
#     elif method == "Direct":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
#     elif method == "Simple":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

#     return (xx, yy), (MA, ma), angle


# # img = np.load("./output_samples/3.npy")
img = pred.copy()
# (xx, yy), (MA, ma), angle = fitEllipse(img)
# print((xx, yy), (MA, ma), angle)

draw = np.zeros((*img.shape, 3), dtype=np.uint8)

draw[img > 0.5] = (255,) * 3

# cv2.ellipse(
#     draw,
#     (int(yy), int(xx)),
#     (int(ma / 2), int(MA / 2)),
#     -angle,
#     0,
#     360,
#     color=(255, 0, 0),
#     thickness=2,
# )
gradient = getbound(img)
plt.imshow(gradient)
plt.show()

# %% [markdown]
# # Test Results

# %%
#evalutte test set
# # import os
# test_list = os.listdir("test_set/")
# # print("The number of test data : ", len(test_list))
# # test_list[:5]


# X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
# for i, item in enumerate(test_list):
#     image = cv2.imread("test_set/" + item, 0)
#     image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
#     X_test[i] = image

# X_test = X_test[:,:,:,np.newaxis] / 255
# #used just for prediction, not as a checkpoint
# model = tf.keras.models.load_model('best_model_224_res.h5', custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef':dice_coef,'specificity':specificity,'sensitivity':sensitivity,'precision':precision})
# model.compile(optimizer=Adam(lr = 1e-4), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])

# # evaluate_gen =
# # y_pred = model.predict(X_test)

# y_pred = model.predict(X_test)
