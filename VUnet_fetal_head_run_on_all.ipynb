# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush111111/unet-fet/blob/main/VUnet_fetal_head_run_on_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# # Imports and augmentation

# %%
# %cd drive/MyDrive/'Semester Project '/dataset_filled/
# %ls

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
trainPath = "training_set/"
testPath = "test_set/"
trainList = sorted(os.listdir(trainPath))
testList = sorted(os.listdir(testPath))


train_image = []
train_mask = []
for i, item in enumerate(trainList):
    if i % 2 == 0:
        train_image.append(item)
    else:
        train_mask.append(item)
print("Ultrasound training images in dataset {}".format(len(train_image)))
print("Ultrasound training masks in dataset  {}".format(len(train_mask)))

# %%
img = np.array(Image.open(trainPath+"006_HC.png"))
img_mask = np.array(Image.open(trainPath+"006_HC_Annotation.png"))
img_mask = np.ma.masked_where(img_mask == 0, img_mask)
print(len(img[0]))
#display images with mask
fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(img, cmap = 'gray')
ax[1].imshow(img_mask, cmap = 'gray')
ax[2].imshow(img, cmap = 'gray', interpolation = 'none')
ax[2].imshow(img_mask, cmap = 'gray', interpolation = 'none', alpha = 0.7)

# %%
#
X = []
y = []
for image, mask in zip(train_image, train_mask):
    X.append(np.array(Image.open(trainPath+image)))
    y.append(np.array(Image.open(trainPath+mask)))

X = np.array(X)
y = np.array(y)

print("X_shape : ", X.shape)
print("y_shape : ", y.shape)

# %%
print("X_shape : ", X[0].shape)
print("y_shape : ", y[0].shape)

# %%
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split

import tensorflow.keras
import tensorflow as tf
from tensorflow.keras import backend as K

K.set_image_data_format('channels_last')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Add
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
def Generator(X_list, y_list, batch_size = 16):
    c = 0

    while(True):
        X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')
        y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            image = X_list[i]
            # image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            mask =  y_list[i]
            # mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            X[i - c] = image
            y[i - c] = mask
        
        X = X / 255
        y = y / 255
        
        c += batch_size
        if(c+batch_size >= len(X_list)):
            c = 0
        yield X, y

def image_Generator(X_list, batch_size = 16):
    c = 0

    while(True):
        X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')
        # y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            image = X_list[i]
            # image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            # mask =  y_list[i]
            # mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            # mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            X[i - c] = image
            # y[i - c] = mask
        
        X = X / 255
        # y = y / 255
        
        c += batch_size
        if(c+batch_size >= len(X_list)):
            c = 0
        yield X

def mask_Generator(y_list, batch_size = 16):
    c = 0

    while(True):
        # X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')
        y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            # image = X_list[i]
            # image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            mask =  y_list[i]
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            # image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            # X[i - c] = image
            y[i - c] = mask
        
        # X = X / 255
        y = y / 255.0
        
        c += batch_size
        if(c+batch_size >= len(y_list)):
            c = 0
        yield y

def train_Generator(X_list, y_list, batch_size = 16):
    image_generator = image_Generator(X_list, batch_size = 16)
    mask_generator = mask_Generator(y_list, batch_size = 16)
    train_gen = zip(image_generator, mask_generator)

    for (img, mask) in train_gen:
    # img, mask = adjust_data(img, mask)
      yield (img,mask)

# %%
train_img_aug = []
train_mask_aug = []


for img, mask in zip(train_image, train_mask):
    img = cv2.imread(trainPath + img)
    mask = cv2.imread(trainPath + mask)
    train_img_aug.append(img)
    
    train_mask_aug.append(mask)
    img_lr = np.fliplr(img)
    mask_lr = np.fliplr(mask)

    img_up = np.flipud(img)
    mask_up = np.flipud(mask)

    img_lr_up = np.flipud(img_lr)
    mask_lr_up = np.flipud(mask_lr)

    img_up_lr = np.fliplr(img_up)
    mask_up_lr = np.fliplr(mask_up)

    train_img_aug.append(img_lr)
    train_mask_aug.append(mask_lr)

    train_img_aug.append(img_up)
    train_mask_aug.append(mask_up)

    train_img_aug.append(img_lr_up)
    train_mask_aug.append(mask_lr_up)

    train_img_aug.append(img_up_lr)
    train_mask_aug.append(mask_up_lr)

print(np.array(train_image).shape)
print(np.array(train_img_aug).shape)

# %% [markdown]
# # Model Training

# %%
# define building blocks
def BatchnormActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_block(x, filters, size, strides=(1,1), padding="same", activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchnormActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchnormActivate(blockInput)
    x = conv_block(x, num_filters, (3,3))
    x = conv_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchnormActivate(x)
    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# def conv_block(x, filters, size, strides=(1,1), padding="same", activation=True):



# def conv_block(input, num_filters):
#     x = Conv2D(num_filters, 3, padding="same")(input)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)
 
#     x = Conv2D(num_filters, 3, padding="same")(x)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)
 
#     return x

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    # convert to 2D before comparing results
    # y_true = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def jac_distance(y_true, y_pred ):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    # intersection = K.sum(y_true_f * y_pred_f)

    intersection = K.sum(K.abs(y_true_f * y_pred_f), axis=-1)
    sum_ = K.sum(K.abs(y_true_f) + K.abs(y_pred_f), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    # print(jac)
    return jac

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
from tensorflow.keras.applications import VGG16

def build_Unet(input_shape, start_neurons, DropoutRatio = 0.5):
    
    input_layer = Input(input_shape) #224 x  224 x 1


    """ Encoder """
    vgg16 = VGG16(include_top=False, weights="imagenet", input_tensor=input_layer,input_shape=(224,224,3))
    for layer in vgg16.layers: #use them as they are
      layer.trainable = False
    skip1 = vgg16.get_layer("block1_conv2").output
    skip2 = vgg16.get_layer("block2_conv2").output
    skip3 = vgg16.get_layer("block3_conv3").output
    skip4 = vgg16.get_layer("block4_conv3").output


    # conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)  # 224 x  224 x 16
    # conv1 = residual_block(conv1,start_neurons * 1)
    # conv1 = residual_block(conv1,start_neurons * 1, True)
    # pool1 = MaxPooling2D((2, 2))(conv1)
    # #pool1 = Dropout(DropoutRatio/2)(pool1)

    # conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1) # 112 x 112 x 32
    # conv2 = residual_block(conv2,start_neurons * 2)
    # conv2 = residual_block(conv2,start_neurons * 2, True)
    # pool2 = MaxPooling2D((2, 2))(conv2)
    # #pool2 = Dropout(DropoutRatio)(pool2)

    # conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2) #56 x 56 x 64
    # conv3 = residual_block(conv3,start_neurons * 4)
    # conv3 = residual_block(conv3,start_neurons * 4, True)
    # pool3 = MaxPooling2D((2, 2))(conv3)
    # #pool3 = Dropout(DropoutRatio)(pool3)

    # conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)# 28 x 28 x 128
    # conv4 = residual_block(conv4,start_neurons * 8)
    # conv4 = residual_block(conv4,start_neurons * 8, True)
    # pool4 = MaxPooling2D((2, 2))(conv4)
    # #pool4 = Dropout(DropoutRatio)(pool4)


    """ Bridge """

    # convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)#14 x 14 x 256
    # convm = residual_block(convm,start_neurons * 16)
    # convm = residual_block(convm,start_neurons * 16, True)
    b1 = vgg16.get_layer("block5_conv3").output


    """ Decoder """
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(b1) # 28 x 28 x 128
    uconv4 = concatenate([deconv4, skip4])
    #uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4) # 56 x 56 x 64
    uconv3 = concatenate([deconv3, skip3])    
    #uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3) #112 x 112 x 32
    uconv2 = concatenate([deconv2, skip2])
        
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2) # 224 x 224 x 16
    uconv1 = concatenate([deconv1, skip1])
    
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1) 
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    """ Output """
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1) # 244 x 224 x 1
    
    model = Model(inputs=[input_layer], outputs=[output_layer])
    return model

# %%
#split training data
#CHANGED JUST FOR GETTING THE OUTPUT

#test_size changed from 0.3 t0 0.2 
X_train, X_val, y_train, y_val = train_test_split(train_img_aug, train_mask_aug, test_size = 0.01, random_state = 1)

# set training parameters
epochs = 65
batch_size = 16
steps_per_epoch = int(len(X_train) / batch_size)
validation_steps = int(len(X_val) / batch_size)

train_gen = train_Generator(X_train, y_train, batch_size = batch_size)
val_gen = train_Generator(X_val, y_val, batch_size = batch_size)

# initialize our model
# inputs = Input((IMG_HEIGHT, IMG_WIDTH, 1))
# output_layer = build_Unet(inputs, 16, 0.5)

# Define callbacks to save model with best val_dice_coef
checkpointer = ModelCheckpoint(filepath = 'best_model_224_res.h5', monitor='val_dice_coef', verbose=1, save_best_only=True, mode='max')
# model = Model(inputs=[inputs], outputs=[output_layer])

model = build_Unet((IMG_HEIGHT, IMG_WIDTH,3),16, 0.5)
model.compile(optimizer=Adam(lr = 5e-5), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])
model.summary()

# %%
# tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=False)

# %%
results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# Out:
# <ipython-input-24-350936afeb50>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer])
# Epoch 1/65
# 249/249 [==============================] - ETA: 0s - loss: -0.6902 - accuracy: 0.8928 - dice_coef: 0.6902 - specificity: 0.9353 - sensitivity: 0.8049 - precision: 0.7971
# Epoch 1: val_dice_coef improved from -inf to 0.87353, saving model to best_model_224_res.h5
# 249/249 [==============================] - 100s 334ms/step - loss: -0.6902 - accuracy: 0.8928 - dice_coef: 0.6902 - specificity: 0.9353 - sensitivity: 0.8049 - precision: 0.7971 - val_loss: -0.8735 - val_accuracy: 0.9744 - val_dice_coef: 0.8735 - val_specificity: 0.9816 - val_sensitivity: 0.9726 - val_precision: 0.9557
# Epoch 2/65
# 249/249 [==============================] - ETA: 0s - loss: -0.8537 - accuracy: 0.9745 - dice_coef: 0.8537 - specificity: 0.9805 - sensitivity: 0.9764 - precision: 0.9519
# Epoch 2: val_dice_coef improved from 0.87353 to 0.87773, saving model to best_model_224_res.h5
# 249/249 [==============================] - 81s 326ms/step - loss: -0.8537 - accuracy: 0.9745 - dice_coef: 0.8537 - specificity: 0.9805 - sensitivity: 0.9764 - precision: 0.9519 - val_loss: -0.8777 - val_accuracy: 0.9777 - val_dice_coef: 0.8777 - val_specificity: 0.9872 - val_sensitivity: 0.9705 - val_precision: 0.9684
# Epoch 3/65
# 249/249 [==============================] - ETA: 0s - loss: -0.8862 - accuracy: 0.9775 - dice_coef: 0.8862 - specificity: 0.9841 - sensitivity: 0.9786 - precision: 0.9607
# Epoch 3: val_dice_coef improved from 0.87773 to 0.89633, saving model to best_model_224_res.h5
# 249/249 [==============================] - 80s 321ms/step - loss: -0.8862 - accuracy: 0.9775 - dice_coef: 0.8862 - specificity: 0.9841 - sensitivity: 0.9786 - precision: 0.9607 - val_loss: -0.8963 - val_accuracy: 0.9790 - val_dice_coef: 0.8963 - val_specificity: 0.9885 - val_sensitivity: 0.9726 - val_precision: 0.9714
# Epoch 4/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9084 - accuracy: 0.9791 - dice_coef: 0.9084 - specificity: 0.9863 - sensitivity: 0.9794 - precision: 0.9660
# Epoch 4: val_dice_coef improved from 0.89633 to 0.91507, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 319ms/step - loss: -0.9084 - accuracy: 0.9791 - dice_coef: 0.9084 - specificity: 0.9863 - sensitivity: 0.9794 - precision: 0.9660 - val_loss: -0.9151 - val_accuracy: 0.9792 - val_dice_coef: 0.9151 - val_specificity: 0.9867 - val_sensitivity: 0.9780 - val_precision: 0.9675
# Epoch 5/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9246 - accuracy: 0.9802 - dice_coef: 0.9246 - specificity: 0.9878 - sensitivity: 0.9800 - precision: 0.9698
# Epoch 5: val_dice_coef improved from 0.91507 to 0.92630, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 319ms/step - loss: -0.9246 - accuracy: 0.9802 - dice_coef: 0.9246 - specificity: 0.9878 - sensitivity: 0.9800 - precision: 0.9698 - val_loss: -0.9263 - val_accuracy: 0.9795 - val_dice_coef: 0.9263 - val_specificity: 0.9908 - val_sensitivity: 0.9695 - val_precision: 0.9771
# Epoch 6/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9369 - accuracy: 0.9811 - dice_coef: 0.9369 - specificity: 0.9890 - sensitivity: 0.9808 - precision: 0.9727
# Epoch 6: val_dice_coef improved from 0.92630 to 0.93892, saving model to best_model_224_res.h5
# 249/249 [==============================] - 80s 320ms/step - loss: -0.9369 - accuracy: 0.9811 - dice_coef: 0.9369 - specificity: 0.9890 - sensitivity: 0.9808 - precision: 0.9727 - val_loss: -0.9389 - val_accuracy: 0.9802 - val_dice_coef: 0.9389 - val_specificity: 0.9900 - val_sensitivity: 0.9745 - val_precision: 0.9752
# Epoch 7/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9461 - accuracy: 0.9818 - dice_coef: 0.9461 - specificity: 0.9898 - sensitivity: 0.9812 - precision: 0.9749
# Epoch 7: val_dice_coef improved from 0.93892 to 0.94568, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 316ms/step - loss: -0.9461 - accuracy: 0.9818 - dice_coef: 0.9461 - specificity: 0.9898 - sensitivity: 0.9812 - precision: 0.9749 - val_loss: -0.9457 - val_accuracy: 0.9798 - val_dice_coef: 0.9457 - val_specificity: 0.9916 - val_sensitivity: 0.9695 - val_precision: 0.9792
# Epoch 8/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9531 - accuracy: 0.9822 - dice_coef: 0.9531 - specificity: 0.9904 - sensitivity: 0.9814 - precision: 0.9763
# Epoch 8: val_dice_coef improved from 0.94568 to 0.95182, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 319ms/step - loss: -0.9531 - accuracy: 0.9822 - dice_coef: 0.9531 - specificity: 0.9904 - sensitivity: 0.9814 - precision: 0.9763 - val_loss: -0.9518 - val_accuracy: 0.9803 - val_dice_coef: 0.9518 - val_specificity: 0.9905 - val_sensitivity: 0.9742 - val_precision: 0.9767
# Epoch 9/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9591 - accuracy: 0.9828 - dice_coef: 0.9591 - specificity: 0.9911 - sensitivity: 0.9823 - precision: 0.9781
# Epoch 9: val_dice_coef improved from 0.95182 to 0.95640, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9591 - accuracy: 0.9828 - dice_coef: 0.9591 - specificity: 0.9911 - sensitivity: 0.9823 - precision: 0.9781 - val_loss: -0.9564 - val_accuracy: 0.9806 - val_dice_coef: 0.9564 - val_specificity: 0.9918 - val_sensitivity: 0.9722 - val_precision: 0.9797
# Epoch 10/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9640 - accuracy: 0.9834 - dice_coef: 0.9640 - specificity: 0.9918 - sensitivity: 0.9831 - precision: 0.9799
# Epoch 10: val_dice_coef improved from 0.95640 to 0.95997, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9640 - accuracy: 0.9834 - dice_coef: 0.9640 - specificity: 0.9918 - sensitivity: 0.9831 - precision: 0.9799 - val_loss: -0.9600 - val_accuracy: 0.9808 - val_dice_coef: 0.9600 - val_specificity: 0.9918 - val_sensitivity: 0.9732 - val_precision: 0.9797
# Epoch 11/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9680 - accuracy: 0.9839 - dice_coef: 0.9680 - specificity: 0.9923 - sensitivity: 0.9838 - precision: 0.9812
# Epoch 11: val_dice_coef improved from 0.95997 to 0.96235, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9680 - accuracy: 0.9839 - dice_coef: 0.9680 - specificity: 0.9923 - sensitivity: 0.9838 - precision: 0.9812 - val_loss: -0.9623 - val_accuracy: 0.9806 - val_dice_coef: 0.9623 - val_specificity: 0.9928 - val_sensitivity: 0.9702 - val_precision: 0.9821
# Epoch 12/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9712 - accuracy: 0.9843 - dice_coef: 0.9712 - specificity: 0.9927 - sensitivity: 0.9843 - precision: 0.9823
# Epoch 12: val_dice_coef improved from 0.96235 to 0.96571, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9712 - accuracy: 0.9843 - dice_coef: 0.9712 - specificity: 0.9927 - sensitivity: 0.9843 - precision: 0.9823 - val_loss: -0.9657 - val_accuracy: 0.9810 - val_dice_coef: 0.9657 - val_specificity: 0.9920 - val_sensitivity: 0.9736 - val_precision: 0.9804
# Epoch 13/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9738 - accuracy: 0.9846 - dice_coef: 0.9738 - specificity: 0.9930 - sensitivity: 0.9848 - precision: 0.9831
# Epoch 13: val_dice_coef improved from 0.96571 to 0.96676, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9738 - accuracy: 0.9846 - dice_coef: 0.9738 - specificity: 0.9930 - sensitivity: 0.9848 - precision: 0.9831 - val_loss: -0.9668 - val_accuracy: 0.9805 - val_dice_coef: 0.9668 - val_specificity: 0.9918 - val_sensitivity: 0.9724 - val_precision: 0.9799
# Epoch 14/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9758 - accuracy: 0.9848 - dice_coef: 0.9758 - specificity: 0.9933 - sensitivity: 0.9851 - precision: 0.9838
# Epoch 14: val_dice_coef improved from 0.96676 to 0.96909, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9758 - accuracy: 0.9848 - dice_coef: 0.9758 - specificity: 0.9933 - sensitivity: 0.9851 - precision: 0.9838 - val_loss: -0.9691 - val_accuracy: 0.9807 - val_dice_coef: 0.9691 - val_specificity: 0.9903 - val_sensitivity: 0.9772 - val_precision: 0.9763
# Epoch 15/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9771 - accuracy: 0.9847 - dice_coef: 0.9771 - specificity: 0.9932 - sensitivity: 0.9850 - precision: 0.9837
# Epoch 15: val_dice_coef improved from 0.96909 to 0.97068, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 315ms/step - loss: -0.9771 - accuracy: 0.9847 - dice_coef: 0.9771 - specificity: 0.9932 - sensitivity: 0.9850 - precision: 0.9837 - val_loss: -0.9707 - val_accuracy: 0.9810 - val_dice_coef: 0.9707 - val_specificity: 0.9920 - val_sensitivity: 0.9742 - val_precision: 0.9803
# Epoch 16/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9790 - accuracy: 0.9852 - dice_coef: 0.9790 - specificity: 0.9937 - sensitivity: 0.9858 - precision: 0.9848
# Epoch 16: val_dice_coef improved from 0.97068 to 0.97231, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 317ms/step - loss: -0.9790 - accuracy: 0.9852 - dice_coef: 0.9790 - specificity: 0.9937 - sensitivity: 0.9858 - precision: 0.9848 - val_loss: -0.9723 - val_accuracy: 0.9813 - val_dice_coef: 0.9723 - val_specificity: 0.9918 - val_sensitivity: 0.9756 - val_precision: 0.9801
# Epoch 17/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9801 - accuracy: 0.9853 - dice_coef: 0.9801 - specificity: 0.9938 - sensitivity: 0.9859 - precision: 0.9852
# Epoch 17: val_dice_coef improved from 0.97231 to 0.97277, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9801 - accuracy: 0.9853 - dice_coef: 0.9801 - specificity: 0.9938 - sensitivity: 0.9859 - precision: 0.9852 - val_loss: -0.9728 - val_accuracy: 0.9810 - val_dice_coef: 0.9728 - val_specificity: 0.9893 - val_sensitivity: 0.9807 - val_precision: 0.9742
# Epoch 18/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9807 - accuracy: 0.9852 - dice_coef: 0.9807 - specificity: 0.9937 - sensitivity: 0.9857 - precision: 0.9849
# Epoch 18: val_dice_coef did not improve from 0.97277
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9807 - accuracy: 0.9852 - dice_coef: 0.9807 - specificity: 0.9937 - sensitivity: 0.9857 - precision: 0.9849 - val_loss: -0.9727 - val_accuracy: 0.9807 - val_dice_coef: 0.9727 - val_specificity: 0.9911 - val_sensitivity: 0.9753 - val_precision: 0.9783
# Epoch 19/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9820 - accuracy: 0.9855 - dice_coef: 0.9820 - specificity: 0.9940 - sensitivity: 0.9864 - precision: 0.9857
# Epoch 19: val_dice_coef improved from 0.97277 to 0.97449, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9820 - accuracy: 0.9855 - dice_coef: 0.9820 - specificity: 0.9940 - sensitivity: 0.9864 - precision: 0.9857 - val_loss: -0.9745 - val_accuracy: 0.9814 - val_dice_coef: 0.9745 - val_specificity: 0.9921 - val_sensitivity: 0.9755 - val_precision: 0.9806
# Epoch 20/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9829 - accuracy: 0.9857 - dice_coef: 0.9829 - specificity: 0.9941 - sensitivity: 0.9867 - precision: 0.9860
# Epoch 20: val_dice_coef improved from 0.97449 to 0.97494, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9829 - accuracy: 0.9857 - dice_coef: 0.9829 - specificity: 0.9941 - sensitivity: 0.9867 - precision: 0.9860 - val_loss: -0.9749 - val_accuracy: 0.9813 - val_dice_coef: 0.9749 - val_specificity: 0.9926 - val_sensitivity: 0.9739 - val_precision: 0.9819
# Epoch 21/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9831 - accuracy: 0.9856 - dice_coef: 0.9831 - specificity: 0.9940 - sensitivity: 0.9865 - precision: 0.9858
# Epoch 21: val_dice_coef improved from 0.97494 to 0.97599, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9831 - accuracy: 0.9856 - dice_coef: 0.9831 - specificity: 0.9940 - sensitivity: 0.9865 - precision: 0.9858 - val_loss: -0.9760 - val_accuracy: 0.9816 - val_dice_coef: 0.9760 - val_specificity: 0.9918 - val_sensitivity: 0.9770 - val_precision: 0.9801
# Epoch 22/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9840 - accuracy: 0.9858 - dice_coef: 0.9840 - specificity: 0.9943 - sensitivity: 0.9869 - precision: 0.9865
# Epoch 22: val_dice_coef improved from 0.97599 to 0.97602, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9840 - accuracy: 0.9858 - dice_coef: 0.9840 - specificity: 0.9943 - sensitivity: 0.9869 - precision: 0.9865 - val_loss: -0.9760 - val_accuracy: 0.9813 - val_dice_coef: 0.9760 - val_specificity: 0.9890 - val_sensitivity: 0.9830 - val_precision: 0.9734
# Epoch 23/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9848 - accuracy: 0.9861 - dice_coef: 0.9848 - specificity: 0.9945 - sensitivity: 0.9874 - precision: 0.9869
# Epoch 23: val_dice_coef did not improve from 0.97602
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9848 - accuracy: 0.9861 - dice_coef: 0.9848 - specificity: 0.9945 - sensitivity: 0.9874 - precision: 0.9869 - val_loss: -0.9758 - val_accuracy: 0.9810 - val_dice_coef: 0.9758 - val_specificity: 0.9889 - val_sensitivity: 0.9820 - val_precision: 0.9733
# Epoch 24/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9848 - accuracy: 0.9859 - dice_coef: 0.9848 - specificity: 0.9944 - sensitivity: 0.9871 - precision: 0.9867
# Epoch 24: val_dice_coef did not improve from 0.97602
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9848 - accuracy: 0.9859 - dice_coef: 0.9848 - specificity: 0.9944 - sensitivity: 0.9871 - precision: 0.9867 - val_loss: -0.9747 - val_accuracy: 0.9804 - val_dice_coef: 0.9747 - val_specificity: 0.9908 - val_sensitivity: 0.9752 - val_precision: 0.9776
# Epoch 25/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9858 - accuracy: 0.9863 - dice_coef: 0.9858 - specificity: 0.9947 - sensitivity: 0.9878 - precision: 0.9875
# Epoch 25: val_dice_coef did not improve from 0.97602
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9858 - accuracy: 0.9863 - dice_coef: 0.9858 - specificity: 0.9947 - sensitivity: 0.9878 - precision: 0.9875 - val_loss: -0.9753 - val_accuracy: 0.9807 - val_dice_coef: 0.9753 - val_specificity: 0.9905 - val_sensitivity: 0.9768 - val_precision: 0.9770
# Epoch 26/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9866 - accuracy: 0.9866 - dice_coef: 0.9866 - specificity: 0.9950 - sensitivity: 0.9885 - precision: 0.9881
# Epoch 26: val_dice_coef did not improve from 0.97602
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9866 - accuracy: 0.9866 - dice_coef: 0.9866 - specificity: 0.9950 - sensitivity: 0.9885 - precision: 0.9881 - val_loss: -0.9757 - val_accuracy: 0.9808 - val_dice_coef: 0.9757 - val_specificity: 0.9898 - val_sensitivity: 0.9790 - val_precision: 0.9753
# Epoch 27/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9877 - accuracy: 0.9870 - dice_coef: 0.9877 - specificity: 0.9954 - sensitivity: 0.9894 - precision: 0.9891
# Epoch 27: val_dice_coef improved from 0.97602 to 0.97624, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 316ms/step - loss: -0.9877 - accuracy: 0.9870 - dice_coef: 0.9877 - specificity: 0.9954 - sensitivity: 0.9894 - precision: 0.9891 - val_loss: -0.9762 - val_accuracy: 0.9809 - val_dice_coef: 0.9762 - val_specificity: 0.9884 - val_sensitivity: 0.9827 - val_precision: 0.9723
# Epoch 28/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9883 - accuracy: 0.9872 - dice_coef: 0.9883 - specificity: 0.9956 - sensitivity: 0.9898 - precision: 0.9896
# Epoch 28: val_dice_coef improved from 0.97624 to 0.97681, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9883 - accuracy: 0.9872 - dice_coef: 0.9883 - specificity: 0.9956 - sensitivity: 0.9898 - precision: 0.9896 - val_loss: -0.9768 - val_accuracy: 0.9812 - val_dice_coef: 0.9768 - val_specificity: 0.9897 - val_sensitivity: 0.9806 - val_precision: 0.9752
# Epoch 29/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9884 - accuracy: 0.9872 - dice_coef: 0.9884 - specificity: 0.9956 - sensitivity: 0.9898 - precision: 0.9895
# Epoch 29: val_dice_coef improved from 0.97681 to 0.97700, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9884 - accuracy: 0.9872 - dice_coef: 0.9884 - specificity: 0.9956 - sensitivity: 0.9898 - precision: 0.9895 - val_loss: -0.9770 - val_accuracy: 0.9812 - val_dice_coef: 0.9770 - val_specificity: 0.9901 - val_sensitivity: 0.9800 - val_precision: 0.9760
# Epoch 30/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9878 - accuracy: 0.9869 - dice_coef: 0.9878 - specificity: 0.9953 - sensitivity: 0.9891 - precision: 0.9888
# Epoch 30: val_dice_coef did not improve from 0.97700
# 249/249 [==============================] - 76s 307ms/step - loss: -0.9878 - accuracy: 0.9869 - dice_coef: 0.9878 - specificity: 0.9953 - sensitivity: 0.9891 - precision: 0.9888 - val_loss: -0.9764 - val_accuracy: 0.9809 - val_dice_coef: 0.9764 - val_specificity: 0.9929 - val_sensitivity: 0.9721 - val_precision: 0.9826
# Epoch 31/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9880 - accuracy: 0.9869 - dice_coef: 0.9880 - specificity: 0.9953 - sensitivity: 0.9892 - precision: 0.9890
# Epoch 31: val_dice_coef improved from 0.97700 to 0.97714, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9880 - accuracy: 0.9869 - dice_coef: 0.9880 - specificity: 0.9953 - sensitivity: 0.9892 - precision: 0.9890 - val_loss: -0.9771 - val_accuracy: 0.9813 - val_dice_coef: 0.9771 - val_specificity: 0.9939 - val_sensitivity: 0.9711 - val_precision: 0.9849
# Epoch 32/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9883 - accuracy: 0.9870 - dice_coef: 0.9883 - specificity: 0.9954 - sensitivity: 0.9894 - precision: 0.9892
# Epoch 32: val_dice_coef did not improve from 0.97714
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9883 - accuracy: 0.9870 - dice_coef: 0.9883 - specificity: 0.9954 - sensitivity: 0.9894 - precision: 0.9892 - val_loss: -0.9753 - val_accuracy: 0.9803 - val_dice_coef: 0.9753 - val_specificity: 0.9955 - val_sensitivity: 0.9636 - val_precision: 0.9888
# Epoch 33/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9888 - accuracy: 0.9872 - dice_coef: 0.9888 - specificity: 0.9956 - sensitivity: 0.9897 - precision: 0.9896
# Epoch 33: val_dice_coef did not improve from 0.97714
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9888 - accuracy: 0.9872 - dice_coef: 0.9888 - specificity: 0.9956 - sensitivity: 0.9897 - precision: 0.9896 - val_loss: -0.9766 - val_accuracy: 0.9809 - val_dice_coef: 0.9766 - val_specificity: 0.9946 - val_sensitivity: 0.9682 - val_precision: 0.9865
# Epoch 34/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9897 - accuracy: 0.9876 - dice_coef: 0.9897 - specificity: 0.9960 - sensitivity: 0.9907 - precision: 0.9905
# Epoch 34: val_dice_coef improved from 0.97714 to 0.97805, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9897 - accuracy: 0.9876 - dice_coef: 0.9897 - specificity: 0.9960 - sensitivity: 0.9907 - precision: 0.9905 - val_loss: -0.9780 - val_accuracy: 0.9816 - val_dice_coef: 0.9780 - val_specificity: 0.9928 - val_sensitivity: 0.9751 - val_precision: 0.9823
# Epoch 35/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9900 - accuracy: 0.9877 - dice_coef: 0.9900 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9908
# Epoch 35: val_dice_coef improved from 0.97805 to 0.97836, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9900 - accuracy: 0.9877 - dice_coef: 0.9900 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9908 - val_loss: -0.9784 - val_accuracy: 0.9818 - val_dice_coef: 0.9784 - val_specificity: 0.9926 - val_sensitivity: 0.9761 - val_precision: 0.9819
# Epoch 36/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9895 - accuracy: 0.9875 - dice_coef: 0.9895 - specificity: 0.9958 - sensitivity: 0.9904 - precision: 0.9901
# Epoch 36: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9895 - accuracy: 0.9875 - dice_coef: 0.9895 - specificity: 0.9958 - sensitivity: 0.9904 - precision: 0.9901 - val_loss: -0.9778 - val_accuracy: 0.9815 - val_dice_coef: 0.9778 - val_specificity: 0.9944 - val_sensitivity: 0.9707 - val_precision: 0.9861
# Epoch 37/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9885 - accuracy: 0.9870 - dice_coef: 0.9885 - specificity: 0.9954 - sensitivity: 0.9893 - precision: 0.9890
# Epoch 37: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9885 - accuracy: 0.9870 - dice_coef: 0.9885 - specificity: 0.9954 - sensitivity: 0.9893 - precision: 0.9890 - val_loss: -0.9762 - val_accuracy: 0.9806 - val_dice_coef: 0.9762 - val_specificity: 0.9943 - val_sensitivity: 0.9675 - val_precision: 0.9860
# Epoch 38/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9884 - accuracy: 0.9869 - dice_coef: 0.9884 - specificity: 0.9954 - sensitivity: 0.9890 - precision: 0.9890
# Epoch 38: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9884 - accuracy: 0.9869 - dice_coef: 0.9884 - specificity: 0.9954 - sensitivity: 0.9890 - precision: 0.9890 - val_loss: -0.9763 - val_accuracy: 0.9807 - val_dice_coef: 0.9763 - val_specificity: 0.9934 - val_sensitivity: 0.9700 - val_precision: 0.9836
# Epoch 39/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9887 - accuracy: 0.9871 - dice_coef: 0.9887 - specificity: 0.9955 - sensitivity: 0.9893 - precision: 0.9893
# Epoch 39: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9887 - accuracy: 0.9871 - dice_coef: 0.9887 - specificity: 0.9955 - sensitivity: 0.9893 - precision: 0.9893 - val_loss: -0.9766 - val_accuracy: 0.9808 - val_dice_coef: 0.9766 - val_specificity: 0.9925 - val_sensitivity: 0.9726 - val_precision: 0.9815
# Epoch 40/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9889 - accuracy: 0.9872 - dice_coef: 0.9889 - specificity: 0.9955 - sensitivity: 0.9896 - precision: 0.9894
# Epoch 40: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9889 - accuracy: 0.9872 - dice_coef: 0.9889 - specificity: 0.9955 - sensitivity: 0.9896 - precision: 0.9894 - val_loss: -0.9774 - val_accuracy: 0.9811 - val_dice_coef: 0.9774 - val_specificity: 0.9901 - val_sensitivity: 0.9796 - val_precision: 0.9760
# Epoch 41/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9899 - accuracy: 0.9876 - dice_coef: 0.9899 - specificity: 0.9959 - sensitivity: 0.9906 - precision: 0.9904
# Epoch 41: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9899 - accuracy: 0.9876 - dice_coef: 0.9899 - specificity: 0.9959 - sensitivity: 0.9906 - precision: 0.9904 - val_loss: -0.9778 - val_accuracy: 0.9814 - val_dice_coef: 0.9778 - val_specificity: 0.9924 - val_sensitivity: 0.9751 - val_precision: 0.9813
# Epoch 42/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9901 - accuracy: 0.9877 - dice_coef: 0.9901 - specificity: 0.9960 - sensitivity: 0.9909 - precision: 0.9906
# Epoch 42: val_dice_coef improved from 0.97836 to 0.97836, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9901 - accuracy: 0.9877 - dice_coef: 0.9901 - specificity: 0.9960 - sensitivity: 0.9909 - precision: 0.9906 - val_loss: -0.9784 - val_accuracy: 0.9816 - val_dice_coef: 0.9784 - val_specificity: 0.9911 - val_sensitivity: 0.9791 - val_precision: 0.9783
# Epoch 43/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9896 - accuracy: 0.9874 - dice_coef: 0.9896 - specificity: 0.9958 - sensitivity: 0.9902 - precision: 0.9901
# Epoch 43: val_dice_coef did not improve from 0.97836
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9896 - accuracy: 0.9874 - dice_coef: 0.9896 - specificity: 0.9958 - sensitivity: 0.9902 - precision: 0.9901 - val_loss: -0.9778 - val_accuracy: 0.9813 - val_dice_coef: 0.9778 - val_specificity: 0.9915 - val_sensitivity: 0.9770 - val_precision: 0.9793
# Epoch 44/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9888 - accuracy: 0.9871 - dice_coef: 0.9888 - specificity: 0.9955 - sensitivity: 0.9894 - precision: 0.9893
# Epoch 44: val_dice_coef improved from 0.97836 to 0.97898, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 314ms/step - loss: -0.9888 - accuracy: 0.9871 - dice_coef: 0.9888 - specificity: 0.9955 - sensitivity: 0.9894 - precision: 0.9893 - val_loss: -0.9790 - val_accuracy: 0.9819 - val_dice_coef: 0.9790 - val_specificity: 0.9911 - val_sensitivity: 0.9802 - val_precision: 0.9784
# Epoch 45/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9893 - accuracy: 0.9873 - dice_coef: 0.9893 - specificity: 0.9957 - sensitivity: 0.9899 - precision: 0.9897
# Epoch 45: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9893 - accuracy: 0.9873 - dice_coef: 0.9893 - specificity: 0.9957 - sensitivity: 0.9899 - precision: 0.9897 - val_loss: -0.9786 - val_accuracy: 0.9816 - val_dice_coef: 0.9786 - val_specificity: 0.9899 - val_sensitivity: 0.9822 - val_precision: 0.9756
# Epoch 46/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9903 - accuracy: 0.9877 - dice_coef: 0.9903 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9908
# Epoch 46: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9903 - accuracy: 0.9877 - dice_coef: 0.9903 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9908 - val_loss: -0.9784 - val_accuracy: 0.9816 - val_dice_coef: 0.9784 - val_specificity: 0.9907 - val_sensitivity: 0.9799 - val_precision: 0.9775
# Epoch 47/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9906 - accuracy: 0.9879 - dice_coef: 0.9906 - specificity: 0.9962 - sensitivity: 0.9913 - precision: 0.9911
# Epoch 47: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9906 - accuracy: 0.9879 - dice_coef: 0.9906 - specificity: 0.9962 - sensitivity: 0.9913 - precision: 0.9911 - val_loss: -0.9780 - val_accuracy: 0.9813 - val_dice_coef: 0.9780 - val_specificity: 0.9899 - val_sensitivity: 0.9810 - val_precision: 0.9756
# Epoch 48/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9903 - accuracy: 0.9877 - dice_coef: 0.9903 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9908
# Epoch 48: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9903 - accuracy: 0.9877 - dice_coef: 0.9903 - specificity: 0.9961 - sensitivity: 0.9909 - precision: 0.9908 - val_loss: -0.9774 - val_accuracy: 0.9810 - val_dice_coef: 0.9774 - val_specificity: 0.9900 - val_sensitivity: 0.9796 - val_precision: 0.9757
# Epoch 49/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9898 - accuracy: 0.9875 - dice_coef: 0.9898 - specificity: 0.9959 - sensitivity: 0.9903 - precision: 0.9903
# Epoch 49: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9898 - accuracy: 0.9875 - dice_coef: 0.9898 - specificity: 0.9959 - sensitivity: 0.9903 - precision: 0.9903 - val_loss: -0.9767 - val_accuracy: 0.9806 - val_dice_coef: 0.9767 - val_specificity: 0.9893 - val_sensitivity: 0.9798 - val_precision: 0.9742
# Epoch 50/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9896 - accuracy: 0.9875 - dice_coef: 0.9896 - specificity: 0.9958 - sensitivity: 0.9902 - precision: 0.9900
# Epoch 50: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9896 - accuracy: 0.9875 - dice_coef: 0.9896 - specificity: 0.9958 - sensitivity: 0.9902 - precision: 0.9900 - val_loss: -0.9769 - val_accuracy: 0.9808 - val_dice_coef: 0.9769 - val_specificity: 0.9908 - val_sensitivity: 0.9767 - val_precision: 0.9777
# Epoch 51/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9901 - accuracy: 0.9877 - dice_coef: 0.9901 - specificity: 0.9960 - sensitivity: 0.9907 - precision: 0.9905
# Epoch 51: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9901 - accuracy: 0.9877 - dice_coef: 0.9901 - specificity: 0.9960 - sensitivity: 0.9907 - precision: 0.9905 - val_loss: -0.9783 - val_accuracy: 0.9815 - val_dice_coef: 0.9783 - val_specificity: 0.9919 - val_sensitivity: 0.9769 - val_precision: 0.9802
# Epoch 52/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9906 - accuracy: 0.9879 - dice_coef: 0.9906 - specificity: 0.9962 - sensitivity: 0.9913 - precision: 0.9911
# Epoch 52: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9906 - accuracy: 0.9879 - dice_coef: 0.9906 - specificity: 0.9962 - sensitivity: 0.9913 - precision: 0.9911 - val_loss: -0.9778 - val_accuracy: 0.9813 - val_dice_coef: 0.9778 - val_specificity: 0.9927 - val_sensitivity: 0.9739 - val_precision: 0.9822
# Epoch 53/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9911 - accuracy: 0.9881 - dice_coef: 0.9911 - specificity: 0.9965 - sensitivity: 0.9918 - precision: 0.9917
# Epoch 53: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 310ms/step - loss: -0.9911 - accuracy: 0.9881 - dice_coef: 0.9911 - specificity: 0.9965 - sensitivity: 0.9918 - precision: 0.9917 - val_loss: -0.9782 - val_accuracy: 0.9815 - val_dice_coef: 0.9782 - val_specificity: 0.9916 - val_sensitivity: 0.9775 - val_precision: 0.9796
# Epoch 54/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9916 - accuracy: 0.9883 - dice_coef: 0.9916 - specificity: 0.9967 - sensitivity: 0.9923 - precision: 0.9921
# Epoch 54: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9916 - accuracy: 0.9883 - dice_coef: 0.9916 - specificity: 0.9967 - sensitivity: 0.9923 - precision: 0.9921 - val_loss: -0.9779 - val_accuracy: 0.9813 - val_dice_coef: 0.9779 - val_specificity: 0.9914 - val_sensitivity: 0.9772 - val_precision: 0.9791
# Epoch 55/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9917 - accuracy: 0.9883 - dice_coef: 0.9917 - specificity: 0.9967 - sensitivity: 0.9924 - precision: 0.9923
# Epoch 55: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 311ms/step - loss: -0.9917 - accuracy: 0.9883 - dice_coef: 0.9917 - specificity: 0.9967 - sensitivity: 0.9924 - precision: 0.9923 - val_loss: -0.9780 - val_accuracy: 0.9814 - val_dice_coef: 0.9780 - val_specificity: 0.9914 - val_sensitivity: 0.9776 - val_precision: 0.9791
# Epoch 56/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9911 - accuracy: 0.9881 - dice_coef: 0.9911 - specificity: 0.9964 - sensitivity: 0.9918 - precision: 0.9916
# Epoch 56: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 310ms/step - loss: -0.9911 - accuracy: 0.9881 - dice_coef: 0.9911 - specificity: 0.9964 - sensitivity: 0.9918 - precision: 0.9916 - val_loss: -0.9778 - val_accuracy: 0.9812 - val_dice_coef: 0.9778 - val_specificity: 0.9921 - val_sensitivity: 0.9754 - val_precision: 0.9807
# Epoch 57/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9902 - accuracy: 0.9877 - dice_coef: 0.9902 - specificity: 0.9961 - sensitivity: 0.9907 - precision: 0.9907
# Epoch 57: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9902 - accuracy: 0.9877 - dice_coef: 0.9902 - specificity: 0.9961 - sensitivity: 0.9907 - precision: 0.9907 - val_loss: -0.9781 - val_accuracy: 0.9814 - val_dice_coef: 0.9781 - val_specificity: 0.9904 - val_sensitivity: 0.9802 - val_precision: 0.9766
# Epoch 58/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9901 - accuracy: 0.9877 - dice_coef: 0.9901 - specificity: 0.9961 - sensitivity: 0.9907 - precision: 0.9907
# Epoch 58: val_dice_coef did not improve from 0.97898
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9901 - accuracy: 0.9877 - dice_coef: 0.9901 - specificity: 0.9961 - sensitivity: 0.9907 - precision: 0.9907 - val_loss: -0.9788 - val_accuracy: 0.9818 - val_dice_coef: 0.9788 - val_specificity: 0.9908 - val_sensitivity: 0.9806 - val_precision: 0.9776
# Epoch 59/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9908 - accuracy: 0.9880 - dice_coef: 0.9908 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9913
# Epoch 59: val_dice_coef improved from 0.97898 to 0.97904, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9908 - accuracy: 0.9880 - dice_coef: 0.9908 - specificity: 0.9963 - sensitivity: 0.9914 - precision: 0.9913 - val_loss: -0.9790 - val_accuracy: 0.9819 - val_dice_coef: 0.9790 - val_specificity: 0.9909 - val_sensitivity: 0.9806 - val_precision: 0.9780
# Epoch 60/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9914 - accuracy: 0.9882 - dice_coef: 0.9914 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920
# Epoch 60: val_dice_coef improved from 0.97904 to 0.97946, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 316ms/step - loss: -0.9914 - accuracy: 0.9882 - dice_coef: 0.9914 - specificity: 0.9966 - sensitivity: 0.9920 - precision: 0.9920 - val_loss: -0.9795 - val_accuracy: 0.9820 - val_dice_coef: 0.9795 - val_specificity: 0.9901 - val_sensitivity: 0.9834 - val_precision: 0.9762
# Epoch 61/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9921 - accuracy: 0.9885 - dice_coef: 0.9921 - specificity: 0.9969 - sensitivity: 0.9929 - precision: 0.9928
# Epoch 61: val_dice_coef improved from 0.97946 to 0.98009, saving model to best_model_224_res.h5
# 249/249 [==============================] - 78s 315ms/step - loss: -0.9921 - accuracy: 0.9885 - dice_coef: 0.9921 - specificity: 0.9969 - sensitivity: 0.9929 - precision: 0.9928 - val_loss: -0.9801 - val_accuracy: 0.9824 - val_dice_coef: 0.9801 - val_specificity: 0.9907 - val_sensitivity: 0.9833 - val_precision: 0.9776
# Epoch 62/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9925 - accuracy: 0.9886 - dice_coef: 0.9925 - specificity: 0.9971 - sensitivity: 0.9933 - precision: 0.9932
# Epoch 62: val_dice_coef improved from 0.98009 to 0.98015, saving model to best_model_224_res.h5
# 249/249 [==============================] - 79s 316ms/step - loss: -0.9925 - accuracy: 0.9886 - dice_coef: 0.9925 - specificity: 0.9971 - sensitivity: 0.9933 - precision: 0.9932 - val_loss: -0.9801 - val_accuracy: 0.9824 - val_dice_coef: 0.9801 - val_specificity: 0.9906 - val_sensitivity: 0.9835 - val_precision: 0.9774
# Epoch 63/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9926 - accuracy: 0.9887 - dice_coef: 0.9926 - specificity: 0.9972 - sensitivity: 0.9933 - precision: 0.9933
# Epoch 63: val_dice_coef did not improve from 0.98015
# 249/249 [==============================] - 77s 308ms/step - loss: -0.9926 - accuracy: 0.9887 - dice_coef: 0.9926 - specificity: 0.9972 - sensitivity: 0.9933 - precision: 0.9933 - val_loss: -0.9792 - val_accuracy: 0.9819 - val_dice_coef: 0.9792 - val_specificity: 0.9890 - val_sensitivity: 0.9856 - val_precision: 0.9736
# Epoch 64/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9922 - accuracy: 0.9885 - dice_coef: 0.9922 - specificity: 0.9970 - sensitivity: 0.9929 - precision: 0.9929
# Epoch 64: val_dice_coef did not improve from 0.98015
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9922 - accuracy: 0.9885 - dice_coef: 0.9922 - specificity: 0.9970 - sensitivity: 0.9929 - precision: 0.9929 - val_loss: -0.9797 - val_accuracy: 0.9822 - val_dice_coef: 0.9797 - val_specificity: 0.9911 - val_sensitivity: 0.9816 - val_precision: 0.9784
# Epoch 65/65
# 249/249 [==============================] - ETA: 0s - loss: -0.9919 - accuracy: 0.9884 - dice_coef: 0.9919 - specificity: 0.9968 - sensitivity: 0.9926 - precision: 0.9925
# Epoch 65: val_dice_coef did not improve from 0.98015
# 249/249 [==============================] - 77s 309ms/step - loss: -0.9919 - accuracy: 0.9884 - dice_coef: 0.9919 - specificity: 0.9968 - sensitivity: 0.9926 - precision: 0.9925 - val_loss: -0.9800 - val_accuracy: 0.9824 - val_dice_coef: 0.9800 - val_specificity: 0.9911 - val_sensitivity: 0.9822 - val_precision: 0.9785

# %%
    # TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type uint8 of argument 'x'.

# %% [markdown]
# # Visualizations

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0346a4f98d12> in <module>
#       3 acc_ax = loss_ax.twinx()
#       4
# ----> 5 loss_ax.plot(results.history['loss'], 'y', label='train loss')
#       6 loss_ax.plot(results.history['val_loss'], 'r', label='val loss')
#       7
#
# NameError: name 'results' is not defined

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0346a4f98d12> in <module>
#       3 acc_ax = loss_ax.twinx()
#       4
# ----> 5 loss_ax.plot(results.history['loss'], 'y', label='train loss')
#       6 loss_ax.plot(results.history['val_loss'], 'r', label='val loss')
#       7
#
# NameError: name 'results' is not defined

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['specificity'], 'b', label='train specificity')
acc_ax.plot(results.history['val_specificity'], 'g', label='val specificity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8cb7ad38bf04> in <module>
#       3 acc_ax = loss_ax.twinx()
#       4
# ----> 5 loss_ax.plot(results.history['loss'], 'y', label='train loss')
#       6 loss_ax.plot(results.history['val_loss'], 'r', label='val loss')
#       7
#
# NameError: name 'results' is not defined

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['sensitivity'], 'b', label='train sensitivity')
acc_ax.plot(results.history['val_sensitivity'], 'g', label='val sensitivity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-91a1f54f6f4b> in <module>
#       3 acc_ax = loss_ax.twinx()
#       4
# ----> 5 loss_ax.plot(results.history['loss'], 'y', label='train loss')
#       6 loss_ax.plot(results.history['val_loss'], 'r', label='val loss')
#       7
#
# NameError: name 'results' is not defined

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['precision'], 'b', label='train precision')
acc_ax.plot(results.history['val_precision'], 'g', label='val precision')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print(results.history['precision'][-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-55f8beaddba7> in <module>
# ----> 1 print(results.history['precision'][-1])
#
# NameError: name 'results' is not defined

# %%
print(results.history['dice_coef'][-1])
# Out:
# 0.9918906688690186

# %%
print(results.history['specificity'][-1])
# Out:
# 0.996821403503418

# %% [markdown]
# testing values

# %% [markdown]
# # testing values

# %%
# import os
test_list = os.listdir("test_set/")
print("The number of test data : ", len(test_list))
test_list[:5]

# %%
#used just for prediction, not as a checkpoint
model = tf.keras.models.load_model('best_model_224_res_VUNET.h5', custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef':dice_coef,'specificity':specificity,'sensitivity':sensitivity,'precision':precision})

# %%
# X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')
# for i, item in enumerate(test_list):
#     image = cv2.imread("test_set/" + item)
#     # print(np.array(image).shape)/
#     image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
#     X_test[i] = image
# X_test = X_test/ 255

# y_pred = model.predict(X_test)

# %%
def getbound(binary_mask):

  # draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  # draw[img > 0.5] = (255,) * 3
  kernelSize = (3,3)

  # gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(binary_mask, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  # gradient = cv2.cvtColor(gradient, cv2.COLOR_GRAY2RGB)
  return gradient


def fitEllipse(binary_mask, method="Direct"):
    assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0

    # print(binary_mask.shape)
   
    gradient  = getbound(binary_mask)

    # print(gradient.shape)

    points1 = np.argwhere(gradient > 0.5)  
    points2 = np.argwhere(binary_mask > 0.5)  

    points = points1
    # print(points1.shape)
    # print(points2.shape)

    if method == "AMS":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
    elif method == "Direct":
        (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
    elif method == "Simple":
        (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

    return (xx, yy), (MA, ma), angle

# %%
# X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')

# y_pred_val  = model.predict_generator(val_gen)
# (img,mask)

# for test, pred in zip(X_val[0:10],y_pred_val[0:10]):
#     fig, ax = plt.subplots(1,4,figsize = (16,16))
#     test = test.reshape((IMG_HEIGHT,IMG_WIDTH,3))

#     pred = pred.reshape((IMG_HEIGHT,IMG_WIDTH))



#     img = pred.copy()
#     (xx, yy), (MA, ma), angle = fitEllipse(img)
#     print((xx, yy), (MA, ma), angle)

#     draw = np.zeros((*img.shape, 3), dtype=np.uint8)

#     draw[img < 0.5] = (255,) * 3

#     cv2.ellipse(
#         draw,
#         (int(yy), int(xx)),
#         (int(ma / 2), int(MA / 2)),
#         -angle,
#         0,
#         360,
#         color=(255, 0, 0),
#         thickness=2,
#     )
    
#     pred = pred>0.5
#     pred = np.ma.masked_where(pred == 0, pred)

#     ax[0].imshow(test, cmap = 'gray')

#     ax[1].imshow(pred, cmap = 'gray')

#     ax[2].imshow(test, cmap = 'gray', interpolation = 'none')
#     ax[2].imshow(pred, cmap = 'jet', interpolation = 'none', alpha = 0.7)
#     ax[3].imshow(draw,cmap='jet')

# %%
# testing on first 50 images, these are from the training set, ground truths of X_test are not provided
X_50 = train_img_aug[0:50:5]
y_50  = train_mask_aug[0:50:5]

X_test = np.empty((len(X_50[:10]), IMG_HEIGHT, IMG_WIDTH,3), dtype = 'float32')



for i, image in enumerate(X_50[:10]):
    # image = cv2.imread("test_set/" + item)
    # print(np.array(image).shape)
    image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    X_test[i] = image
    
X_test = X_test/ 255

y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 12s 12s/step

# %%
fig, ax = plt.subplots(1,1)
pr = y_pred[6].reshape((IMG_HEIGHT,IMG_WIDTH))
# p = cv2.cvtColor(y_pred[0][:,:], cv2.COLOR_BGR2GRAY)
ax.imshow( pr, cmap='gray')
# ax[1].imshow(te )
# y_pred = y_pred[y_pred > 0.5]
# print(y_pred[6])

# %%
def dice_coef(y_true, y_pred):
    # convert to 2D before comparing results
    # y_true = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    # print(np.array(y_true).shape)
    # print(np.array(y_pred).shape)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)


    # print((2. * intersection ) / (K.sum(y_true_f) + K.sum(y_pred_f) ))
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def jac_distance(y_true, y_pred ):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    # intersection = K.sum(y_true_f * y_pred_f)

    intersection = K.sum(K.abs(y_true_f * y_pred_f), axis=-1)
    sum_ = K.sum(K.abs(y_true_f) + K.abs(y_pred_f), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    # print(jac)
    return jac

# %%
i=0
for test, pred in zip(X_test[0:10],y_pred[0:10]):
    
    y_true = cv2.cvtColor(y_50[i], cv2.COLOR_BGR2GRAY)
    y_true = cv2.resize(y_true, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    y_true = np.array(y_true).astype(float) / 255.0
    y_p = np.array(pred).astype(float)  

    dice = dice_coef( y_true, y_p)
    jac = jac_distance(y_true, y_p)
    # print(dice,jac)
    i=i+1
    fig, ax = plt.subplots(1,4,figsize = (16,16))
    test = test.reshape((IMG_HEIGHT,IMG_WIDTH,3))

    pred = pred.reshape((IMG_HEIGHT,IMG_WIDTH))

    img = pred.copy()
    (xx, yy), (MA, ma), angle = fitEllipse(img)
    # print((xx, yy), (MA, ma), angle)

    draw = np.zeros((*img.shape, 3), dtype=np.uint8)

    draw[img < 0.5] = (255,) * 3

    cv2.ellipse(
        draw,
        (int(yy), int(xx)),
        (int(ma / 2), int(MA / 2)),
        -angle,
        0,
        360,
        color=(255, 0, 0),
        thickness=2,
    )
    
    pred = pred>0.5
    pred = np.ma.masked_where(pred == 0, pred)

    ax[0].imshow(test, cmap = 'gray')

    ax[1].imshow(pred, cmap = 'gray')

    ax[2].imshow(test, cmap = 'gray', interpolation = 'none')
    ax[2].imshow(pred, cmap = 'jet', interpolation = 'none', alpha = 0.7)

    ax[3].text(3, 7, 'dice ' + str(round(float(dice),4)) + '\njacc ' + str(round(float(jac),4)), fontsize = 15, color = 'g')

    ax[3].imshow(draw,cmap='jet')

# %%
dice_coef_val = []
jac_distance_val = []

for i in range(len(y_pred)):
  y_true = cv2.cvtColor(y_50[i], cv2.COLOR_BGR2GRAY)
  
  y_true = cv2.resize(y_true, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
  y_true = np.array(y_true).astype(float) / 255.0
  y_pred = np.array(y_pred).astype(float)  
  dice_coef_val.append(dice_coef( y_true, y_pred[i]))
  jac_distance_val.append(jac_distance(y_true, y_pred[i]))
  # print(dice_coef(y_true, y_pred[i]))
# Out:
# tf.Tensor(0.9478634609441297, shape=(), dtype=float64)
# tf.Tensor(0.9596218119489381, shape=(), dtype=float64)
# tf.Tensor(0.9625567162988652, shape=(), dtype=float64)
# tf.Tensor(0.9532225306326244, shape=(), dtype=float64)
# tf.Tensor(0.953222528523291, shape=(), dtype=float64)
# tf.Tensor(0.7678562917981805, shape=(), dtype=float64)
# tf.Tensor(0.9714251418955072, shape=(), dtype=float64)
# tf.Tensor(0.9685022517359323, shape=(), dtype=float64)
# tf.Tensor(0.967918353073545, shape=(), dtype=float64)
# tf.Tensor(0.9679183464300728, shape=(), dtype=float64)

# %%
#ellipse fitting is performed on below displayed figure


def getbound(img):
  draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  draw[img > 0.5] = (255,) * 3

  kernelSize = (3,3)
  gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(draw, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  return gradient

# def fitEllipse(binary_mask, method="Direct"):
#     assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0
#     points = np.argwhere(binary_mask > 0.5)  

#     if method == "AMS":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
#     elif method == "Direct":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
#     elif method == "Simple":
#         (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

#     return (xx, yy), (MA, ma), angle


# # img = np.load("./output_samples/3.npy")
img = pred.copy()
# (xx, yy), (MA, ma), angle = fitEllipse(img)
# print((xx, yy), (MA, ma), angle)

draw = np.zeros((*img.shape, 3), dtype=np.uint8)

draw[img > 0.5] = (255,) * 3

# cv2.ellipse(
#     draw,
#     (int(yy), int(xx)),
#     (int(ma / 2), int(MA / 2)),
#     -angle,
#     0,
#     360,
#     color=(255, 0, 0),
#     thickness=2,
# )
gradient = getbound(img)
plt.imshow(gradient)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-46-2fe4c006decc> in <module>
#      48 #     thickness=2,
#      49 # )
# ---> 50 gradient = getbound(img)
#      51 plt.imshow(gradient)
#      52 plt.show()
#
# <ipython-input-46-2fe4c006decc> in getbound(img)
#       8
#       9   kernelSize = (3,3)
# ---> 10   gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
#      11   kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
#      12   gradient = cv2.morphologyEx(draw, cv2.MORPH_GRADIENT, kernel)
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = cv::impl::<unnamed>::NONE; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %% [markdown]
# # Test Results

# %%
#evalutte test set
# # import os
# test_list = os.listdir("test_set/")
# # print("The number of test data : ", len(test_list))
# # test_list[:5]


# X_test = np.empty((len(test_list), IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
# for i, item in enumerate(test_list):
#     image = cv2.imread("test_set/" + item, 0)
#     image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
#     X_test[i] = image

# X_test = X_test[:,:,:,np.newaxis] / 255
# #used just for prediction, not as a checkpoint
# model = tf.keras.models.load_model('best_model_224_res.h5', custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef':dice_coef,'specificity':specificity,'sensitivity':sensitivity,'precision':precision})
# model.compile(optimizer=Adam(lr = 1e-4), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])

# # evaluate_gen =
# # y_pred = model.predict(X_test)

# y_pred = model.predict(X_test)
