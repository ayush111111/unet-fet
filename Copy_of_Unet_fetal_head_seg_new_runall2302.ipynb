# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush111111/unet-fet/blob/main/Copy_of_Unet_fetal_head_seg_new_runall2302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports and augmentation

# %%
# %cd drive/MyDrive/'Semester Project '/dataset_filled/
# %ls
# Out:
# /content/drive/MyDrive/Semester Project /dataset_filled
#  best_model_224_res_64epoch_1e-4_val_coef_98.h5
#  best_model_224_res_reduce_lr2302.h5
#  best_model_224_res_reduce_lr.h5
#  best_model_224_res_retraining_1e-4.h5
#  best_model_224_res_unk.h5
#  best_model_224_res_VUNET.h5
# 'Copy of best_model_224_res_64epoch_1e-4_val_coef_98.h5'
# 'Copy of best_model_224_res.h5'
#  model.png
#  test_set/
#  training_set/

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
trainPath = "training_set/"
testPath = "test_set/"
trainList = sorted(os.listdir(trainPath))
testList = sorted(os.listdir(testPath))


train_image = []
train_mask = []
for i, item in enumerate(trainList):
    if i % 2 == 0:
        train_image.append(item)
    else:
        train_mask.append(item)
print("Ultrasound training images in dataset {}".format(len(train_image)))
print("Ultrasound training masks in dataset  {}".format(len(train_mask)))
# Out:
# Ultrasound training images in dataset 999
# Ultrasound training masks in dataset  999

# %%
img = np.array(Image.open(trainPath+"000_HC.png"))
img_mask = np.array(Image.open(trainPath+"000_HC_Annotation.png"))
img_mask = np.ma.masked_where(img_mask == 0, img_mask)
print(len(img[0]))
#display images with mask
fig, ax = plt.subplots(1,3,figsize = (16,12))
ax[0].imshow(img, cmap = 'gray')
ax[1].imshow(img_mask, cmap = 'gray')
ax[2].imshow(img, cmap = 'gray', interpolation = 'none')
ax[2].imshow(img_mask, cmap = 'gray', interpolation = 'none', alpha = 0.7)
# Out:
# 800

# %%
#
X = []
y = []
for image, mask in zip(train_image, train_mask):
    X.append(np.array(Image.open(trainPath+image)))
    y.append(np.array(Image.open(trainPath+mask)))

X = np.array(X)
y = np.array(y)

print("X_shape : ", X.shape)
print("y_shape : ", y.shape)
# Out:
# X_shape :  (999,)
# y_shape :  (999,)
# <ipython-input-6-5829c98f866b>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array(X)
# <ipython-input-6-5829c98f866b>:9: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y = np.array(y)

# %%
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split

import tensorflow.keras
import tensorflow as tf
from tensorflow.keras import backend as K

K.set_image_data_format('channels_last')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Add
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


IMG_HEIGHT = 224
IMG_WIDTH = 224

# %%
def Generator(X_list, y_list, batch_size = 16):
    c = 0

    while(True):
        X = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        y = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')
        
        for i in range(c,c+batch_size):
            image = X_list[i]
            image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            mask =  y_list[i]
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    
            X[i - c] = image
            y[i - c] = mask
        
        X = X[:,:,:,np.newaxis] / 255
        y = y[:,:,:,np.newaxis] / 255
        
        c += batch_size
        if(c+batch_size >= len(X_list)):
            c = 0
        yield X, y

# %%
train_img_aug = []
train_mask_aug = []


for img, mask in zip(train_image, train_mask):
    img = cv2.imread(trainPath + img)
    mask = cv2.imread(trainPath + mask)
    train_img_aug.append(img)
    
    train_mask_aug.append(mask)
    img_lr = np.fliplr(img)
    mask_lr = np.fliplr(mask)

    img_up = np.flipud(img)
    mask_up = np.flipud(mask)

    img_lr_up = np.flipud(img_lr)
    mask_lr_up = np.flipud(mask_lr)

    img_up_lr = np.fliplr(img_up)
    mask_up_lr = np.fliplr(mask_up)

    train_img_aug.append(img_lr)
    train_mask_aug.append(mask_lr)

    train_img_aug.append(img_up)
    train_mask_aug.append(mask_up)

    train_img_aug.append(img_lr_up)
    train_mask_aug.append(mask_lr_up)

    train_img_aug.append(img_up_lr)
    train_mask_aug.append(mask_up_lr)

print(len(train_image))
print(len(train_img_aug))
# Out:
# 999
# 4995

# %% [markdown]
# # Model Training

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
# define building blocks
def BatchnormActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_block(x, filters, size, strides=(1,1), padding="same", activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchnormActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate=False):
    x = BatchnormActivate(blockInput)
    x = conv_block(x, num_filters, (3,3))
    x = conv_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchnormActivate(x)
    return x

# %%
def build_Unet(input_layer, start_neurons, DropoutRatio = 0.5):
    

    """ Encoder """
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    #pool1 = Dropout(DropoutRatio/2)(pool1)

    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    #pool2 = Dropout(DropoutRatio)(pool2)

    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    #pool3 = Dropout(DropoutRatio)(pool3)

    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    #pool4 = Dropout(DropoutRatio)(pool4)


    """ Bridge """
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)



    """ Decoder """
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    #uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    #uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    """ Output """
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

# %%
#split training data

#test_size changed from 0.3 t0 0.2 
X_train, X_val, y_train, y_val = train_test_split(train_img_aug, train_mask_aug, test_size = 0.2, random_state = 1)

# set training parameters
epochs = 100
batch_size = 16
steps_per_epoch = int(len(X_train) / batch_size)
validation_steps = int(len(X_val) / batch_size)

train_gen = Generator(X_train, y_train, batch_size = batch_size)
val_gen = Generator(X_val, y_val, batch_size = batch_size)

# initialize our model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, 1))
output_layer = build_Unet(inputs, 16, 0.5)

# Define callbacks to save model with best val_dice_coef
checkpointer = ModelCheckpoint(filepath = 'best_model_224_res_reduce_lr2302.h5', monitor='val_dice_coef', verbose=1, save_best_only=True, mode='max')
model = Model(inputs=[inputs], outputs=[output_layer])
model.compile(optimizer=Adam(lr = 1e-4), loss=dice_coef_loss, metrics=['accuracy',dice_coef,specificity,sensitivity,precision,])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 224, 224, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 16  2320        ['activation_1[0][0]']
#                                 )
#
#  add (Add)                      (None, 224, 224, 16  0           ['conv2d_2[0][0]',
#                                 )                                 'conv2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 224, 224, 16  64         ['add[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 16  2320        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 224, 224, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 224, 224, 16  2320        ['activation_3[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 224, 224, 16  0           ['conv2d_4[0][0]',
#                                 )                                 'add[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 224, 224, 16  64         ['add_1[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 224, 224, 16  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 16  0           ['activation_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 112, 112, 32  4640        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 112, 112, 32  128        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 112, 112, 32  9248        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 112, 112, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 112, 112, 32  9248        ['activation_6[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 112, 112, 32  0           ['conv2d_7[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 112, 112, 32  128        ['add_2[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 112, 112, 32  9248        ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 112, 112, 32  128        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 112, 112, 32  9248        ['activation_8[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 112, 112, 32  0           ['conv2d_9[0][0]',
#                                 )                                 'add_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 112, 112, 32  128        ['add_3[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 112, 112, 32  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 32)  0           ['activation_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_11[0][0]']
#
#  add_4 (Add)                    (None, 56, 56, 64)   0           ['conv2d_12[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 64)  256         ['add_4[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_13[0][0]']
#
#  add_5 (Add)                    (None, 56, 56, 64)   0           ['conv2d_14[0][0]',
#                                                                   'add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 56, 56, 64)  256         ['add_5[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_14[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 128)  0           ['conv2d_17[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 128)  512        ['add_6[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_18[0][0]']
#
#  add_7 (Add)                    (None, 28, 28, 128)  0           ['conv2d_19[0][0]',
#                                                                   'add_6[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['add_7[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_21[0][0]']
#
#  add_8 (Add)                    (None, 14, 14, 256)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 256)  1024       ['add_8[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_23[0][0]']
#
#  add_9 (Add)                    (None, 14, 14, 256)  0           ['conv2d_24[0][0]',
#                                                                   'add_8[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['add_9[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 28, 28, 128)  295040     ['activation_24[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_19[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 28, 28, 128)  295040      ['concatenate[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_26[0][0]']
#
#  add_10 (Add)                   (None, 28, 28, 128)  0           ['conv2d_27[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 128)  512        ['add_10[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_28[0][0]']
#
#  add_11 (Add)                   (None, 28, 28, 128)  0           ['conv2d_29[0][0]',
#                                                                   'add_10[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 128)  512        ['add_11[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_29[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 56, 56, 64)   73792       ['concatenate_1[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 56, 56, 64)  256         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 56, 56, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_31[0][0]']
#
#  add_12 (Add)                   (None, 56, 56, 64)   0           ['conv2d_32[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 56, 56, 64)  256         ['add_12[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 56, 56, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 56, 56, 64)   36928       ['activation_33[0][0]']
#
#  add_13 (Add)                   (None, 56, 56, 64)   0           ['conv2d_34[0][0]',
#                                                                   'add_12[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 56, 56, 64)  256         ['add_13[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 56, 56, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_34[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 112, 112, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'activation_9[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 112, 112, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 112, 112, 32  128        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 112, 112, 32  9248        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 112, 112, 32  128        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 112, 112, 32  9248        ['activation_36[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 112, 112, 32  0           ['conv2d_37[0][0]',
#                                 )                                 'conv2d_35[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 112, 112, 32  128        ['add_14[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 112, 112, 32  9248        ['activation_37[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 112, 112, 32  128        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 112, 112, 32  9248        ['activation_38[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 112, 112, 32  0           ['conv2d_39[0][0]',
#                                 )                                 'add_14[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 112, 112, 32  128        ['add_15[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 112, 112, 32  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 224, 224, 16  4624       ['activation_39[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 224, 224, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 224, 224, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 224, 224, 16  64         ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  activation_40 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_40[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 224, 224, 16  2320        ['activation_40[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 224, 224, 16  64         ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  activation_41 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 224, 224, 16  2320        ['activation_41[0][0]']
#                                 )
#
#  add_16 (Add)                   (None, 224, 224, 16  0           ['conv2d_42[0][0]',
#                                 )                                 'conv2d_40[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 224, 224, 16  64         ['add_16[0][0]']
#  ormalization)                  )
#
#  activation_42 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 224, 224, 16  2320        ['activation_42[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 224, 224, 16  64         ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 224, 224, 16  2320        ['activation_43[0][0]']
#                                 )
#
#  add_17 (Add)                   (None, 224, 224, 16  0           ['conv2d_44[0][0]',
#                                 )                                 'add_16[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 224, 224, 16  64         ['add_17[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 224, 224, 16  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 224, 224, 1)  17          ['activation_44[0][0]']
#
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5)

# %% [markdown]
# # fit model

# %%
results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer,reduce_lr])
# Out:
# <ipython-input-15-97ab44bd4fe9>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   results = model.fit_generator(train_gen, steps_per_epoch=steps_per_epoch, epochs = epochs, validation_data = val_gen, validation_steps = validation_steps,callbacks=[checkpointer,reduce_lr])
# Epoch 1/100
# 249/249 [==============================] - ETA: 0s - loss: -0.8394 - accuracy: 0.9470 - dice_coef: 0.8394 - specificity: 0.9471 - sensitivity: 0.9645 - precision: 0.8977
# Epoch 1: val_dice_coef improved from -inf to 0.87367, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 140s 396ms/step - loss: -0.8394 - accuracy: 0.9470 - dice_coef: 0.8394 - specificity: 0.9471 - sensitivity: 0.9645 - precision: 0.8977 - val_loss: -0.8737 - val_accuracy: 0.9452 - val_dice_coef: 0.8737 - val_specificity: 0.9489 - val_sensitivity: 0.9533 - val_precision: 0.8849 - lr: 0.0010
# Epoch 2/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9456 - accuracy: 0.9747 - dice_coef: 0.9456 - specificity: 0.9844 - sensitivity: 0.9710 - precision: 0.9622
# Epoch 2: val_dice_coef improved from 0.87367 to 0.94126, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 98s 394ms/step - loss: -0.9456 - accuracy: 0.9747 - dice_coef: 0.9456 - specificity: 0.9844 - sensitivity: 0.9710 - precision: 0.9622 - val_loss: -0.9413 - val_accuracy: 0.9671 - val_dice_coef: 0.9413 - val_specificity: 0.9819 - val_sensitivity: 0.9497 - val_precision: 0.9559 - lr: 0.0010
# Epoch 3/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9602 - accuracy: 0.9753 - dice_coef: 0.9602 - specificity: 0.9862 - sensitivity: 0.9692 - precision: 0.9664
# Epoch 3: val_dice_coef improved from 0.94126 to 0.96471, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 97s 392ms/step - loss: -0.9602 - accuracy: 0.9753 - dice_coef: 0.9602 - specificity: 0.9862 - sensitivity: 0.9692 - precision: 0.9664 - val_loss: -0.9647 - val_accuracy: 0.9765 - val_dice_coef: 0.9647 - val_specificity: 0.9846 - val_sensitivity: 0.9757 - val_precision: 0.9633 - lr: 0.0010
# Epoch 4/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9695 - accuracy: 0.9785 - dice_coef: 0.9695 - specificity: 0.9887 - sensitivity: 0.9743 - precision: 0.9726
# Epoch 4: val_dice_coef improved from 0.96471 to 0.96619, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 99s 398ms/step - loss: -0.9695 - accuracy: 0.9785 - dice_coef: 0.9695 - specificity: 0.9887 - sensitivity: 0.9743 - precision: 0.9726 - val_loss: -0.9662 - val_accuracy: 0.9759 - val_dice_coef: 0.9662 - val_specificity: 0.9790 - val_sensitivity: 0.9874 - val_precision: 0.9511 - lr: 0.0010
# Epoch 5/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9724 - accuracy: 0.9793 - dice_coef: 0.9724 - specificity: 0.9895 - sensitivity: 0.9750 - precision: 0.9746
# Epoch 5: val_dice_coef improved from 0.96619 to 0.96728, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9724 - accuracy: 0.9793 - dice_coef: 0.9724 - specificity: 0.9895 - sensitivity: 0.9750 - precision: 0.9746 - val_loss: -0.9673 - val_accuracy: 0.9762 - val_dice_coef: 0.9673 - val_specificity: 0.9870 - val_sensitivity: 0.9695 - val_precision: 0.9684 - lr: 0.0010
# Epoch 6/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9730 - accuracy: 0.9792 - dice_coef: 0.9730 - specificity: 0.9896 - sensitivity: 0.9745 - precision: 0.9747
# Epoch 6: val_dice_coef improved from 0.96728 to 0.97364, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 353ms/step - loss: -0.9730 - accuracy: 0.9792 - dice_coef: 0.9730 - specificity: 0.9896 - sensitivity: 0.9745 - precision: 0.9747 - val_loss: -0.9736 - val_accuracy: 0.9796 - val_dice_coef: 0.9736 - val_specificity: 0.9905 - val_sensitivity: 0.9730 - val_precision: 0.9768 - lr: 0.0010
# Epoch 7/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9761 - accuracy: 0.9807 - dice_coef: 0.9761 - specificity: 0.9905 - sensitivity: 0.9774 - precision: 0.9772
# Epoch 7: val_dice_coef did not improve from 0.97364
# 249/249 [==============================] - 96s 385ms/step - loss: -0.9761 - accuracy: 0.9807 - dice_coef: 0.9761 - specificity: 0.9905 - sensitivity: 0.9774 - precision: 0.9772 - val_loss: -0.9732 - val_accuracy: 0.9789 - val_dice_coef: 0.9732 - val_specificity: 0.9841 - val_sensitivity: 0.9860 - val_precision: 0.9624 - lr: 0.0010
# Epoch 8/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9776 - accuracy: 0.9814 - dice_coef: 0.9776 - specificity: 0.9909 - sensitivity: 0.9787 - precision: 0.9783
# Epoch 8: val_dice_coef improved from 0.97364 to 0.97619, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 97s 391ms/step - loss: -0.9776 - accuracy: 0.9814 - dice_coef: 0.9776 - specificity: 0.9909 - sensitivity: 0.9787 - precision: 0.9783 - val_loss: -0.9762 - val_accuracy: 0.9807 - val_dice_coef: 0.9762 - val_specificity: 0.9902 - val_sensitivity: 0.9774 - val_precision: 0.9764 - lr: 0.0010
# Epoch 9/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9786 - accuracy: 0.9818 - dice_coef: 0.9786 - specificity: 0.9912 - sensitivity: 0.9795 - precision: 0.9791
# Epoch 9: val_dice_coef improved from 0.97619 to 0.97706, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 355ms/step - loss: -0.9786 - accuracy: 0.9818 - dice_coef: 0.9786 - specificity: 0.9912 - sensitivity: 0.9795 - precision: 0.9791 - val_loss: -0.9771 - val_accuracy: 0.9811 - val_dice_coef: 0.9771 - val_specificity: 0.9905 - val_sensitivity: 0.9784 - val_precision: 0.9771 - lr: 0.0010
# Epoch 10/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9795 - accuracy: 0.9823 - dice_coef: 0.9795 - specificity: 0.9916 - sensitivity: 0.9803 - precision: 0.9800
# Epoch 10: val_dice_coef did not improve from 0.97706
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9795 - accuracy: 0.9823 - dice_coef: 0.9795 - specificity: 0.9916 - sensitivity: 0.9803 - precision: 0.9800 - val_loss: -0.9765 - val_accuracy: 0.9807 - val_dice_coef: 0.9765 - val_specificity: 0.9910 - val_sensitivity: 0.9757 - val_precision: 0.9783 - lr: 0.0010
# Epoch 11/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9799 - accuracy: 0.9824 - dice_coef: 0.9799 - specificity: 0.9917 - sensitivity: 0.9806 - precision: 0.9803
# Epoch 11: val_dice_coef improved from 0.97706 to 0.97777, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 348ms/step - loss: -0.9799 - accuracy: 0.9824 - dice_coef: 0.9799 - specificity: 0.9917 - sensitivity: 0.9806 - precision: 0.9803 - val_loss: -0.9778 - val_accuracy: 0.9814 - val_dice_coef: 0.9778 - val_specificity: 0.9913 - val_sensitivity: 0.9775 - val_precision: 0.9790 - lr: 0.0010
# Epoch 12/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9806 - accuracy: 0.9828 - dice_coef: 0.9806 - specificity: 0.9920 - sensitivity: 0.9812 - precision: 0.9809
# Epoch 12: val_dice_coef did not improve from 0.97777
# 249/249 [==============================] - 86s 347ms/step - loss: -0.9806 - accuracy: 0.9828 - dice_coef: 0.9806 - specificity: 0.9920 - sensitivity: 0.9812 - precision: 0.9809 - val_loss: -0.9771 - val_accuracy: 0.9810 - val_dice_coef: 0.9771 - val_specificity: 0.9904 - val_sensitivity: 0.9783 - val_precision: 0.9768 - lr: 0.0010
# Epoch 13/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9756 - accuracy: 0.9799 - dice_coef: 0.9756 - specificity: 0.9899 - sensitivity: 0.9762 - precision: 0.9759
# Epoch 13: val_dice_coef did not improve from 0.97777
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9756 - accuracy: 0.9799 - dice_coef: 0.9756 - specificity: 0.9899 - sensitivity: 0.9762 - precision: 0.9759 - val_loss: -0.9763 - val_accuracy: 0.9804 - val_dice_coef: 0.9763 - val_specificity: 0.9886 - val_sensitivity: 0.9807 - val_precision: 0.9727 - lr: 0.0010
# Epoch 14/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9794 - accuracy: 0.9821 - dice_coef: 0.9794 - specificity: 0.9915 - sensitivity: 0.9798 - precision: 0.9797
# Epoch 14: val_dice_coef improved from 0.97777 to 0.97880, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 98s 394ms/step - loss: -0.9794 - accuracy: 0.9821 - dice_coef: 0.9794 - specificity: 0.9915 - sensitivity: 0.9798 - precision: 0.9797 - val_loss: -0.9788 - val_accuracy: 0.9819 - val_dice_coef: 0.9788 - val_specificity: 0.9914 - val_sensitivity: 0.9791 - val_precision: 0.9793 - lr: 0.0010
# Epoch 15/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9800 - accuracy: 0.9824 - dice_coef: 0.9800 - specificity: 0.9917 - sensitivity: 0.9805 - precision: 0.9803
# Epoch 15: val_dice_coef did not improve from 0.97880
# 249/249 [==============================] - 86s 347ms/step - loss: -0.9800 - accuracy: 0.9824 - dice_coef: 0.9800 - specificity: 0.9917 - sensitivity: 0.9805 - precision: 0.9803 - val_loss: -0.9771 - val_accuracy: 0.9810 - val_dice_coef: 0.9771 - val_specificity: 0.9942 - val_sensitivity: 0.9694 - val_precision: 0.9856 - lr: 0.0010
# Epoch 16/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9806 - accuracy: 0.9827 - dice_coef: 0.9806 - specificity: 0.9920 - sensitivity: 0.9809 - precision: 0.9810
# Epoch 16: val_dice_coef did not improve from 0.97880
# 249/249 [==============================] - 95s 383ms/step - loss: -0.9806 - accuracy: 0.9827 - dice_coef: 0.9806 - specificity: 0.9920 - sensitivity: 0.9809 - precision: 0.9810 - val_loss: -0.9786 - val_accuracy: 0.9818 - val_dice_coef: 0.9786 - val_specificity: 0.9915 - val_sensitivity: 0.9785 - val_precision: 0.9795 - lr: 0.0010
# Epoch 17/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9819 - accuracy: 0.9834 - dice_coef: 0.9819 - specificity: 0.9925 - sensitivity: 0.9824 - precision: 0.9822
# Epoch 17: val_dice_coef did not improve from 0.97880
# 249/249 [==============================] - 87s 348ms/step - loss: -0.9819 - accuracy: 0.9834 - dice_coef: 0.9819 - specificity: 0.9925 - sensitivity: 0.9824 - precision: 0.9822 - val_loss: -0.9773 - val_accuracy: 0.9810 - val_dice_coef: 0.9773 - val_specificity: 0.9920 - val_sensitivity: 0.9747 - val_precision: 0.9805 - lr: 0.0010
# Epoch 18/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9827 - accuracy: 0.9838 - dice_coef: 0.9827 - specificity: 0.9928 - sensitivity: 0.9832 - precision: 0.9830
# Epoch 18: val_dice_coef did not improve from 0.97880
# 249/249 [==============================] - 85s 344ms/step - loss: -0.9827 - accuracy: 0.9838 - dice_coef: 0.9827 - specificity: 0.9928 - sensitivity: 0.9832 - precision: 0.9830 - val_loss: -0.9779 - val_accuracy: 0.9813 - val_dice_coef: 0.9779 - val_specificity: 0.9905 - val_sensitivity: 0.9792 - val_precision: 0.9772 - lr: 0.0010
# Epoch 19/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9826 - accuracy: 0.9838 - dice_coef: 0.9826 - specificity: 0.9928 - sensitivity: 0.9830 - precision: 0.9829
# Epoch 19: val_dice_coef did not improve from 0.97880
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9826 - accuracy: 0.9838 - dice_coef: 0.9826 - specificity: 0.9928 - sensitivity: 0.9830 - precision: 0.9829 - val_loss: -0.9769 - val_accuracy: 0.9808 - val_dice_coef: 0.9769 - val_specificity: 0.9921 - val_sensitivity: 0.9737 - val_precision: 0.9807 - lr: 0.0010
# Epoch 20/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9839 - accuracy: 0.9845 - dice_coef: 0.9839 - specificity: 0.9933 - sensitivity: 0.9845 - precision: 0.9841
# Epoch 20: val_dice_coef improved from 0.97880 to 0.98058, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 89s 356ms/step - loss: -0.9839 - accuracy: 0.9845 - dice_coef: 0.9839 - specificity: 0.9933 - sensitivity: 0.9845 - precision: 0.9841 - val_loss: -0.9806 - val_accuracy: 0.9828 - val_dice_coef: 0.9806 - val_specificity: 0.9910 - val_sensitivity: 0.9836 - val_precision: 0.9782 - lr: 2.0000e-04
# Epoch 21/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9851 - accuracy: 0.9851 - dice_coef: 0.9851 - specificity: 0.9938 - sensitivity: 0.9856 - precision: 0.9854
# Epoch 21: val_dice_coef improved from 0.98058 to 0.98083, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 97s 392ms/step - loss: -0.9851 - accuracy: 0.9851 - dice_coef: 0.9851 - specificity: 0.9938 - sensitivity: 0.9856 - precision: 0.9854 - val_loss: -0.9808 - val_accuracy: 0.9829 - val_dice_coef: 0.9808 - val_specificity: 0.9910 - val_sensitivity: 0.9840 - val_precision: 0.9784 - lr: 2.0000e-04
# Epoch 22/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9858 - accuracy: 0.9855 - dice_coef: 0.9858 - specificity: 0.9941 - sensitivity: 0.9863 - precision: 0.9862
# Epoch 22: val_dice_coef improved from 0.98083 to 0.98084, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 354ms/step - loss: -0.9858 - accuracy: 0.9855 - dice_coef: 0.9858 - specificity: 0.9941 - sensitivity: 0.9863 - precision: 0.9862 - val_loss: -0.9808 - val_accuracy: 0.9829 - val_dice_coef: 0.9808 - val_specificity: 0.9909 - val_sensitivity: 0.9842 - val_precision: 0.9781 - lr: 2.0000e-04
# Epoch 23/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9865 - accuracy: 0.9858 - dice_coef: 0.9865 - specificity: 0.9945 - sensitivity: 0.9871 - precision: 0.9869
# Epoch 23: val_dice_coef did not improve from 0.98084
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9865 - accuracy: 0.9858 - dice_coef: 0.9865 - specificity: 0.9945 - sensitivity: 0.9871 - precision: 0.9869 - val_loss: -0.9808 - val_accuracy: 0.9829 - val_dice_coef: 0.9808 - val_specificity: 0.9909 - val_sensitivity: 0.9841 - val_precision: 0.9782 - lr: 2.0000e-04
# Epoch 24/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9872 - accuracy: 0.9861 - dice_coef: 0.9872 - specificity: 0.9948 - sensitivity: 0.9878 - precision: 0.9877
# Epoch 24: val_dice_coef improved from 0.98084 to 0.98088, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 97s 391ms/step - loss: -0.9872 - accuracy: 0.9861 - dice_coef: 0.9872 - specificity: 0.9948 - sensitivity: 0.9878 - precision: 0.9877 - val_loss: -0.9809 - val_accuracy: 0.9829 - val_dice_coef: 0.9809 - val_specificity: 0.9914 - val_sensitivity: 0.9832 - val_precision: 0.9792 - lr: 2.0000e-04
# Epoch 25/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9879 - accuracy: 0.9865 - dice_coef: 0.9879 - specificity: 0.9951 - sensitivity: 0.9885 - precision: 0.9883
# Epoch 25: val_dice_coef improved from 0.98088 to 0.98113, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 98s 394ms/step - loss: -0.9879 - accuracy: 0.9865 - dice_coef: 0.9879 - specificity: 0.9951 - sensitivity: 0.9885 - precision: 0.9883 - val_loss: -0.9811 - val_accuracy: 0.9831 - val_dice_coef: 0.9811 - val_specificity: 0.9915 - val_sensitivity: 0.9835 - val_precision: 0.9794 - lr: 2.0000e-04
# Epoch 26/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9885 - accuracy: 0.9867 - dice_coef: 0.9885 - specificity: 0.9953 - sensitivity: 0.9891 - precision: 0.9890
# Epoch 26: val_dice_coef did not improve from 0.98113
# 249/249 [==============================] - 85s 343ms/step - loss: -0.9885 - accuracy: 0.9867 - dice_coef: 0.9885 - specificity: 0.9953 - sensitivity: 0.9891 - precision: 0.9890 - val_loss: -0.9809 - val_accuracy: 0.9829 - val_dice_coef: 0.9809 - val_specificity: 0.9914 - val_sensitivity: 0.9832 - val_precision: 0.9791 - lr: 2.0000e-04
# Epoch 27/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9890 - accuracy: 0.9870 - dice_coef: 0.9890 - specificity: 0.9956 - sensitivity: 0.9895 - precision: 0.9896
# Epoch 27: val_dice_coef did not improve from 0.98113
# 249/249 [==============================] - 85s 342ms/step - loss: -0.9890 - accuracy: 0.9870 - dice_coef: 0.9890 - specificity: 0.9956 - sensitivity: 0.9895 - precision: 0.9896 - val_loss: -0.9808 - val_accuracy: 0.9829 - val_dice_coef: 0.9808 - val_specificity: 0.9916 - val_sensitivity: 0.9826 - val_precision: 0.9796 - lr: 2.0000e-04
# Epoch 28/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9894 - accuracy: 0.9872 - dice_coef: 0.9894 - specificity: 0.9958 - sensitivity: 0.9900 - precision: 0.9900
# Epoch 28: val_dice_coef did not improve from 0.98113
# 249/249 [==============================] - 97s 388ms/step - loss: -0.9894 - accuracy: 0.9872 - dice_coef: 0.9894 - specificity: 0.9958 - sensitivity: 0.9900 - precision: 0.9900 - val_loss: -0.9809 - val_accuracy: 0.9830 - val_dice_coef: 0.9809 - val_specificity: 0.9915 - val_sensitivity: 0.9831 - val_precision: 0.9794 - lr: 2.0000e-04
# Epoch 29/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9890 - accuracy: 0.9871 - dice_coef: 0.9890 - specificity: 0.9955 - sensitivity: 0.9896 - precision: 0.9895
# Epoch 29: val_dice_coef did not improve from 0.98113
# 249/249 [==============================] - 87s 347ms/step - loss: -0.9890 - accuracy: 0.9871 - dice_coef: 0.9890 - specificity: 0.9955 - sensitivity: 0.9896 - precision: 0.9895 - val_loss: -0.9807 - val_accuracy: 0.9828 - val_dice_coef: 0.9807 - val_specificity: 0.9900 - val_sensitivity: 0.9862 - val_precision: 0.9760 - lr: 2.0000e-04
# Epoch 30/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9886 - accuracy: 0.9869 - dice_coef: 0.9886 - specificity: 0.9953 - sensitivity: 0.9891 - precision: 0.9890
# Epoch 30: val_dice_coef improved from 0.98113 to 0.98136, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 353ms/step - loss: -0.9886 - accuracy: 0.9869 - dice_coef: 0.9886 - specificity: 0.9953 - sensitivity: 0.9891 - precision: 0.9890 - val_loss: -0.9814 - val_accuracy: 0.9832 - val_dice_coef: 0.9814 - val_specificity: 0.9926 - val_sensitivity: 0.9813 - val_precision: 0.9821 - lr: 2.0000e-04
# Epoch 31/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9889 - accuracy: 0.9871 - dice_coef: 0.9889 - specificity: 0.9955 - sensitivity: 0.9895 - precision: 0.9894
# Epoch 31: val_dice_coef did not improve from 0.98136
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9889 - accuracy: 0.9871 - dice_coef: 0.9889 - specificity: 0.9955 - sensitivity: 0.9895 - precision: 0.9894 - val_loss: -0.9809 - val_accuracy: 0.9830 - val_dice_coef: 0.9809 - val_specificity: 0.9921 - val_sensitivity: 0.9816 - val_precision: 0.9808 - lr: 2.0000e-04
# Epoch 32/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9897 - accuracy: 0.9874 - dice_coef: 0.9897 - specificity: 0.9959 - sensitivity: 0.9903 - precision: 0.9903
# Epoch 32: val_dice_coef improved from 0.98136 to 0.98170, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9897 - accuracy: 0.9874 - dice_coef: 0.9897 - specificity: 0.9959 - sensitivity: 0.9903 - precision: 0.9903 - val_loss: -0.9817 - val_accuracy: 0.9834 - val_dice_coef: 0.9817 - val_specificity: 0.9925 - val_sensitivity: 0.9823 - val_precision: 0.9818 - lr: 2.0000e-04
# Epoch 33/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9904 - accuracy: 0.9877 - dice_coef: 0.9904 - specificity: 0.9961 - sensitivity: 0.9910 - precision: 0.9909
# Epoch 33: val_dice_coef did not improve from 0.98170
# 249/249 [==============================] - 86s 347ms/step - loss: -0.9904 - accuracy: 0.9877 - dice_coef: 0.9904 - specificity: 0.9961 - sensitivity: 0.9910 - precision: 0.9909 - val_loss: -0.9816 - val_accuracy: 0.9833 - val_dice_coef: 0.9816 - val_specificity: 0.9923 - val_sensitivity: 0.9827 - val_precision: 0.9813 - lr: 2.0000e-04
# Epoch 34/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9906 - accuracy: 0.9878 - dice_coef: 0.9906 - specificity: 0.9963 - sensitivity: 0.9913 - precision: 0.9912
# Epoch 34: val_dice_coef did not improve from 0.98170
# 249/249 [==============================] - 85s 344ms/step - loss: -0.9906 - accuracy: 0.9878 - dice_coef: 0.9906 - specificity: 0.9963 - sensitivity: 0.9913 - precision: 0.9912 - val_loss: -0.9809 - val_accuracy: 0.9829 - val_dice_coef: 0.9809 - val_specificity: 0.9919 - val_sensitivity: 0.9820 - val_precision: 0.9804 - lr: 2.0000e-04
# Epoch 35/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9905 - accuracy: 0.9878 - dice_coef: 0.9905 - specificity: 0.9962 - sensitivity: 0.9912 - precision: 0.9911
# Epoch 35: val_dice_coef did not improve from 0.98170
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9905 - accuracy: 0.9878 - dice_coef: 0.9905 - specificity: 0.9962 - sensitivity: 0.9912 - precision: 0.9911 - val_loss: -0.9806 - val_accuracy: 0.9828 - val_dice_coef: 0.9806 - val_specificity: 0.9924 - val_sensitivity: 0.9803 - val_precision: 0.9814 - lr: 2.0000e-04
# Epoch 36/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9902 - accuracy: 0.9877 - dice_coef: 0.9902 - specificity: 0.9960 - sensitivity: 0.9909 - precision: 0.9906
# Epoch 36: val_dice_coef did not improve from 0.98170
# 249/249 [==============================] - 86s 347ms/step - loss: -0.9902 - accuracy: 0.9877 - dice_coef: 0.9902 - specificity: 0.9960 - sensitivity: 0.9909 - precision: 0.9906 - val_loss: -0.9809 - val_accuracy: 0.9829 - val_dice_coef: 0.9809 - val_specificity: 0.9921 - val_sensitivity: 0.9816 - val_precision: 0.9809 - lr: 2.0000e-04
# Epoch 37/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9904 - accuracy: 0.9878 - dice_coef: 0.9904 - specificity: 0.9962 - sensitivity: 0.9910 - precision: 0.9909
# Epoch 37: val_dice_coef did not improve from 0.98170
# 249/249 [==============================] - 85s 343ms/step - loss: -0.9904 - accuracy: 0.9878 - dice_coef: 0.9904 - specificity: 0.9962 - sensitivity: 0.9910 - precision: 0.9909 - val_loss: -0.9809 - val_accuracy: 0.9830 - val_dice_coef: 0.9809 - val_specificity: 0.9920 - val_sensitivity: 0.9819 - val_precision: 0.9807 - lr: 2.0000e-04
# Epoch 38/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9918 - accuracy: 0.9884 - dice_coef: 0.9918 - specificity: 0.9968 - sensitivity: 0.9926 - precision: 0.9924
# Epoch 38: val_dice_coef improved from 0.98170 to 0.98227, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 350ms/step - loss: -0.9918 - accuracy: 0.9884 - dice_coef: 0.9918 - specificity: 0.9968 - sensitivity: 0.9926 - precision: 0.9924 - val_loss: -0.9823 - val_accuracy: 0.9836 - val_dice_coef: 0.9823 - val_specificity: 0.9936 - val_sensitivity: 0.9809 - val_precision: 0.9844 - lr: 4.0000e-05
# Epoch 39/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9924 - accuracy: 0.9886 - dice_coef: 0.9924 - specificity: 0.9971 - sensitivity: 0.9932 - precision: 0.9932
# Epoch 39: val_dice_coef improved from 0.98227 to 0.98233, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 352ms/step - loss: -0.9924 - accuracy: 0.9886 - dice_coef: 0.9924 - specificity: 0.9971 - sensitivity: 0.9932 - precision: 0.9932 - val_loss: -0.9823 - val_accuracy: 0.9836 - val_dice_coef: 0.9823 - val_specificity: 0.9935 - val_sensitivity: 0.9812 - val_precision: 0.9842 - lr: 4.0000e-05
# Epoch 40/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9928 - accuracy: 0.9887 - dice_coef: 0.9928 - specificity: 0.9973 - sensitivity: 0.9937 - precision: 0.9937
# Epoch 40: val_dice_coef improved from 0.98233 to 0.98236, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9928 - accuracy: 0.9887 - dice_coef: 0.9928 - specificity: 0.9973 - sensitivity: 0.9937 - precision: 0.9937 - val_loss: -0.9824 - val_accuracy: 0.9836 - val_dice_coef: 0.9824 - val_specificity: 0.9935 - val_sensitivity: 0.9813 - val_precision: 0.9842 - lr: 4.0000e-05
# Epoch 41/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9931 - accuracy: 0.9888 - dice_coef: 0.9931 - specificity: 0.9975 - sensitivity: 0.9940 - precision: 0.9940
# Epoch 41: val_dice_coef improved from 0.98236 to 0.98244, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9931 - accuracy: 0.9888 - dice_coef: 0.9931 - specificity: 0.9975 - sensitivity: 0.9940 - precision: 0.9940 - val_loss: -0.9824 - val_accuracy: 0.9837 - val_dice_coef: 0.9824 - val_specificity: 0.9934 - val_sensitivity: 0.9817 - val_precision: 0.9840 - lr: 4.0000e-05
# Epoch 42/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9934 - accuracy: 0.9889 - dice_coef: 0.9934 - specificity: 0.9976 - sensitivity: 0.9943 - precision: 0.9943
# Epoch 42: val_dice_coef did not improve from 0.98244
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9934 - accuracy: 0.9889 - dice_coef: 0.9934 - specificity: 0.9976 - sensitivity: 0.9943 - precision: 0.9943 - val_loss: -0.9824 - val_accuracy: 0.9837 - val_dice_coef: 0.9824 - val_specificity: 0.9935 - val_sensitivity: 0.9816 - val_precision: 0.9841 - lr: 4.0000e-05
# Epoch 43/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9936 - accuracy: 0.9889 - dice_coef: 0.9936 - specificity: 0.9977 - sensitivity: 0.9945 - precision: 0.9946
# Epoch 43: val_dice_coef improved from 0.98244 to 0.98244, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 350ms/step - loss: -0.9936 - accuracy: 0.9889 - dice_coef: 0.9936 - specificity: 0.9977 - sensitivity: 0.9945 - precision: 0.9946 - val_loss: -0.9824 - val_accuracy: 0.9837 - val_dice_coef: 0.9824 - val_specificity: 0.9934 - val_sensitivity: 0.9818 - val_precision: 0.9840 - lr: 4.0000e-05
# Epoch 44/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9937 - accuracy: 0.9890 - dice_coef: 0.9937 - specificity: 0.9978 - sensitivity: 0.9948 - precision: 0.9948
# Epoch 44: val_dice_coef improved from 0.98244 to 0.98245, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 352ms/step - loss: -0.9937 - accuracy: 0.9890 - dice_coef: 0.9937 - specificity: 0.9978 - sensitivity: 0.9948 - precision: 0.9948 - val_loss: -0.9825 - val_accuracy: 0.9837 - val_dice_coef: 0.9825 - val_specificity: 0.9934 - val_sensitivity: 0.9817 - val_precision: 0.9840 - lr: 4.0000e-05
# Epoch 45/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9939 - accuracy: 0.9890 - dice_coef: 0.9939 - specificity: 0.9979 - sensitivity: 0.9950 - precision: 0.9950
# Epoch 45: val_dice_coef improved from 0.98245 to 0.98253, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9939 - accuracy: 0.9890 - dice_coef: 0.9939 - specificity: 0.9979 - sensitivity: 0.9950 - precision: 0.9950 - val_loss: -0.9825 - val_accuracy: 0.9837 - val_dice_coef: 0.9825 - val_specificity: 0.9935 - val_sensitivity: 0.9819 - val_precision: 0.9841 - lr: 4.0000e-05
# Epoch 46/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9941 - accuracy: 0.9891 - dice_coef: 0.9941 - specificity: 0.9980 - sensitivity: 0.9951 - precision: 0.9952
# Epoch 46: val_dice_coef improved from 0.98253 to 0.98254, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 349ms/step - loss: -0.9941 - accuracy: 0.9891 - dice_coef: 0.9941 - specificity: 0.9980 - sensitivity: 0.9951 - precision: 0.9952 - val_loss: -0.9825 - val_accuracy: 0.9837 - val_dice_coef: 0.9825 - val_specificity: 0.9934 - val_sensitivity: 0.9819 - val_precision: 0.9840 - lr: 4.0000e-05
# Epoch 47/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9942 - accuracy: 0.9891 - dice_coef: 0.9942 - specificity: 0.9980 - sensitivity: 0.9953 - precision: 0.9954
# Epoch 47: val_dice_coef did not improve from 0.98254
# 249/249 [==============================] - 87s 348ms/step - loss: -0.9942 - accuracy: 0.9891 - dice_coef: 0.9942 - specificity: 0.9980 - sensitivity: 0.9953 - precision: 0.9954 - val_loss: -0.9825 - val_accuracy: 0.9837 - val_dice_coef: 0.9825 - val_specificity: 0.9935 - val_sensitivity: 0.9817 - val_precision: 0.9842 - lr: 4.0000e-05
# Epoch 48/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9943 - accuracy: 0.9891 - dice_coef: 0.9943 - specificity: 0.9981 - sensitivity: 0.9955 - precision: 0.9955
# Epoch 48: val_dice_coef did not improve from 0.98254
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9943 - accuracy: 0.9891 - dice_coef: 0.9943 - specificity: 0.9981 - sensitivity: 0.9955 - precision: 0.9955 - val_loss: -0.9825 - val_accuracy: 0.9837 - val_dice_coef: 0.9825 - val_specificity: 0.9934 - val_sensitivity: 0.9820 - val_precision: 0.9840 - lr: 4.0000e-05
# Epoch 49/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9944 - accuracy: 0.9892 - dice_coef: 0.9944 - specificity: 0.9982 - sensitivity: 0.9956 - precision: 0.9957
# Epoch 49: val_dice_coef improved from 0.98254 to 0.98263, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 98s 396ms/step - loss: -0.9944 - accuracy: 0.9892 - dice_coef: 0.9944 - specificity: 0.9982 - sensitivity: 0.9956 - precision: 0.9957 - val_loss: -0.9826 - val_accuracy: 0.9837 - val_dice_coef: 0.9826 - val_specificity: 0.9935 - val_sensitivity: 0.9821 - val_precision: 0.9841 - lr: 4.0000e-05
# Epoch 50/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9945 - accuracy: 0.9892 - dice_coef: 0.9945 - specificity: 0.9982 - sensitivity: 0.9958 - precision: 0.9958
# Epoch 50: val_dice_coef improved from 0.98263 to 0.98269, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 98s 393ms/step - loss: -0.9945 - accuracy: 0.9892 - dice_coef: 0.9945 - specificity: 0.9982 - sensitivity: 0.9958 - precision: 0.9958 - val_loss: -0.9827 - val_accuracy: 0.9837 - val_dice_coef: 0.9827 - val_specificity: 0.9933 - val_sensitivity: 0.9826 - val_precision: 0.9837 - lr: 4.0000e-05
# Epoch 51/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9946 - accuracy: 0.9892 - dice_coef: 0.9946 - specificity: 0.9983 - sensitivity: 0.9959 - precision: 0.9959
# Epoch 51: val_dice_coef improved from 0.98269 to 0.98269, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9946 - accuracy: 0.9892 - dice_coef: 0.9946 - specificity: 0.9983 - sensitivity: 0.9959 - precision: 0.9959 - val_loss: -0.9827 - val_accuracy: 0.9837 - val_dice_coef: 0.9827 - val_specificity: 0.9932 - val_sensitivity: 0.9829 - val_precision: 0.9835 - lr: 4.0000e-05
# Epoch 52/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9947 - accuracy: 0.9892 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960
# Epoch 52: val_dice_coef did not improve from 0.98269
# 249/249 [==============================] - 86s 347ms/step - loss: -0.9947 - accuracy: 0.9892 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960 - val_loss: -0.9827 - val_accuracy: 0.9837 - val_dice_coef: 0.9827 - val_specificity: 0.9932 - val_sensitivity: 0.9827 - val_precision: 0.9836 - lr: 4.0000e-05
# Epoch 53/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9947 - accuracy: 0.9892 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960
# Epoch 53: val_dice_coef did not improve from 0.98269
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9947 - accuracy: 0.9892 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960 - val_loss: -0.9826 - val_accuracy: 0.9836 - val_dice_coef: 0.9826 - val_specificity: 0.9932 - val_sensitivity: 0.9826 - val_precision: 0.9835 - lr: 4.0000e-05
# Epoch 54/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9947 - accuracy: 0.9893 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9959 - precision: 0.9959
# Epoch 54: val_dice_coef did not improve from 0.98269
# 249/249 [==============================] - 96s 385ms/step - loss: -0.9947 - accuracy: 0.9893 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9959 - precision: 0.9959 - val_loss: -0.9823 - val_accuracy: 0.9835 - val_dice_coef: 0.9823 - val_specificity: 0.9931 - val_sensitivity: 0.9822 - val_precision: 0.9833 - lr: 4.0000e-05
# Epoch 55/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9947 - accuracy: 0.9893 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960
# Epoch 55: val_dice_coef did not improve from 0.98269
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9947 - accuracy: 0.9893 - dice_coef: 0.9947 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960 - val_loss: -0.9822 - val_accuracy: 0.9835 - val_dice_coef: 0.9822 - val_specificity: 0.9929 - val_sensitivity: 0.9824 - val_precision: 0.9828 - lr: 4.0000e-05
# Epoch 56/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9948 - accuracy: 0.9893 - dice_coef: 0.9948 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960
# Epoch 56: val_dice_coef improved from 0.98269 to 0.98291, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 349ms/step - loss: -0.9948 - accuracy: 0.9893 - dice_coef: 0.9948 - specificity: 0.9983 - sensitivity: 0.9960 - precision: 0.9960 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9831 - val_precision: 0.9838 - lr: 8.0000e-06
# Epoch 57/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9949 - accuracy: 0.9893 - dice_coef: 0.9949 - specificity: 0.9984 - sensitivity: 0.9962 - precision: 0.9962
# Epoch 57: val_dice_coef improved from 0.98291 to 0.98291, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 352ms/step - loss: -0.9949 - accuracy: 0.9893 - dice_coef: 0.9949 - specificity: 0.9984 - sensitivity: 0.9962 - precision: 0.9962 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9831 - val_precision: 0.9838 - lr: 8.0000e-06
# Epoch 58/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9949 - accuracy: 0.9893 - dice_coef: 0.9949 - specificity: 0.9984 - sensitivity: 0.9963 - precision: 0.9963
# Epoch 58: val_dice_coef improved from 0.98291 to 0.98292, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 353ms/step - loss: -0.9949 - accuracy: 0.9893 - dice_coef: 0.9949 - specificity: 0.9984 - sensitivity: 0.9963 - precision: 0.9963 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9831 - val_precision: 0.9838 - lr: 8.0000e-06
# Epoch 59/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9950 - accuracy: 0.9893 - dice_coef: 0.9950 - specificity: 0.9985 - sensitivity: 0.9964 - precision: 0.9964
# Epoch 59: val_dice_coef improved from 0.98292 to 0.98292, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9950 - accuracy: 0.9893 - dice_coef: 0.9950 - specificity: 0.9985 - sensitivity: 0.9964 - precision: 0.9964 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9934 - val_sensitivity: 0.9831 - val_precision: 0.9839 - lr: 8.0000e-06
# Epoch 60/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9950 - accuracy: 0.9893 - dice_coef: 0.9950 - specificity: 0.9985 - sensitivity: 0.9965 - precision: 0.9965
# Epoch 60: val_dice_coef improved from 0.98292 to 0.98292, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 352ms/step - loss: -0.9950 - accuracy: 0.9893 - dice_coef: 0.9950 - specificity: 0.9985 - sensitivity: 0.9965 - precision: 0.9965 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9934 - val_sensitivity: 0.9831 - val_precision: 0.9839 - lr: 8.0000e-06
# Epoch 61/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9951 - accuracy: 0.9893 - dice_coef: 0.9951 - specificity: 0.9985 - sensitivity: 0.9966 - precision: 0.9965
# Epoch 61: val_dice_coef improved from 0.98292 to 0.98293, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 354ms/step - loss: -0.9951 - accuracy: 0.9893 - dice_coef: 0.9951 - specificity: 0.9985 - sensitivity: 0.9966 - precision: 0.9965 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9934 - val_sensitivity: 0.9831 - val_precision: 0.9839 - lr: 8.0000e-06
# Epoch 62/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9951 - accuracy: 0.9893 - dice_coef: 0.9951 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9966
# Epoch 62: val_dice_coef improved from 0.98293 to 0.98293, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 350ms/step - loss: -0.9951 - accuracy: 0.9893 - dice_coef: 0.9951 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9966 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9833 - val_precision: 0.9837 - lr: 1.6000e-06
# Epoch 63/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9951 - accuracy: 0.9893 - dice_coef: 0.9951 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9966
# Epoch 63: val_dice_coef did not improve from 0.98293
# 249/249 [==============================] - 96s 386ms/step - loss: -0.9951 - accuracy: 0.9893 - dice_coef: 0.9951 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9966 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9833 - val_precision: 0.9837 - lr: 1.6000e-06
# Epoch 64/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9967
# Epoch 64: val_dice_coef did not improve from 0.98293
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9833 - val_precision: 0.9837 - lr: 1.6000e-06
# Epoch 65/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9967
# Epoch 65: val_dice_coef improved from 0.98293 to 0.98293, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 349ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9833 - val_precision: 0.9837 - lr: 1.6000e-06
# Epoch 66/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 66: val_dice_coef improved from 0.98293 to 0.98293, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 350ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9933 - val_sensitivity: 0.9833 - val_precision: 0.9837 - lr: 1.6000e-06
# Epoch 67/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9968
# Epoch 67: val_dice_coef improved from 0.98293 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9966 - precision: 0.9968 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 3.2000e-07
# Epoch 68/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 68: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 342ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 3.2000e-07
# Epoch 69/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 69: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 3.2000e-07
# Epoch 70/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 70: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 343ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 3.2000e-07
# Epoch 71/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 71: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 340ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 3.2000e-07
# Epoch 72/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9968
# Epoch 72: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9952 - accuracy: 0.9893 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9968 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 6.4000e-08
# Epoch 73/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9968
# Epoch 73: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 351ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9968 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 6.4000e-08
# Epoch 74/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 74: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 349ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9932 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 6.4000e-08
# Epoch 75/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 75: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 355ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 6.4000e-08
# Epoch 76/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 76: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 87s 350ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 6.4000e-08
# Epoch 77/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 77: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 343ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.2800e-08
# Epoch 78/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 78: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 89s 357ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.2800e-08
# Epoch 79/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 79: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 96s 386ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.2800e-08
# Epoch 80/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 80: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 87s 347ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.2800e-08
# Epoch 81/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 81: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 353ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.2800e-08
# Epoch 82/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 82: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 353ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.5600e-09
# Epoch 83/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 83: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 87s 349ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.5600e-09
# Epoch 84/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 84: val_dice_coef improved from 0.98294 to 0.98294, saving model to best_model_224_res_reduce_lr2302.h5
# 249/249 [==============================] - 88s 352ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.5600e-09
# Epoch 85/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 85: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 97s 388ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.5600e-09
# Epoch 86/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 86: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 87s 348ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.5600e-09
# Epoch 87/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 87: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 5.1200e-10
# Epoch 88/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 88: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 347ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 5.1200e-10
# Epoch 89/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 89: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 342ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 5.1200e-10
# Epoch 90/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 90: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 5.1200e-10
# Epoch 91/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 91: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 5.1200e-10
# Epoch 92/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 92: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.0240e-10
# Epoch 93/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 93: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.0240e-10
# Epoch 94/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 94: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.0240e-10
# Epoch 95/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 95: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 344ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.0240e-10
# Epoch 96/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 96: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 346ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 1.0240e-10
# Epoch 97/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 97: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.0480e-11
# Epoch 98/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 98: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 86s 345ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.0480e-11
# Epoch 99/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 99: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 344ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.0480e-11
# Epoch 100/100
# 249/249 [==============================] - ETA: 0s - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967
# Epoch 100: val_dice_coef did not improve from 0.98294
# 249/249 [==============================] - 85s 343ms/step - loss: -0.9952 - accuracy: 0.9894 - dice_coef: 0.9952 - specificity: 0.9986 - sensitivity: 0.9967 - precision: 0.9967 - val_loss: -0.9829 - val_accuracy: 0.9838 - val_dice_coef: 0.9829 - val_specificity: 0.9931 - val_sensitivity: 0.9836 - val_precision: 0.9834 - lr: 2.0480e-11

# %% [markdown]
# # Visualize training

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['dice_coef'], 'b', label='train dice coef')
acc_ax.plot(results.history['val_dice_coef'], 'g', label='val dice coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['specificity'], 'b', label='train specificity')
acc_ax.plot(results.history['val_specificity'], 'g', label='val specificity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['sensitivity'], 'b', label='train sensitivity')
acc_ax.plot(results.history['val_sensitivity'], 'g', label='val sensitivity')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(results.history['loss'], 'y', label='train loss')
loss_ax.plot(results.history['val_loss'], 'r', label='val loss')

acc_ax.plot(results.history['precision'], 'b', label='train precision')
acc_ax.plot(results.history['val_precision'], 'g', label='val precision')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
print(results.history['precision'][-1])
# Out:
# 0.9967459440231323

# %%
print(results.history['dice_coef'][-1])
# Out:
# 0.9952038526535034

# %%
print(results.history['specificity'][-1])
# Out:
# 0.9986162185668945

# %% [markdown]
# # Predict

# %%
# import os
test_list = os.listdir("test_set/")
print("The number of test data : ", len(test_list))
test_list[:5]
# Out:
# The number of test data :  335
# ['001_HC.png', '000_HC.png', '003_HC.png', '004_HC.png', '002_HC.png']

# %%
#used just for prediction, not as a checkpoint
model = tf.keras.models.load_model('best_model_224_res_reduce_lr2302.h5', custom_objects={'dice_coef_loss': dice_coef_loss, 'dice_coef':dice_coef,'specificity':specificity,'sensitivity':sensitivity,'precision':precision})

# %%
smooth=1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection +smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def dice_coef(y_true, y_pred):
    # convert to 2D before comparing results
    # y_true = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
    # print(np.array(y_true).shape)
    # print(np.array(y_pred).shape)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)


    # print((2. * intersection ) / (K.sum(y_true_f) + K.sum(y_pred_f) ))
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def jac_distance(y_true, y_pred ):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    # intersection = K.sum(y_true_f * y_pred_f)

    intersection = K.sum(K.abs(y_true_f * y_pred_f), axis=-1)
    sum_ = K.sum(K.abs(y_true_f) + K.abs(y_pred_f), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    # print(jac)
    return jac


def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
X_50 = train_image[:]
y_50  = train_mask[:]

X_test = np.empty((len(X_50[:]), IMG_HEIGHT, IMG_WIDTH), dtype = 'float32')


for i, item in enumerate(X_50[:]):
    image = cv2.imread("training_set/" + item, 0)
    image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    X_test[i] = image


X_test = X_test[:,:,:,np.newaxis] / 255

# %%
X_test.shape
# Out:
# (999, 224, 224, 1)

# %%
y_pred = model.predict(X_test)
# Out:
# 32/32 [==============================] - 16s 160ms/step

# %%
y_pred.shape
# Out:
# (999, 224, 224, 1)

# %%
def getbound(binary_mask):

  # draw = np.zeros((*img.shape, 3), dtype=np.uint8)

  # draw[img > 0.5] = (255,) * 3
  kernelSize = (3,3)

  # gray = cv2.cvtColor(draw, cv2.COLOR_BGR2GRAY)
  kernel = cv2.getStructuringElement(cv2.MORPH_RECT, kernelSize)
  gradient = cv2.morphologyEx(binary_mask, cv2.MORPH_GRADIENT, kernel)
  # plt.imshow()
  # plt.show()
  # gradient = cv2.cvtColor(gradient, cv2.COLOR_GRAY2RGB)
  return gradient

def get_largest_component(gray):
    # convert the image to grayscale
    # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Convert to CV_8UC1 with scaling     
    scaled_img = cv2.convertScaleAbs(img, alpha=(255.0/np.max(img)))
    # apply thresholding to binarize the image
    _, thresh = cv2.threshold(scaled_img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    # find contours in the binary image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # get the largest contour based on area
    largest_contour = max(contours, key=cv2.contourArea)

    # create a mask for the largest contour
    mask = np.zeros(img.shape[:2], np.uint8)
    cv2.drawContours(mask, [largest_contour], 0, 255, -1)

    # apply the mask to the original image to get only the largest component
    largest_component = cv2.bitwise_and(img, img, mask=mask)

    return largest_component


def commonRows(A, B):

    #reformat B
    B = np.squeeze( B, axis=1  )
    B = np.fliplr(B)

    aset = set([tuple(x) for x in A])
    bset = set([tuple(x. tolist() ) for x in B])
    
    return np.array([x for x in aset & bset])

def fitEllipse(binary_mask, method):
    assert binary_mask.min() >= 0.0 and binary_mask.max() <= 1.0

  
    #get largest contour
    img_gray_8bit = cv2.convertScaleAbs(binary_mask, alpha=(255.0/np.max(binary_mask)))
    contours, hierarchy = cv2.findContours(img_gray_8bit, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    largest_contour = max(contours, key=cv2.contourArea)
    # binary_mask = cv2.convertScaleAbs(largest_contour, alpha=(np.max(largest_contour)/255.0))
    
    # largest_component  = get_largest_component(binary_mask)
    gradient  = getbound(binary_mask)

    # print(gradient.shape)

    points1 = np.argwhere(gradient > 0.5)  


    points1 = commonRows(points1,largest_contour)
    
    points = points1


    if method == "AMS":
      #taubins method
        (xx, yy), (MA, ma), angle = cv2.fitEllipseAMS(points)
    elif method == "Direct":
      #Fitzgibbon1999
        (xx, yy), (MA, ma), angle = cv2.fitEllipseDirect(points)
    elif method == "Simple":
      #Fitzgibbon95]
        (xx, yy), (MA, ma), angle = cv2.fitEllipse(points)

    return (xx, yy), (MA, ma), angle

# %%
i=0

dice_val = []
jac_val = []
# ellipse_val = []
precision_val = []
specificity_val = []
sensitivity_val  = []

ellipse_val_direct = []
ellipse_val_direct_img = []
ellipse_val_direct_dice = []

ellipse_val_AMS = []
ellipse_val_AMS_img = []
ellipse_val_AMS_dice = []

ellipse_val_Simple = []
ellipse_val_Simple_img = []
ellipse_val_Simple_dice = []




for test, pred in zip(X_test[:],y_pred[:]):

    y_true = cv2.imread("training_set/" + y_50[i], 0)
    # y_true = cv2.cvtColor(y_50[i], cv2.COLOR_BGR2GRAY)
    y_true = cv2.resize(y_true, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
    y_true = np.array(y_true).astype(float) / 255.0
    y_p = np.array(pred).astype(float)


    dice = dice_coef( y_true, y_p)
    jac = jac_distance(y_true, y_p)
    pr = precision( y_true, y_p)
    sp = specificity( y_true, y_p)
    se = sensitivity( y_true, y_p)

    dice_val.append(dice)
    jac_val.append(jac)
    precision_val.append(pr)
    specificity_val.append(sp)
    sensitivity_val.append(se)
    i=i+1

    # fig, ax = plt.subplots(1,4,figsize = (16,16))
    # test = test.reshape((IMG_HEIGHT,IMG_WIDTH))
    # pred = pred.reshape((IMG_HEIGHT,IMG_WIDTH))

    #direct
    img1 = pred.copy()
    (xx1, yy1), (MA1, ma1), angle1 = fitEllipse(img1,method="Direct")
    # print((xx, yy), (MA, ma), angle)
    ellipse_val_direct.append([(xx1, yy1), (MA1, ma1), angle1])
    img1 = np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), np.uint8)
    
    cv2.ellipse(
        img1,
        (int(yy1), int(xx1)),
        (int(ma1 / 2), int(MA1 / 2)),
        -angle1,
        0,
        360,
        color=(255, 255, 255),
        thickness=-1,
    )
    
    ellipse_val_direct_img.append(img1)
    img1 =  cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    ed = dice_coef( y_true, np.array(img1).astype(float)/255.0)
    ellipse_val_direct_dice.append(ed)



    #AMS
    img2 = pred.copy()
    (xx2, yy2), (MA2, ma2), angle2 = fitEllipse(img2,method="AMS")
    # print((xx, yy), (MA, ma), angle)
    ellipse_val_AMS.append([(xx2, yy2), (MA2, ma2), angle2])
    img2 = np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), np.uint8)
    cv2.ellipse(
        img2,
        (int(yy2), int(xx2)),
        (int(ma2 / 2), int(MA2 / 2)),
        -angle2,
        0,
        360,
        color=(255, 255, 255),
        thickness=-1,
    )
    
    ellipse_val_AMS_img.append(img2)
    img2 =  cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    ed = dice_coef( y_true, np.array(img2).astype(float)/255.0)
    ellipse_val_AMS_dice.append(ed)

    #simple
    img3 = pred.copy()
    (xx3, yy3), (MA3, ma3), angle3 = fitEllipse(img3,method="Simple")
    # print((xx, yy), (MA, ma), angle)
    ellipse_val_Simple.append([(xx3, yy3), (MA3, ma3), angle3])
    img3 = np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), np.uint8)
    cv2.ellipse(
        img3,
        (int(yy3), int(xx3)),
        (int(ma3 / 2), int(MA3 / 2)),
        -angle3,
        0,
        360,
        color=(255, 255, 255),
        thickness=-1,
    )
    
    ellipse_val_Simple_img.append(img3)
    img3 =  cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
    ed = dice_coef( y_true, np.array(img3).astype(float)/255.0)
    ellipse_val_Simple_dice.append(ed)


    # draw = np.zeros((*img.shape, 3), dtype=np.uint8)
    # draw = draw + 255  
    # # draw[img > 0.5] = (255,) * 3


    # cv2.ellipse(
    #     draw,
    #     (int(yy1), int(xx1)),
    #     (int(ma1 / 2), int(MA1 / 2)),
    #     -angle1,
    #     0,
    #     360,
    #     color=(255, 0, 0),
    #     thickness=3,
    # )
    
    # cv2.ellipse(
    #     draw,
    #     (int(yy2), int(xx2)),
    #     (int(ma2 / 2), int(MA2/ 2)),
    #     -angle2,
    #     0,
    #     360,
    #     color=(0, 255, 0),
    #     thickness=2,
    # )
    
    # cv2.ellipse(
    #     draw,
    #     (int(yy3), int(xx3)),
    #     (int(ma3 / 2), int(MA3 / 2)),
    #     -angle3,
    #     0,
    #     360,
    #     color=(0, 0, 255),
    #     thickness=1,
    # )
    
    # pred = pred<0.5
    # pred = np.ma.masked_where(pred == 0, pred)

    # ax[0].imshow(test, cmap = 'gray')

    # ax[1].imshow(pred, cmap = 'gray', interpolation = 'none')
    # ax[1].imshow(y_true, cmap = 'jet', interpolation = 'none', alpha=0.7)

    # ax[2].imshow(test, cmap = 'gray', interpolation = 'none')
    # ax[2].imshow(pred, cmap = 'jet', interpolation = 'none', alpha = 0.7)
    # ax[3].text(3, 7, 'dice ' + str(round(float(dice),4)) + '\njacc ' + str(round(float(jac),4)), fontsize = 15, color = 'g')

    # ax[3].imshow(draw,cmap='jet')

# %% [markdown]
# # statistical analysis

# %%
import pandas as pd

# %%
#take input as index
def showImage(i,method):
  test = X_test[i]
  pred = y_pred[i]
  
  draw = np.zeros((*img.shape,), dtype=np.uint8)
  draw = draw + 255  
    # # draw[img > 0.5] = (255,) * 3

  y_true = cv2.imread("training_set/" + y_50[i], 0)
  # y_true = cv2.cvtColor(y_50[i], cv2.COLOR_BGR2GRAY)
  y_true = cv2.resize(y_true, (IMG_HEIGHT, IMG_WIDTH), interpolation=cv2.INTER_AREA)
  y_true = np.array(y_true).astype(float) / 255.0
  y_p = np.array(pred).astype(float)
  dice = dice_coef( y_true, y_p)
  jac = jac_distance(y_true, y_p)

  # count = np.count_nonzero(y_true > 0.01)
  # print(count)
  # count = np.count_nonzero(y_p > 0.1)
  # print(count)
  img3 = pred.copy()

  # largest_component = get_largest_component(img3)

  # print(largest_component.shape)

  (xx3, yy3), (MA3, ma3), angle3 = fitEllipse(img3, method)

  img3 = np.zeros((IMG_HEIGHT, IMG_WIDTH, 3), np.uint8)
  cv2.ellipse(draw, (int(yy3), int(xx3)), (int(ma3 / 2), int(MA3 / 2)), -angle3, 0, 360,color=(255, 0, 0), thickness=-1)
  cv2.ellipse(img3, (int(yy3), int(xx3)), (int(ma3 / 2), int(MA3 / 2)), -angle3, 0, 360,color=(255, 255, 255), thickness=-1)
  img3 =  cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
  ed = dice_coef( y_true, np.array(img3).astype(float)/255.0)
  ej = jac_distance( y_true, np.array(img3).astype(float)/255.0)

  fig, ax = plt.subplots(1, 4, figsize=(16, 16))
  test = test.reshape((IMG_HEIGHT, IMG_WIDTH))
  pred = pred.reshape((IMG_HEIGHT, IMG_WIDTH))
  ax[0].imshow(test, cmap='gray')
  ax[0].text(3,7, ' '+ str(i),fontsize=14,color='r')
  ax[1].imshow(pred, cmap='gray', interpolation='none')
  ax[1].imshow(y_true, cmap='jet', interpolation='none', alpha=0.7)
  ax[1].text(3, 7, 'dice ' + str(round(float(dice), 4)) + '\njacc ' + str(round(float(jac), 4)), fontsize=15, color='g')

  ax[2].imshow(test, cmap='gray', interpolation='none')
  ax[2].imshow(pred, cmap='jet', interpolation='none', alpha=0.7)

  ax[3].imshow(draw, cmap='gray')
  ax[3].imshow(y_true, cmap='jet', interpolation='none', alpha=0.7)
  ax[3].text(3, 7, 'dice ' + str(round(float(ed), 4)) + '\njacc ' + str(round(float(ej), 4)), fontsize=15, color='g')

# %%
showImage(120,"AMS")

# %%
  # For Colab users
from google.colab.patches import cv2_imshow

def imshowww(img):

    cv2_imshow(img)

    # For Jupyter Notebook users:
    # cv2.imshow(“Penguin”, img)  # Here, "Penguin" is the name that'll be given to the window
    
    # waiting for key event
    cv2.waitKey(0)

    # destroying all windows
    cv2.destroyAllWindows()

# %%
lowest_indices = np.argsort(dice_val)[0:10]
for i in lowest_indices:
  showImage(i,"AMS")

# %%
lowest_indices = np.argsort(ellipse_val_direct_dice)[0:10]
for i in lowest_indices:
  showImage(i,"AMS")

# %%
# Generate some random dice scores
dice_scores = np.array(dice_val)

#remove 1 outlier
dice_scores = dice_scores[dice_scores != np.min(dice_scores)]



# Create a boxplot of the dice scores
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
axs[0].boxplot(dice_scores*100)
axs[0].set_title('Dice Scores')
axs[0].set_ylabel('Score')

# Create a Bland-Altman plot of the dice scores
# mean = np.mean(dice_scores)
# diff = dice_scores - mean
# mean_diff = np.mean(diff)
# std_diff = np.std(diff)
# limit_of_agreement = 1.96 * std_diff
# lower_loa = mean_diff - limit_of_agreement
# upper_loa = mean_diff + limit_of_agreement
# axs[1].scatter(np.full(len(diff), mean), diff)
# axs[1].axhline(mean_diff, color='black', linestyle='--')
# axs[1].axhline(lower_loa, color='red', linestyle='--')
# axs[1].axhline(upper_loa, color='red', linestyle='--')
# axs[1].set_title('Bland-Altman Plot')
# axs[1].set_xlabel('Mean of Dice Scores')
# axs[1].set_ylabel('Difference from Mean')

# Create a histogram of the dice scores
axs[1].hist(dice_scores, bins=1000)
axs[1].set_xlim([min(dice_scores), max(dice_scores)])
axs[1].set_title('Histogram of Dice Scores')
axs[1].set_xlabel('Score')
axs[1].set_ylabel('Frequency')



plt.show()

# %%
# Plot the data
fig, ax = plt.subplots(1,3,figsize=(15, 5))

ax[0].plot(ellipse_val_direct_dice, label='Direct method', color='green')
ax[1].plot(ellipse_val_AMS_dice, label='AMS method', color='blue')
ax[2].plot(ellipse_val_Simple_dice, label='Simple method', color='red')

# ax.set_xlabel('Sample Index')
# ax.set_ylabel('Dice Score')
# ax.set_title('Comparison of Ellipse Fitting Methods')

# ax.legend()
plt.show()

# %%
np.not_equal(ellipse_val_direct_dice, ellipse_val_AMS_dice).nonzero()
# Calculate the mean difference between the two methods
mean_diff = np.mean(np.array(ellipse_val_direct_dice) - np.array(ellipse_val_AMS_dice))

# Calculate the limits of agreement as mean difference plus/minus 1.96 times the standard deviation of the differences
limits_of_agreement = mean_diff + np.array([-1.96, 1.96]) * np.std(np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))

# Create the Bland-Altman plot
plt.scatter(np.mean([ellipse_val_direct_dice, ellipse_val_Simple_dice], axis=0), np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))
plt.axhline(mean_diff, color='gray', linestyle='--')
plt.axhline(limits_of_agreement[0], color='gray', linestyle='--')
plt.axhline(limits_of_agreement[1], color='gray', linestyle='--')
plt.xlabel('Mean of two methods')
plt.ylabel('Difference between two methods')
plt.title('Bland-Altman Plot')
plt.show()

# %%
np.not_equal(ellipse_val_direct_dice, ellipse_val_Simple_dice).nonzero()
# Calculate the mean difference between the two methods
mean_diff = np.mean(np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))

# Calculate the limits of agreement as mean difference plus/minus 1.96 times the standard deviation of the differences
limits_of_agreement = mean_diff + np.array([-1.96, 1.96]) * np.std(np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))

# Create the Bland-Altman plot
plt.scatter(np.mean([ellipse_val_direct_dice, ellipse_val_Simple_dice], axis=0), np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))
plt.axhline(mean_diff, color='gray', linestyle='--')
plt.axhline(limits_of_agreement[0], color='gray', linestyle='--')
plt.axhline(limits_of_agreement[1], color='gray', linestyle='--')
plt.xlabel('Mean of two methods')
plt.ylabel('Difference between two methods')
plt.title('Bland-Altman Plot')
plt.show()

# %%
np.not_equal(ellipse_val_AMS_dice, ellipse_val_Simple_dice).nonzero()
# Calculate the mean difference between the two methods
mean_diff = np.mean(np.array(ellipse_val_AMS_dice) - np.array(ellipse_val_Simple_dice))

# Calculate the limits of agreement as mean difference plus/minus 1.96 times the standard deviation of the differences
limits_of_agreement = mean_diff + np.array([-1.96, 1.96]) * np.std(np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))

# Create the Bland-Altman plot
plt.scatter(np.mean([ellipse_val_direct_dice, ellipse_val_Simple_dice], axis=0), np.array(ellipse_val_direct_dice) - np.array(ellipse_val_Simple_dice))
plt.axhline(mean_diff, color='gray', linestyle='--')
plt.axhline(limits_of_agreement[0], color='gray', linestyle='--')
plt.axhline(limits_of_agreement[1], color='gray', linestyle='--')
plt.xlabel('Mean of two methods')
plt.ylabel('Difference between two methods')
plt.title('Bland-Altman Plot')
plt.show()

# %%
print(ellipse_val_AMS_dice[9], ellipse_val_Simple_dice[9],ellipse_val_direct_dice[9])
# Out:
# tf.Tensor(0.17058410940618843, shape=(), dtype=float64) tf.Tensor(0.24921415961652765, shape=(), dtype=float64) tf.Tensor(0.17633170905999546, shape=(), dtype=float64)

# %%
n, bins, patches = plt.hist(dice_val,bins=np.arange(0,1,0.01))
plt.show()

# %%
df_describe = pd.DataFrame(dice_val)
df_describe.describe()
# Out:
#                 0
# count  999.000000
# mean     0.989332
# std      0.028776
# min      0.134231
# 25%      0.989455
# 50%      0.994043
# 75%      0.995374
# max      0.996966

# %%
n, bins, patches = plt.hist(jac_val,bins=np.arange(0,1,0.01))
plt.show()

# %%
df_describe = pd.DataFrame(jac_val)
df_describe.describe()
# Out:
#                 0
# count  999.000000
# mean     0.979838
# std      0.034158
# min      0.072144
# 25%      0.979131
# 50%      0.988156
# 75%      0.990791
# max      0.993951

# %%
n, bins, patches = plt.hist(precision_val,bins=np.arange(0,100,1))
plt.show()

# %% [markdown]
# bb
